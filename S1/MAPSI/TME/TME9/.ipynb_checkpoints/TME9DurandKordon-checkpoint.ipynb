# %% [markdown]
# # Régression & optimisation par descente de gradient
#
# Ce tme a deux objectifs:
#  - acquérir les connaissances de base pour faire face au problème de la régression, c'est à dire de l'estimation d'un score réel correpondant à une situation,
#  - travailler sur les techniques d'optimisation par descente de gradient

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Génération de données jouet & construction d'une solution analytique
#
# Dans un premier temps, générons des données jouets paramétriques:
#  - $N$: nombre de points à générer
#  - $x \in [0, 1]$ tirage avec un simple rand() ou un linspace() -au choix-
#      - Si vous optez pour un tirage aléatoire des abscisses, triez les points pour simplifier les traitements ultérieurs
#  - $y=ax+b+\epsilon, \epsilon \sim \mathcal N(0,\sigma^2)$
#      - Rappel : en multipliant un tirage aléatoire selon une gaussienne centrée réduite par $\sigma$ on obtient le bruit décrit ci-dessus
#
# Afin de travailler sur les bonnes pratiques, nous distinguerons un ensemble d'apprentissage et un ensemble de test.
# Les deux sont tirés selon la même distribution. L'ensemble de test comptera -arbitrairement- 1000 points.

# %%
def gen_data_lin(a, b, sig, N=500, Ntest=1000):
    X_train = np.sort(np.random.rand(N)) # sort optionnel, mais ça aide pour les plots
    X_test  = np.sort(np.random.rand(Ntest))
    sig1 = np.random.normal(0,sig,size=(N))
    sig2 = np.random.normal(0,sig,size=(Ntest))
    Y_train = a * X_train + b + sig1
    Y_test  = a * X_test + b + sig2
    return X_train, Y_train, X_test, Y_test

# %%
# génération de données jouets:
a = 6.
b = -1.
N = 100
sig = .4 # écart type

X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)

plt.figure()
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_train, Y_train, 'b')
plt.show()

# %% [markdown]
# Vous devez obtenir quelque chose de la forme:<br>
# ![données jouet](fig/gen_data.png)

# %% [markdown]
# ## Validation des formules analytiques
# Nous avons vu deux types de résolutions analytique: à partir des estimateurs des espérances et co-variances d'une part et des moindres carrés d'autre part. Testons les deux méthodes.
#
# ### Estimation de paramètres probabilistes
#  - $\hat a = \frac{\mbox{cov}(X,Y)}{\sigma_x^2}$
#  - $\hat b = E(Y)−\frac{\mbox{cov}(X,Y)}{\sigma_x^2} E(X)$
#
#  Estimer les paramètres, calculer l'erreur au sens des moindres carrés sur les données d'apprentissage et de test, puis tracer la droite de régression

# %%
def modele_lin_analytique(X_train, Y_train):
    cov_xy = np.cov(X_train, Y_train)[0][1]
    cov_std2 = cov_xy / (X_train.std()**2)
    ahat = cov_std2
    bhat = Y_train.mean() - cov_std2 * X_train.mean()
    return ahat, bhat

ahat, bhat = modele_lin_analytique(X_train, Y_train)
print(ahat,"\n",bhat)
# Out:
# 5.963473638350712
#  -1.0030290079012372

# %%
def erreur_mc(y, yhat):
    return ((y-yhat)**2).mean()

yhat_train = ahat*X_train+bhat
yhat_test  = ahat*X_test +bhat

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat_train, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):', erreur_mc(yhat_test, Y_test))
# Out:
# Erreur moyenne au sens des moindres carrés (train): 0.16997691190012454
# Erreur moyenne au sens des moindres carrés (test): 0.14933723251459036

# %%
plt.figure()
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_train, Y_train, 'b')
plt.plot(X_test, yhat_test, 'g', lw=3)

# %% [markdown]
# ## Formulation au sens des moindres carrés
#
# Nous partons directement sur une écriture matricielle. Du coup, il est nécessaire de construire la matrice enrichie $Xe$:
#     $$Xe = \left[\begin{array}{cc}
#                 X_0 & 1\\
#                 \vdots & \vdots\\
#                 X_N & 1
#                 \end{array}
#                 \right] $$
# Le code de la fonction d'enrichissement est donné ci-dessous.
#
# Il faut ensuite poser et résoudre un système d'équations linéaires de la forme:
# $$ A w = B $$
# **Rappel des formules vues en cours/TD:**
# $$ A=X^T X$$
# $$ B=X^T Y$$
# Fonction de résolution: `np.linalg.solve(A,B)`
# Vous devez obtenir la même solution que précédemment.

# %%
def make_mat_lin_biais(X): # fonctionne pour un vecteur unidimensionel X
    N = len(X)
    return np.hstack((X.reshape(N,1),np.ones((N,1))))

# %%
Xe = make_mat_lin_biais(X_train)
A = Xe.T @ Xe
B = Xe.T @ Y_train
w = np.linalg.solve(A,B)

print(w)
# Out:
# [ 5.9038389  -0.97653505]

# %% [markdown]
# Soit les données polynomiales générées avec la fonction ci-dessous
#  - proposer & une solution d'enrichissement (vue en cours et TD)
#  - résoudre analytiquement le problème des moindres carrés
#  - calculer l'erreur au sens des moindes carrés en apprentissage ET en test
#  - tracer les données et la solution

# %%
def gen_data_poly2(a, b, c, sig, N=500, Ntest=1000):
    '''
    Tire N points X aléatoirement entre 0 et 1 et génère y = ax^2 + bx + c + eps
    eps ~ N(0, sig^2)
    '''
    X_train = np.sort(np.random.rand(N))
    X_test  = np.sort(np.random.rand(Ntest))
    Y_train = a*X_train**2+b*X_train+c+np.random.randn(N)*sig
    Y_test  = a*X_test**2 +b*X_test +c+np.random.randn(Ntest)*sig
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = gen_data_poly2(10, -10, 5, 0.1, N=100, Ntest=100)
plt.figure()
plt.plot(X_train, Y_train)
plt.show()

# %%
def make_mat_poly_biais(X): # fonctionne pour un vecteur unidimensionel X
    N = len(X)
    tmp = np.hstack((X.reshape(N,1)**2,(X.reshape(N,1)))) # X**2, X
    return np.hstack((tmp, np.ones((N,1)))) # X**2, X, 1

Xe   = make_mat_poly_biais(X_train)
Xe_t = make_mat_poly_biais(X_test) 
A = Xe.T @ Xe
B = Xe.T @ Y_train
w = np.linalg.solve(A,B)

A_t = Xe_t.T @ Xe_t
B_t = Xe_t.T @ Y_test
w_t = np.linalg.solve(A_t,B_t)

print(w)

yhat   = X_train**2 * w[0]   + X_train * w[1]   + w[2]
yhat_t = X_test**2  * w_t[0] + X_test  * w_t[1] + w_t[2]
print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):', erreur_mc(yhat_t, Y_test))

plt.figure()
plt.plot(X_train, Y_train, 'b.')
plt.plot(X_train, yhat, 'r')
plt.show()
# Out:
# [ 9.95592204 -9.93507065  4.96774383]
# Erreur moyenne au sens des moindres carrés (train): 0.009774467979771304
# Erreur moyenne au sens des moindres carrés (test): 0.008696411040869474

# %% [markdown]
# # Fonction de coût & optimisation par descente de gradient
#
# Comme vu en TD et en cours, nous allons maintenant résoudre le problème de la régression par minimisation d'une fonction de coût:
# $$ C = \sum_{i=1}^N (y_i - f(x_i))$$
#
# Soit un problème avec des données $(x_i,y_i)_{i=1,\ldots,N}$, une fonction de décision/prédiction paramétrée par un vecteur $w$ et une fonction de cout à optimiser $C(w)$.
# Notre but est de trouver les paramètres $w^\star$ minimisant la fonction de coût:
# $$ w^\star = \arg\min_w C(w)$$
#
# l'algorithme de la descente de gradient est le suivant (rappel):
#
#  - $w_0 \leftarrow init$ par exemple : 0
#  - boucle
#      - $w_{t+1} \leftarrow w_{t} - \epsilon \nabla_w C(w_t)$
#
# Compléter le squelette d'implémentation fourni ci-dessous:

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)

# pour travailler en matrice: (re)construction de la matrice contenant les X et un biais
Xe = make_mat_lin_biais(X_train) # dataset linéaire, transformation lineaire des données
wstar = np.linalg.solve(Xe.T @ Xe, Xe.T @ Y_train)

def descente_grad_mc(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for i in range(nIterations):
        if i%(nIterations/10)==0:
            print(i*100/nIterations,"%")
        w = w - eps * 2 * X.T @ (X @ w - y)
        allw.append(w) # stockage de toutes les valeurs intermédiaires pour analyse
    allw = np.array(allw)
    return w, allw # la dernière valeur (meilleure) + tout l'historique pour le plot
    
w, allw = descente_grad_mc(Xe, Y_train, eps=1e-4, nIterations=10000)
print(wstar)
print(w)
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# [ 5.69711447 -0.82299352]
# [ 5.69710132 -0.82298686]

# %% [markdown]
# On s'intéresse ensuite à comprendre la descente de gradient dans l'espace des paramètres. Le code ci-dessous permet de tracer le cout pour un ensemble de paramètres (toutes les valeurs de paramètres prises par l'algorithmes au fil du temps).

# %%
# tracer de l'espace des couts
def plot_parametres( allw, X, y, opti = [], ngrid = 20, extract_bornes=False):
    '''
    Fonction de tracer d'un historique de coefficients
    ATTENTION: ca ne marche qu'en 2D (évidemment)
    Chaque w doit contenir 2 valeurs
    
    Il faut fournir les données (X,y) pour calculer le cout associé 
    à un jeu de paramètres w
    ATTENTION X = forme matricielle des données
    '''
    w_min = [-0.5, -2] # bornes par défaut, uniquement pour notre cas d'usage
    w_max = [8, 5]
    if extract_bornes: # bornes générales
        w_min = np.min(allw,0) # trouver les bornes
        w_max = np.max(allw,0)
    # faire une grille régulière avec tous les couples possibles entre le min et le max
    w1range = np.linspace(w_min[0], w_max[0], ngrid)
    w2range = np.linspace(w_min[1], w_max[1], ngrid)
    w1,w2 = np.meshgrid(w1range,w2range)
    # calcul de tous les couts associés à tous les couples de paramètres
    cost = np.array([[np.log(((X @ np.array([w1i,w2j])-y)**2).sum()) for w1i in w1range] for w2j in w2range])
    plt.figure()
    plt.contour(w1, w2, cost)
    if len(opti) > 0:
        plt.scatter(wstar[0], wstar[1],c='r')
    plt.plot(allw[:,0],allw[:,1],'b+-' ,lw=2 )
    return
    
plot_parametres(allw, Xe, Y_train, opti=wstar)
# plt.savefig('fig/grad_descente.png')

# %% [markdown]
# Vous devez obtenir un image de la forme :<br>
# ![Descente de gradient](fig/grad_descente.png)
#
# Tester différents jeux de paramètres pour mettre en évidence les phénomènes suivants:
#  - Divergence du gradient
#  - Convergence incomplète (trop lente ou pas assez d'itération)
#  - Convergence idéale: pas de gradient suffisamment grand et nombre d'itérations bien choisi

# %% [markdown]
# # Passage sur des données réelles
#
# Après avoir étudié trois manières de faire face au problème de la régression, nous proposons d'étudier un cas réel: la prédiction de la consommation des voitures en fonction de leurs caractéristiques.
#
# Dans le cas présent, nous allons baser la solution sur la résolution analytique du problème des moindres carrés (`np.linalg.solve(A,B)`), qui semble la mieux adaptée au problème qui nous intéresse.
#
# Le jeu de données est issu des datasets UCI, un répertoire parmi les plus connus en machine learning. Les données **sont déjà téléchargées et présentes dans le tme** mais vous voulez plus d'informations:
# https://archive.ics.uci.edu/ml/datasets/auto+mpg
#
# ![voiture](fig/Large9.jpg)
#
# Après avoir importé les données (fonction fournie), vous construirez une solution optimale et l'évaluerez au sens des moindres carrés en apprentissage et en test.

# %%
import pandas as pd
# Chargement des données
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) # comme np.loadtxt mais en plus robuste
# remplacement des données manquantes '?' => Nan pour travailler sur des nombres
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
# remplacement des valeurs manquantes par la moyenne
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())

print(data.head()) # visualiser ce qu'il y a dans les données

X = np.array(data.values[:,1:-2], dtype=np.float64)
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
# separation app/test
def separation_train_test(X, y, pc_train=0.75):
    napp = int(len(y)*pc_train) # nb de points pour le train
    X_train, Y_train = X[:napp], y[:napp]
    X_test, Y_test   = X[napp:], y[napp:]
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)

# %% [markdown]
# # Resolution analytique

# %%
def make_mat_lin_biais(X):
    N = X.shape[0]
    return np.hstack((X,np.ones((N,1)))) # ax + by + cz + ... + g ? ou ax² + by ... + g ?
    
def compute_yhat(X, w):
    res = w[0]
    N = X.shape[1]
    for i in range(1, N):
        res += X[:,i] * w[i]
    return res

def compute_w(X, y, linear):
    if(linear):
        Xe = make_mat_lin_biais(X)
    else:
        Xe = X
    A  = Xe.T @ Xe
    B  = Xe.T @ y
    w  = np.linalg.solve(A,B)
    return w
     
w   = compute_w(X_train, Y_train, linear=False)
w_t = compute_w(X_test , Y_test , linear=False)

print(w)

yhat   = compute_yhat(X_train, w)
yhat_t = compute_yhat(X_test , w_t)

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):',  erreur_mc(yhat_t, Y_test))
# Out:
# [-0.362168    0.00073902  0.00268987 -0.00563114 -0.01289395  0.54066773]
# Erreur moyenne au sens des moindres carrés (train): 10.661281449323736
# Erreur moyenne au sens des moindres carrés (test): 40.23068275181207

# %%
def plot_y(Y_train, Y_test, yhat, yhat_t):
    # tracé des prédictions:
    plt.figure()
    plt.subplot(211)
    plt.plot(Y_test, label="GT")
    plt.plot(yhat_t, label="pred")
    plt.title('En test')
    plt.legend()
    plt.subplot(212)
    plt.plot(Y_train, label="GT")
    plt.plot(yhat, label="pred")
    plt.title('En train')
    return

plot_y(Y_train, Y_test, yhat, yhat_t)

# %%
# interprétation des poids
plt.figure()
plt.bar(np.arange(len(w)), w)
plt.show()

# %% [markdown]
# # Résolution avec descente de gradient

# %%
def train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100, norm=False, grad="normal"):
                
        if norm:
            Xn_train, Xn_test = normalisation(X_train, X_test)
        else:
            Xn_train, Xn_test = X_train, X_test
        
        Xe_train = make_mat_lin_biais(Xn_train)
        Xe_test  = make_mat_lin_biais(Xn_test)
        
        if grad == "normal":
            w, _ = descente_grad_mc(Xe_train, Y_train, eps, nIterations)
        elif grad == "stoch":
            w, _ = descente_grad_mc_stoch(Xe_train, Y_train, eps, nIterations)
        elif grad == "momentum":
            w, _ = descente_grad_mc_stoch_mom(Xe_train, Y_train, eps, 0.9, nIterations)
        elif grad == "batch":
            w, _ = descente_grad_mc_stoch_batch(Xe_train, Y_train, eps, 20, nIterations)
        else:
            print("Pas de gradient ?")
                
        yhat   = Xe_train @ w
        yhat_t = Xe_test @ w

        print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
        print('Erreur moyenne au sens des moindres carrés (test):' , erreur_mc(yhat_t, Y_test))
        
        plot_y(Y_train, Y_test, yhat, yhat_t)
        
        plt.figure()
        plt.bar(np.arange(len(w)), w)
        plt.show()

# %%
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
train(X_train, X_test, Y_train, Y_test, eps=1e-6, nIterations=10, norm=False) # Gradient vanishing car pas de normalisation !
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 3.868530276071835e+78
# Erreur moyenne au sens des moindres carrés (test): 2.345811916660169e+78

# %% [markdown]
# ## Normalisation
#
# Sur le diagramme ci-dessus, on ne voit pas grand chose pour une raison évidente: on ne peut pas comparer ces poids qui comparent des variables dont les ordres de grandeur sont différents.
#
# Nous allons donc assimiler chaque colonne $X_j$ à une variable suivant une loi normale et nous allons revenir à une Normale centrée réduite selon la formule de base:
#
# $$X_j \sim \mathcal N(\mu_j, \sigma_j^2) $$
# $$\Rightarrow Z_j = \frac{X_j - \mu_j}{\sigma_j} \sim \mathcal N(0, 1) $$
#
# Tous les $Z_j$ sont comparables et nous seront en mesure de comprendre l'impact de chaque variables sur les résultats.
#
# **ATTENTION:** on ne se basera que sur les données d'apprentissage pour le calcul des $\{\mu_j, \sigma_j\}$.
#
# Une fois la normalisation effectuée, analyser l'impact des différentes variables descriptives sur la valeur à prédire.

# %%
def normalisation(X_train, X_test):
    '''
    Fonction de normalisation des données pour rendre les colonnes comparables
    Chaque variable sera assimilée à une loi normale qu'il faut centrer + réduire.
    ATTENTION: il faut calculer les moyennes et écarts-types sur les données d'apprentissage seulement
    '''
    stds     = X_train.std(axis=0)
    means    = X_train.mean(axis=0)
    stds_t   = X_test.std(axis=0)
    means_t  = X_test.mean(axis=0)
    Xn_train = (X_train - means)   / stds**2
    Xn_test  = (X_test  - means_t) / stds_t**2
    Xn_train = np.hstack((Xn_train, np.ones((Xn_train.shape[0], 1))))
    Xn_test  = np.hstack((Xn_test,  np.ones((Xn_test.shape [0], 1))))
    return Xn_train, Xn_test

Xn_train, Xn_test = normalisation(X_train, X_test)

w   = compute_w(Xn_train, Y_train, linear=False)
w_t = compute_w(Xn_test , Y_test , linear=False)

yhat   = compute_yhat(Xn_train, w  )
yhat_t = compute_yhat(Xn_test , w_t)

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):',  erreur_mc(yhat_t, Y_test))

plot_y(Y_train, Y_test, yhat, yhat_t)

plt.figure()
plt.bar(np.arange(len(w)), w)
plt.show()
# Out:
# Erreur moyenne au sens des moindres carrés (train): 9.197411943240763
# Erreur moyenne au sens des moindres carrés (test): 14.700511217891421

# %%
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=True) # Pourquoi un meilleur test que train ? Pourquoi besoin d'autant d'iterations ?
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 10.005814220020042
# Erreur moyenne au sens des moindres carrés (test): 206.60932167594717

# %%
X_train.shape
# Out:
# (298, 6)

# %% [markdown]
# # Questions d'ouverture
#
# ## Sélection de caractéristiques
#
# Quels sont les résultats obtenus en éliminant toutes les variables servent moins?
#
# ## Feature engineering
#
# En étudiant la signification des variables du problèmes, on trouve:
#
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
#
# D'après la question précédente, le poids, l'année du modèle et le biais sont des facteurs important pour le calcul de la consommation... Jusqu'ici, nous n'avons pas pris en compte l'origine qui était difficile à coder.
#
# ### Encodage de l'origine
#
# La variable origine est accessible de la manière suivante:
#
# ```
#   origine = data.values[:,-2]
# ```
# Il faut le faire au début du traitement pour bien conserver la séparation en l'apprentissage et le test.
#
# Au moins les deux derniers facteurs discrets pourraient être traités différemment en one-hot encoding:
# $$X_j = x \in \{1, \ldots, K\} \Rightarrow [0, 0, 1, 0] \in \{0, 1\}^K$$
#
# La valeur $x$ donne l'index de la colonne non nulle.
#
# ### Encodage de l'année
#
# Pour l'année, il est possible de procéder de la même manière, mais il préférable de découper les années en 10 catégories puis d'encoder pour limiter le nombre de dimensions.

# %%
# SAVE
# def encode_discrete_values(X, index):
#     Xcollone=0
#     for idx in index:
#         Xi = one_hot_encoding(X[:,idx])
#         #print(Xi.shape)
#         Xcollone+=Xi.shape[1]
#    # print(Xcollone)
#     newX=np.zeros([X.shape[0],X.shape[1]+Xcollone])

#     for i in range(X.shape[0]):
#         for j in range(X.shape[1]):
#             if j  not in index:
#                 newX[i][j]=X[i][j]
#     n=0
#     indexencode=[]
#     for i in index:
#         newX = np.delete(newX, i-n, axis=1)
#         n+=1
#     indexdep=X.shape[1]-n
#     for w in index:
#         Xw= one_hot_encoding(X[:,w])

#         for i in range(newX.shape[0]):
#             n=0

#             for j in range(indexdep,indexdep+Xw.shape[1]-1):
#                 newX[i][j]=Xw[i][0+n-1]
#                 if j not in indexencode:
#                     indexencode.append(j)
#         indexdep=indexdep+Xw.shape[1]
#               # Comment faire pour le probleme de shape ? Pointeur sur tableau one hot ?
#     return newX , indexencode
# def normalisation2(X_train, X_test,v):
#     '''
#     Fonction de normalisation des données pour rendre les colonnes comparables
#     Chaque variable sera assimilée à une loi normale qu'il faut centrer + réduire.
#     ATTENTION: il faut calculer les moyennes et écarts-types sur les données d'apprentissage seulement
#     '''

#     stds     = X_train[0:v[0]].std(axis=0)
#     means    = X_train[0:v[0]].mean(axis=0)
#     stds_t   = X_test[0:v[0]].std(axis=0)
#     means_t  = X_test[0:v[0]].mean(axis=0)
#     Xn_train = (X_train[0:v[0]] - means)   / stds2
#     Xn_test  = (X_test[0:v[0]]  - means_t) / stds_t2
#     Xn_train = np.hstack((Xn_train[0:v[0]], np.ones((Xn_train.shape[0], 1))))
#     Xn_test  = np.hstack((Xn_test[0:v[0]],  np.ones((Xn_test.shape [0], 1))))
#     return Xn_train, Xn_test
# def train2(X_train, X_test, Y_train, Y_test, v,eps=1e-4, nIterations=100, norm=False, grad="normal"):

#         if norm:
#             Xn_train, Xn_test = normalisation2(X_train, X_test,v)
#         else:
#             Xn_train, Xn_test = X_train, X_test

#         Xe_train = make_mat_lin_biais(Xn_train)
#         Xe_test  = make_mat_lin_biais(Xntest)

#         if grad == "normal":
#             w  ,  = descente_grad_mc(Xe_train, Y_train, eps, nIterations)
#         elif grad == "stoch":
#             w = descente_grad_mc_stoch(Xe_train, Y_train, eps, nIterations)
#         elif grad =="momentum":
#             w = descente_grad_mc_stoch_mom(Xe_train, Y_train, eps, nIterations)

#         yhat   = Xe_train @ w
#         yhat_t = Xe_test @ w

#         print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
#         print('Erreur moyenne au sens des moindres carrés (test):' , erreur_mc(yhat_t, Y_test))

#         plot_y(Y_train, Y_test, yhat, yhat_t)

#         plt.figure()
#         plt.bar(np.arange(len(w)), w)
#         plt.show()

# %%
# Rechargement des donnees
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) 
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())
print(data.head())

X = np.array(data.values[:,:-1], dtype=np.float64) # Cette fois on prend toutes les valeurs
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
# Index suivant le type de variable
discrete_values_index = np.array([1, 7])
date_values_index = np.array([6])
continuous_values_index = np.array([0, 2, 3, 4, 5])

# %%
# Traitement des variables discrete :
def one_hot_encoding(array):
    n = len(array)
    unique_values = np.unique(array)
    n_unique = len(unique_values)
    dic = {}
    for i in range(n_unique):
        dic[unique_values[i]] = i
    res = np.zeros((n, n_unique))
    for i in range(n):
        res[i][dic[array[i]]] = 1
    return res

def encode_discrete_values(X, index):
    for idx in index:
        X[:,idx] = one_hot_encoding(X[:,idx]) # Comment faire pour le probleme de shape ? Pointeur sur tableau one hot ?
    return X                                  # Ou on remplace juste les valeurs dans les colonnes par les index ?
                                              # Il faut ajouter des colonnes en nombre de categorie pour le one hot encode

# print(X[:5,1])
# X = encode_discrete_values(X, discrete_values_index)
# print(X[:5,1])

# %%
# Traitement de la variable date :
def discretize_years(array, n, index):
    array = np.sort(array)
    size = len(array)
    cpt = 0
    n_interval = size//n
    for i in range(1, size+1):
        array[i-1] = cpt
        if i%n_interval == 0:
            cpt += 1
    array = array.reshape(-1)
    X[:,index[0]] = array
    return X

# print(X[:,date_values_index])
X = discretize_years(X[:,date_values_index], 10, date_values_index)
# print(X[:,date_values_index])

# %%
### Test avec toutes les features continues+discretes :
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
# 9. car name: string (unique for each instance)

X = np.array(data.values[:,:-1], dtype=np.float64)
# X = discretize_years(X[:,date_values_index], 10, date_values_index)
# X = encode_discrete_values(X, discrete_values_index)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
# train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=True)
# Out:
# (298, 8)

# %%
### Test avec toutes les features continues :
# 1. mpg: continuous
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous

index_to_delete = np.concatenate((discrete_values_index, date_values_index))
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=True)
# Out:
# (298, 5)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 0.00043928460776516536
# Erreur moyenne au sens des moindres carrés (test): 119.8142710949402

# %%
### Test avec seulement les features :
# 3. displacement: continuous
# 4. horsepower: continuous
# 6. acceleration: continuous

index_to_delete = [0, 1, 4, 6, 7]
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=True)
# Out:
# (298, 3)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 11.92692667411723
# Erreur moyenne au sens des moindres carrés (test): 197.7028422165873

# %% [markdown]
# # Question d'ouverture sur le gradient
#
# ## La normalisation a-t-elle un impact sur le gradient?
#
# La normalisation des données peut au moins nous aider à régler plus facilement le pas (qui sera toujours du même ordre de grandeur... Mais cela a-t-il un impact sur la manière dont nous nous rapprochons de la solution optimale?
#
# ## Gradient stochastique
#
# Dans la plupart des algorithmes modernes d'optimisation liés aux réseaux de neurones, le gradient est calculé de manière stochastique, sur un exemple à la fois:
#
# - $w_0 \leftarrow init$ par exemple : 0
# - boucle
#      - tirage d'une donnée $i$: $(x_i,y_i)$
#      - $w_{t+1} \leftarrow w_{t} - \epsilon \nabla_w C_i(w)$
#
#
# Etudier le fonctionnement de cet algorithme sur les exemples jouets précédents.
#
# ## Amélioration du gradient
#
# Le blog de S. Ruder explique particulièrement bien les améliorations possibles sur les descentes de gradient.
#
# https://ruder.io/optimizing-gradient-descent/
#
# Comparer une descente de gradient stochastique avec et sans moment sur les données jouets des premières questions.

# %%
### Impact de la normalisation :
# La normalisation des données permet de ne pas avoir un gradient qui tend vers 0 ou vers de très grands nombres.
# Lors de la descente de gradient, si notre gradient prend des valeurs énormes, on pourrait rater un minimum local interessant.
# Dans le cas contraire, si le gradient prend des valeurs trop petite, on finit par avoir une perte d'information.

# %%
### Gradient stochastique :
def make_mat_lin_biais(X): # Redefinition de la fonction
    N = len(X)
    return np.hstack((X.reshape(N,1),np.ones((N,1))))

X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

# Gradient classique :
def descente_grad_mc(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for _ in range(nIterations):
        w = w - eps * 2 * X.T @ (X @ w - y)
        allw.append(w) # stockage de toutes les valeurs intermédiaires pour analyse
    allw = np.array(allw)
    return w, allw # la dernière valeur (meilleure) + tout l'historique pour le plot
    
w, allw = descente_grad_mc(Xe, Y_train, eps=1e-4, nIterations=100_000)
print(w)

plot_parametres(allw, Xe, Y_train, opti=wstar)

# Gradient stochastique :
def descente_grad_mc_stoch(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for _ in range(nIterations):
        rand = np.random.randint(X.shape[0])
        w = w - eps * 2 * X.T[:,rand] * (X[rand] @ w - y[rand])
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s, allw_s = descente_grad_mc_stoch(Xe, Y_train, eps=0.1, nIterations=1_000)
print(w_s)

plot_parametres(allw_s, Xe, Y_train, opti=wstar)

# Train avec gradient normal :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="normal")
# Train avec gradient stochastique :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Out:
# [ 6.00484591 -0.96114273]
# [ 5.88037577 -0.871372  ]
# Erreur moyenne au sens des moindres carrés (train): 0.13455389291838882
# Erreur moyenne au sens des moindres carrés (test): 0.1667602351127462
# Erreur moyenne au sens des moindres carrés (train): 0.28491348946439543
# Erreur moyenne au sens des moindres carrés (test): 0.3140018232906143

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

### Amelioration du gradient :
# Gradient stochastique avec moment :
def descente_grad_mc_stoch_mom(X, y, eps=1e-4, gamma=0.9, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    value = w
    allw = [w]
    for i in range(nIterations):
        rand = np.random.randint(X.shape[0])
        gradient = eps * 2 * X.T[:,rand] * (X[rand] @ w - y[rand])
        new_value = (1-gamma) * gradient + gamma * value
        w = w - new_value
        value = new_value
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s_m, allw_s_m = descente_grad_mc_stoch_mom(Xe, Y_train, eps=0.1, nIterations=1_000)
print(w_s_m)

plot_parametres(allw_s_m, Xe, Y_train, opti=wstar)

# Train avec gradient sans moment :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Train avec gradient avec moment :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="momentum")
# Out:
# [ 5.89369299 -1.04096332]
# Erreur moyenne au sens des moindres carrés (train): 0.38530585589112365
# Erreur moyenne au sens des moindres carrés (test): 0.44070512590860983
# Erreur moyenne au sens des moindres carrés (train): 0.38348532976220007
# Erreur moyenne au sens des moindres carrés (test): 0.4375871336301998

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

### Amelioration du gradient :
# Gradient stochastique avec minibatch :
def descente_grad_mc_stoch_batch(X, y, eps=1e-4, n_batch=20, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    value = w
    allw = [w]
    for i in range(nIterations):
        rand = np.random.randint(X.shape[0]) - n_batch
        batch = X[rand:rand+n_batch]
        batch_t = batch.T
        batch_y = y[rand:rand+n_batch]
        gradient = eps * 2 * batch_t @ (batch @ w - batch_y)
        w = w - gradient
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s_b, allw_s_b = descente_grad_mc_stoch_batch(Xe, Y_train, eps=0.01, n_batch=20, nIterations=1_000)
print(w_s_b)

plot_parametres(allw_s_b, Xe, Y_train, opti=wstar)

# Train avec gradient stoch :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Train avec gradient avec batch :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="batch")
# Out:
# [ 5.80167264 -0.93691502]
# Erreur moyenne au sens des moindres carrés (train): 0.24104673534329343
# Erreur moyenne au sens des moindres carrés (test): 0.3320036769506795
# Erreur moyenne au sens des moindres carrés (train): 0.09923539072107673
# Erreur moyenne au sens des moindres carrés (test): 0.17928633389749218

# %% [markdown]
# # Exercice supplémentaire : regression avec multi layer perceptron

# %%
import tensorflow as tf

# %%
# Rechargement des donnees
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) 
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())
print(data.head())

X = np.array(data.values[:,:-1], dtype=np.float64)
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
index_to_delete = np.concatenate((discrete_values_index, date_values_index))
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)

# %%
TEST_SPLIT = 0.25
N_FEATURES = X.shape[1]
EPOCHS = 20
NB_NEURONS = 32
DROPOUT_VALUE = 0.3

# %%
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=1-TEST_SPLIT)
print(X_train.shape)
# Out:
# (298, 5)

# %%
def norm(X):
    n,m = X.shape
    for i in range(n):
        for j in range(m):
            X[i][j] = (X[i][j] - X[:,j].min()) / (X[:,j].max() - X[:,j].min())
    return X

X_train_unnorm = X_train.copy()
X_test_unnorm = X_test.copy()

print(X_train.mean(axis=0))
X_train = norm(X_train)
X_test = norm(X_test)
print(X_train.mean(axis=0))
# Out:
# [  20.77013423  214.49832215  111.96979866 3130.23489933   15.22315436]
# [0.4993601  0.52790678 0.57298831 0.6737239  0.69030311]

# %% [markdown]
# # Descente de gradient stochastique

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
#     model.add(tf.keras.layers.Dropout(DROPOUT_VALUE)) # Dropout pour eviter overfit
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="sgd", metrics=["mean_squared_error"]) # Fonction de loss moindre carres et optimisation par descente de gradient
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 65ms/step - loss: 355.8544 - mean_squared_error: 355.8544 - val_loss: 641.2018 - val_mean_squared_error: 641.2018
# Epoch 2/20
# 10/10 [==============================] - 0s 4ms/step - loss: 335.9579 - mean_squared_error: 335.9579 - val_loss: 776.5944 - val_mean_squared_error: 776.5944
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 258.4712 - mean_squared_error: 258.4712 - val_loss: 377.8129 - val_mean_squared_error: 377.8129
# Epoch 4/20
# 10/10 [==============================] - 0s 4ms/step - loss: 106.0301 - mean_squared_error: 106.0301 - val_loss: 62.5496 - val_mean_squared_error: 62.5496
# Epoch 5/20
# 10/10 [==============================] - 0s 4ms/step - loss: 78.7990 - mean_squared_error: 78.7990 - val_loss: 109.1398 - val_mean_squared_error: 109.1398
# Epoch 6/20
# 10/10 [==============================] - 0s 4ms/step - loss: 28.4508 - mean_squared_error: 28.4508 - val_loss: 170.5025 - val_mean_squared_error: 170.5025
# Epoch 7/20
# 10/10 [==============================] - 0s 4ms/step - loss: 24.4762 - mean_squared_error: 24.4762 - val_loss: 143.4303 - val_mean_squared_error: 143.4303
# Epoch 8/20
# 10/10 [==============================] - 0s 4ms/step - loss: 29.1586 - mean_squared_error: 29.1586 - val_loss: 109.9438 - val_mean_squared_error: 109.9438
# Epoch 9/20
# 10/10 [==============================] - 0s 4ms/step - loss: 7.3145 - mean_squared_error: 7.3145 - val_loss: 38.8177 - val_mean_squared_error: 38.8177
# Epoch 10/20
# 10/10 [==============================] - 0s 4ms/step - loss: 6.6982 - mean_squared_error: 6.6982 - val_loss: 49.4383 - val_mean_squared_error: 49.4383
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 15.9816 - mean_squared_error: 15.9816 - val_loss: 33.0291 - val_mean_squared_error: 33.0291
# Epoch 12/20
# 10/10 [==============================] - 0s 4ms/step - loss: 11.0171 - mean_squared_error: 11.0171 - val_loss: 77.9967 - val_mean_squared_error: 77.9967
# Epoch 13/20
# 10/10 [==============================] - 0s 4ms/step - loss: 8.3505 - mean_squared_error: 8.3505 - val_loss: 89.0375 - val_mean_squared_error: 89.0375
# Epoch 14/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8927 - mean_squared_error: 3.8927 - val_loss: 97.7534 - val_mean_squared_error: 97.7534
# Epoch 15/20
# 10/10 [==============================] - 0s 4ms/step - loss: 7.2835 - mean_squared_error: 7.2835 - val_loss: 153.4431 - val_mean_squared_error: 153.4431
# Epoch 16/20
# 10/10 [==============================] - 0s 4ms/step - loss: 7.8080 - mean_squared_error: 7.8080 - val_loss: 30.0603 - val_mean_squared_error: 30.0603
# Epoch 17/20
# 10/10 [==============================] - 0s 4ms/step - loss: 7.7682 - mean_squared_error: 7.7682 - val_loss: 20.1677 - val_mean_squared_error: 20.1677
# Epoch 18/20
# 10/10 [==============================] - 0s 4ms/step - loss: 9.8151 - mean_squared_error: 9.8151 - val_loss: 32.8612 - val_mean_squared_error: 32.8612
# Epoch 19/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.5231 - mean_squared_error: 4.5231 - val_loss: 87.4899 - val_mean_squared_error: 87.4899
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2548 - mean_squared_error: 4.2548 - val_loss: 137.1008 - val_mean_squared_error: 137.1008

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
sample=10
predictions = model.predict([X_test])
print("Valeurs en entree normalisees:\n", X_test[:sample])
print("Valeurs en entree non-normalisees:\n", X_test_unnorm[:sample])
print("Valeurs reelle en sortie:\n", Y_test[:sample])
print("Valeurs predit en sortie:\n", predictions[:sample])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test[:sample], predictions[:sample])))
# Out:
# Valeurs en entree normalisees:
#  [[0.1862069  1.         0.91666667 1.         0.45185185]
#  [0.5820208  0.40114613 0.53464717 0.85633727 1.        ]
#  [0.51092125 0.74256209 0.68052419 0.91810198 0.9006135 ]
#  [0.73283804 0.29919679 0.52839285 0.59050989 0.52791411]
#  [0.73930163 0.29940109 0.52841529 0.57711417 0.59831288]
#  [0.68112927 0.24220935 0.49038426 0.54221095 0.77638037]
#  [0.79962853 0.25948755 0.52094758 0.57174974 0.59003067]
#  [0.60787519 0.43103483 0.68063172 0.71673729 0.64386503]
#  [0.61649331 0.4939355  0.87073189 0.69660013 0.44923313]
#  [0.57340267 0.4939355  0.87073189 0.72479216 0.51554333]]
# Valeurs en entree non-normalisees:
#  [[  23.   350.   125.  3900.    17.4]
#  [  27.2  141.    71.  3190.    24.8]
#  [  23.9  260.    90.  3420.    22.2]
#  [  34.2  105.    70.  2200.    13.2]
#  [  34.5  105.    70.  2150.    14.9]
#  [  31.8   85.    65.  2020.    19.2]
#  [  37.3   91.    69.  2130.    14.7]
#  [  28.4  151.    90.  2670.    16. ]
#  [  28.8  173.   115.  2595.    11.3]
#  [  26.8  173.   115.  2700.    12.9]]
# Valeurs reelle en sortie:
#  [23.  27.2 23.9 34.2 34.5 31.8 37.3 28.4 28.8 26.8]
# Valeurs predit en sortie:
#  [[ 8.394167]
#  [17.921389]
#  [14.631865]
#  [22.397638]
#  [22.676964]
#  [22.518238]
#  [24.079643]
#  [18.454718]
#  [17.929451]
#  [17.142792]]
# Valeur d'erreur moyenne:
#  12.668798445628271

# %% [markdown]
# # Adam

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
#     model.add(tf.keras.layers.Dropout(DROPOUT_VALUE)) # Dropout pour eviter overfit
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="adam", metrics=["mean_squared_error"]) # Fonction de loss moindre carres et optimisation par descente de gradient
    model.summary()
    return model

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 0s 7ms/step - loss: 4.1935 - mean_squared_error: 4.1935 - val_loss: 29.5158 - val_mean_squared_error: 29.5158
# Epoch 2/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.6478 - mean_squared_error: 5.6478 - val_loss: 27.0233 - val_mean_squared_error: 27.0233
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.0818 - mean_squared_error: 5.0818 - val_loss: 16.6721 - val_mean_squared_error: 16.6721
# Epoch 4/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.0188 - mean_squared_error: 5.0188 - val_loss: 20.6109 - val_mean_squared_error: 20.6109
# Epoch 5/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3538 - mean_squared_error: 4.3538 - val_loss: 21.9224 - val_mean_squared_error: 21.9224
# Epoch 6/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.9162 - mean_squared_error: 4.9162 - val_loss: 47.9420 - val_mean_squared_error: 47.9420
# Epoch 7/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9155 - mean_squared_error: 2.9155 - val_loss: 25.6277 - val_mean_squared_error: 25.6277
# Epoch 8/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.4644 - mean_squared_error: 5.4644 - val_loss: 38.7021 - val_mean_squared_error: 38.7021
# Epoch 9/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5328 - mean_squared_error: 2.5328 - val_loss: 79.6853 - val_mean_squared_error: 79.6853
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 8.7420 - mean_squared_error: 8.7420 - val_loss: 47.8234 - val_mean_squared_error: 47.8234
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9989 - mean_squared_error: 1.9989 - val_loss: 31.2215 - val_mean_squared_error: 31.2215
# Epoch 12/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3015 - mean_squared_error: 2.3015 - val_loss: 41.7388 - val_mean_squared_error: 41.7388
# Epoch 13/20
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9191 - mean_squared_error: 1.9191 - val_loss: 41.7682 - val_mean_squared_error: 41.7682
# Epoch 14/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1939 - mean_squared_error: 2.1939 - val_loss: 28.5069 - val_mean_squared_error: 28.5069
# Epoch 15/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5005 - mean_squared_error: 2.5005 - val_loss: 57.2733 - val_mean_squared_error: 57.2733
# Epoch 16/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2714 - mean_squared_error: 4.2714 - val_loss: 48.0888 - val_mean_squared_error: 48.0888
# Epoch 17/20
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7606 - mean_squared_error: 1.7606 - val_loss: 48.2930 - val_mean_squared_error: 48.2930
# Epoch 18/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0863 - mean_squared_error: 2.0863 - val_loss: 47.8490 - val_mean_squared_error: 47.8490
# Epoch 19/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9455 - mean_squared_error: 3.9455 - val_loss: 22.2592 - val_mean_squared_error: 22.2592
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8920 - mean_squared_error: 3.8920 - val_loss: 40.3844 - val_mean_squared_error: 40.3844

# %%
# Check prediction
sample=10
predictions = model.predict([X_test])
print("Valeurs en entree normalisees:\n", X_test[:sample])
print("Valeurs en entree non-normalisees:\n", X_test_unnorm[:sample])
print("Valeurs reelle en sortie:\n", Y_test[:sample])
print("Valeurs predit en sortie:\n", predictions[:sample])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test[:sample], predictions[:sample])))
# Out:
# Valeurs en entree normalisees:
#  [[0.1862069  1.         0.91666667 1.         0.45185185]
#  [0.5820208  0.40114613 0.53464717 0.85633727 1.        ]
#  [0.51092125 0.74256209 0.68052419 0.91810198 0.9006135 ]
#  [0.73283804 0.29919679 0.52839285 0.59050989 0.52791411]
#  [0.73930163 0.29940109 0.52841529 0.57711417 0.59831288]
#  [0.68112927 0.24220935 0.49038426 0.54221095 0.77638037]
#  [0.79962853 0.25948755 0.52094758 0.57174974 0.59003067]
#  [0.60787519 0.43103483 0.68063172 0.71673729 0.64386503]
#  [0.61649331 0.4939355  0.87073189 0.69660013 0.44923313]
#  [0.57340267 0.4939355  0.87073189 0.72479216 0.51554333]]
# Valeurs en entree non-normalisees:
#  [[  23.   350.   125.  3900.    17.4]
#  [  27.2  141.    71.  3190.    24.8]
#  [  23.9  260.    90.  3420.    22.2]
#  [  34.2  105.    70.  2200.    13.2]
#  [  34.5  105.    70.  2150.    14.9]
#  [  31.8   85.    65.  2020.    19.2]
#  [  37.3   91.    69.  2130.    14.7]
#  [  28.4  151.    90.  2670.    16. ]
#  [  28.8  173.   115.  2595.    11.3]
#  [  26.8  173.   115.  2700.    12.9]]
# Valeurs reelle en sortie:
#  [23.  27.2 23.9 34.2 34.5 31.8 37.3 28.4 28.8 26.8]
# Valeurs predit en sortie:
#  [[ 9.503419]
#  [20.973051]
#  [17.515793]
#  [28.574783]
#  [28.868107]
#  [27.90456 ]
#  [31.114937]
#  [22.357872]
#  [22.061699]
#  [20.717346]]
# Valeur d'erreur moyenne:
#  10.094349604563154

# %% [markdown]
# # Adam + optimisation learning rate + early stopping

# %%
EPOCHS = 100

# %%
def get_callbacks():   
    reduce_lr = ReduceLROnPlateau(monitor='val_mse', factor=0.75, patience=100, verbose=1, mode="min", min_delta=1e-4, min_lr=1e-6)

    early_stopping = EarlyStopping(monitor="val_loss", patience=100 , verbose=1, mode="min", restore_best_weights=True)
    
#     model_cp = ModelCheckpoint('model.h5', 
#                                  save_best_only = True, 
#                                  save_weights_only = True,
#                                  monitor = 'val_loss', 
#                                  mode = 'min', verbose = 1)
    
#     return [early_stopping, model_cp, reduce_lr]
    return [early_stopping, reduce_lr]

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
#     model.add(tf.keras.layers.Dropout(DROPOUT_VALUE)) # Dropout pour eviter overfit
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="adam", metrics=["mean_squared_error"], callbacks=get_callbacks())
    model.summary()
    return model

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.9437 - mean_squared_error: 1.9437 - val_loss: 63.8123 - val_mean_squared_error: 63.8123
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3344 - mean_squared_error: 4.3344 - val_loss: 39.5080 - val_mean_squared_error: 39.5080
# Epoch 3/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8524 - mean_squared_error: 1.8524 - val_loss: 41.6235 - val_mean_squared_error: 41.6235
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5294 - mean_squared_error: 1.5294 - val_loss: 20.8201 - val_mean_squared_error: 20.8201
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6413 - mean_squared_error: 2.6413 - val_loss: 21.4062 - val_mean_squared_error: 21.4062
# Epoch 6/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0372 - mean_squared_error: 3.0372 - val_loss: 59.7428 - val_mean_squared_error: 59.7428
# Epoch 7/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7872 - mean_squared_error: 1.7872 - val_loss: 22.3337 - val_mean_squared_error: 22.3337
# Epoch 8/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4799 - mean_squared_error: 3.4799 - val_loss: 54.6687 - val_mean_squared_error: 54.6687
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.7554 - mean_squared_error: 1.7554 - val_loss: 33.4831 - val_mean_squared_error: 33.4831
# Epoch 10/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6916 - mean_squared_error: 1.6916 - val_loss: 24.2577 - val_mean_squared_error: 24.2577
# Epoch 11/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1889 - mean_squared_error: 2.1889 - val_loss: 43.7852 - val_mean_squared_error: 43.7852
# Epoch 12/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9545 - mean_squared_error: 1.9545 - val_loss: 30.9256 - val_mean_squared_error: 30.9256
# Epoch 13/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4625 - mean_squared_error: 1.4625 - val_loss: 48.4571 - val_mean_squared_error: 48.4571
# Epoch 14/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.7330 - mean_squared_error: 1.7330 - val_loss: 37.2505 - val_mean_squared_error: 37.2505
# Epoch 15/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1317 - mean_squared_error: 3.1317 - val_loss: 62.7956 - val_mean_squared_error: 62.7956
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.2942 - mean_squared_error: 3.2942 - val_loss: 38.3878 - val_mean_squared_error: 38.3878
# Epoch 17/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8999 - mean_squared_error: 1.8999 - val_loss: 34.6864 - val_mean_squared_error: 34.6864
# Epoch 18/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5346 - mean_squared_error: 1.5346 - val_loss: 55.5516 - val_mean_squared_error: 55.5516
# Epoch 19/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6277 - mean_squared_error: 2.6277 - val_loss: 17.4087 - val_mean_squared_error: 17.4087
# Epoch 20/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3982 - mean_squared_error: 3.3982 - val_loss: 49.5548 - val_mean_squared_error: 49.5548
# Epoch 21/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5194 - mean_squared_error: 2.5194 - val_loss: 36.1974 - val_mean_squared_error: 36.1974
# Epoch 22/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9577 - mean_squared_error: 1.9577 - val_loss: 34.8246 - val_mean_squared_error: 34.8246
# Epoch 23/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3510 - mean_squared_error: 2.3510 - val_loss: 71.6641 - val_mean_squared_error: 71.6641
# Epoch 24/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8768 - mean_squared_error: 3.8768 - val_loss: 47.4706 - val_mean_squared_error: 47.4706
# Epoch 25/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4794 - mean_squared_error: 1.4794 - val_loss: 52.9257 - val_mean_squared_error: 52.9257
# Epoch 26/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9169 - mean_squared_error: 1.9169 - val_loss: 71.7949 - val_mean_squared_error: 71.7949
# Epoch 27/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8449 - mean_squared_error: 1.8449 - val_loss: 39.5761 - val_mean_squared_error: 39.5761
# Epoch 28/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4077 - mean_squared_error: 1.4077 - val_loss: 39.7787 - val_mean_squared_error: 39.7787
# Epoch 29/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3339 - mean_squared_error: 3.3339 - val_loss: 20.3827 - val_mean_squared_error: 20.3827
# Epoch 30/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1376 - mean_squared_error: 3.1376 - val_loss: 29.9709 - val_mean_squared_error: 29.9709
# Epoch 31/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5692 - mean_squared_error: 3.5692 - val_loss: 42.0022 - val_mean_squared_error: 42.0022
# Epoch 32/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9278 - mean_squared_error: 1.9278 - val_loss: 21.3870 - val_mean_squared_error: 21.3870
# Epoch 33/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4651 - mean_squared_error: 2.4651 - val_loss: 56.8186 - val_mean_squared_error: 56.8186
# Epoch 34/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6491 - mean_squared_error: 1.6491 - val_loss: 34.2840 - val_mean_squared_error: 34.2840
# Epoch 35/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4443 - mean_squared_error: 1.4443 - val_loss: 53.1460 - val_mean_squared_error: 53.1460
# Epoch 36/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4619 - mean_squared_error: 1.4619 - val_loss: 49.7117 - val_mean_squared_error: 49.7117
# Epoch 37/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0005 - mean_squared_error: 2.0005 - val_loss: 34.0379 - val_mean_squared_error: 34.0379
# Epoch 38/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7982 - mean_squared_error: 1.7982 - val_loss: 39.0007 - val_mean_squared_error: 39.0007
# Epoch 39/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8433 - mean_squared_error: 1.8433 - val_loss: 45.1882 - val_mean_squared_error: 45.1882
# Epoch 40/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1280 - mean_squared_error: 2.1280 - val_loss: 16.0459 - val_mean_squared_error: 16.0459
# Epoch 41/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8035 - mean_squared_error: 1.8035 - val_loss: 42.7954 - val_mean_squared_error: 42.7954
# Epoch 42/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7247 - mean_squared_error: 1.7247 - val_loss: 41.7719 - val_mean_squared_error: 41.7719
# Epoch 43/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4806 - mean_squared_error: 2.4806 - val_loss: 51.9470 - val_mean_squared_error: 51.9470
# Epoch 44/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0070 - mean_squared_error: 2.0070 - val_loss: 63.9243 - val_mean_squared_error: 63.9243
# Epoch 45/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0976 - mean_squared_error: 2.0976 - val_loss: 38.9758 - val_mean_squared_error: 38.9758
# Epoch 46/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.9994 - mean_squared_error: 1.9994 - val_loss: 35.5397 - val_mean_squared_error: 35.5397
# Epoch 47/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5420 - mean_squared_error: 1.5420 - val_loss: 30.3497 - val_mean_squared_error: 30.3497
# Epoch 48/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3709 - mean_squared_error: 1.3709 - val_loss: 25.0800 - val_mean_squared_error: 25.0800
# Epoch 49/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1449 - mean_squared_error: 3.1449 - val_loss: 27.5305 - val_mean_squared_error: 27.5305
# Epoch 50/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5465 - mean_squared_error: 1.5465 - val_loss: 61.4734 - val_mean_squared_error: 61.4734
# Epoch 51/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9150 - mean_squared_error: 2.9150 - val_loss: 37.2318 - val_mean_squared_error: 37.2318
# Epoch 52/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5859 - mean_squared_error: 1.5859 - val_loss: 28.4216 - val_mean_squared_error: 28.4216
# Epoch 53/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3798 - mean_squared_error: 1.3798 - val_loss: 29.8426 - val_mean_squared_error: 29.8426
# Epoch 54/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2765 - mean_squared_error: 1.2765 - val_loss: 32.1947 - val_mean_squared_error: 32.1947
# Epoch 55/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3605 - mean_squared_error: 1.3605 - val_loss: 46.1094 - val_mean_squared_error: 46.1094
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6470 - mean_squared_error: 1.6470 - val_loss: 40.4692 - val_mean_squared_error: 40.4692
# Epoch 57/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7010 - mean_squared_error: 1.7010 - val_loss: 38.9986 - val_mean_squared_error: 38.9986
# Epoch 58/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5152 - mean_squared_error: 1.5152 - val_loss: 63.4768 - val_mean_squared_error: 63.4768
# Epoch 59/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1614 - mean_squared_error: 2.1614 - val_loss: 34.8696 - val_mean_squared_error: 34.8696
# Epoch 60/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3428 - mean_squared_error: 1.3428 - val_loss: 49.4959 - val_mean_squared_error: 49.4959
# Epoch 61/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5523 - mean_squared_error: 2.5523 - val_loss: 61.4473 - val_mean_squared_error: 61.4473
# Epoch 62/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4423 - mean_squared_error: 2.4423 - val_loss: 27.3758 - val_mean_squared_error: 27.3758
# Epoch 63/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4364 - mean_squared_error: 1.4364 - val_loss: 32.4803 - val_mean_squared_error: 32.4803
# Epoch 64/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0808 - mean_squared_error: 2.0808 - val_loss: 45.6389 - val_mean_squared_error: 45.6389
# Epoch 65/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8296 - mean_squared_error: 1.8296 - val_loss: 41.4530 - val_mean_squared_error: 41.4530
# Epoch 66/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5156 - mean_squared_error: 1.5156 - val_loss: 27.2020 - val_mean_squared_error: 27.2020
# Epoch 67/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4805 - mean_squared_error: 1.4805 - val_loss: 19.6582 - val_mean_squared_error: 19.6582
# Epoch 68/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4411 - mean_squared_error: 1.4411 - val_loss: 42.8777 - val_mean_squared_error: 42.8777
# Epoch 69/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0190 - mean_squared_error: 2.0190 - val_loss: 40.3813 - val_mean_squared_error: 40.3813
# Epoch 70/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4147 - mean_squared_error: 3.4147 - val_loss: 62.9733 - val_mean_squared_error: 62.9733
# Epoch 71/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0744 - mean_squared_error: 3.0744 - val_loss: 45.3534 - val_mean_squared_error: 45.3534
# Epoch 72/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6748 - mean_squared_error: 1.6748 - val_loss: 24.4277 - val_mean_squared_error: 24.4277
# Epoch 73/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5226 - mean_squared_error: 2.5226 - val_loss: 30.8672 - val_mean_squared_error: 30.8672
# Epoch 74/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3305 - mean_squared_error: 1.3305 - val_loss: 22.8377 - val_mean_squared_error: 22.8377
# Epoch 75/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4811 - mean_squared_error: 1.4811 - val_loss: 45.3296 - val_mean_squared_error: 45.3296
# Epoch 76/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2653 - mean_squared_error: 1.2653 - val_loss: 26.3711 - val_mean_squared_error: 26.3711
# Epoch 77/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7717 - mean_squared_error: 1.7717 - val_loss: 36.9960 - val_mean_squared_error: 36.9960
# Epoch 78/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6019 - mean_squared_error: 1.6019 - val_loss: 19.8158 - val_mean_squared_error: 19.8158
# Epoch 79/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4153 - mean_squared_error: 1.4153 - val_loss: 31.1249 - val_mean_squared_error: 31.1249
# Epoch 80/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6796 - mean_squared_error: 1.6796 - val_loss: 52.8623 - val_mean_squared_error: 52.8623
# Epoch 81/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6225 - mean_squared_error: 1.6225 - val_loss: 32.4165 - val_mean_squared_error: 32.4165
# Epoch 82/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4029 - mean_squared_error: 1.4029 - val_loss: 26.8317 - val_mean_squared_error: 26.8317
# Epoch 83/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0638 - mean_squared_error: 2.0638 - val_loss: 36.2357 - val_mean_squared_error: 36.2357
# Epoch 84/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5053 - mean_squared_error: 1.5053 - val_loss: 60.3318 - val_mean_squared_error: 60.3318
# Epoch 85/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7208 - mean_squared_error: 1.7208 - val_loss: 36.2514 - val_mean_squared_error: 36.2514
# Epoch 86/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2872 - mean_squared_error: 1.2872 - val_loss: 17.0613 - val_mean_squared_error: 17.0613
# Epoch 87/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0217 - mean_squared_error: 2.0217 - val_loss: 24.5070 - val_mean_squared_error: 24.5070
# Epoch 88/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5180 - mean_squared_error: 1.5180 - val_loss: 16.9766 - val_mean_squared_error: 16.9766
# Epoch 89/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6353 - mean_squared_error: 1.6353 - val_loss: 55.8021 - val_mean_squared_error: 55.8021
# Epoch 90/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5434 - mean_squared_error: 1.5434 - val_loss: 15.2995 - val_mean_squared_error: 15.2995
# Epoch 91/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8294 - mean_squared_error: 1.8294 - val_loss: 36.7949 - val_mean_squared_error: 36.7949
# Epoch 92/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2646 - mean_squared_error: 1.2646 - val_loss: 30.3957 - val_mean_squared_error: 30.3957
# Epoch 93/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7187 - mean_squared_error: 3.7187 - val_loss: 24.9355 - val_mean_squared_error: 24.9355
# Epoch 94/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2866 - mean_squared_error: 1.2866 - val_loss: 41.4774 - val_mean_squared_error: 41.4774
# Epoch 95/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6168 - mean_squared_error: 1.6168 - val_loss: 31.2279 - val_mean_squared_error: 31.2279
# Epoch 96/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3458 - mean_squared_error: 1.3458 - val_loss: 52.1798 - val_mean_squared_error: 52.1798
# Epoch 97/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4603 - mean_squared_error: 1.4603 - val_loss: 35.1913 - val_mean_squared_error: 35.1913
# Epoch 98/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2435 - mean_squared_error: 1.2435 - val_loss: 24.6340 - val_mean_squared_error: 24.6340
# Epoch 99/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4631 - mean_squared_error: 1.4631 - val_loss: 32.9316 - val_mean_squared_error: 32.9316
# Epoch 100/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3748 - mean_squared_error: 1.3748 - val_loss: 30.2735 - val_mean_squared_error: 30.2735

# %%
# Check prediction
predictions = model.predict([X_test])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test, predictions)))
# Out:
# Valeur d'erreur moyenne:
#  9.63593153993698
