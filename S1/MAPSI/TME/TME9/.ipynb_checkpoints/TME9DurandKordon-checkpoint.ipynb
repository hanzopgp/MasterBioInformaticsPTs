# %% [markdown]
# # Régression & optimisation par descente de gradient
#
# Ce tme a deux objectifs:
#  - acquérir les connaissances de base pour faire face au problème de la régression, c'est à dire de l'estimation d'un score réel correpondant à une situation,
#  - travailler sur les techniques d'optimisation par descente de gradient

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Génération de données jouet & construction d'une solution analytique
#
# Dans un premier temps, générons des données jouets paramétriques:
#  - $N$: nombre de points à générer
#  - $x \in [0, 1]$ tirage avec un simple rand() ou un linspace() -au choix-
#      - Si vous optez pour un tirage aléatoire des abscisses, triez les points pour simplifier les traitements ultérieurs
#  - $y=ax+b+\epsilon, \epsilon \sim \mathcal N(0,\sigma^2)$
#      - Rappel : en multipliant un tirage aléatoire selon une gaussienne centrée réduite par $\sigma$ on obtient le bruit décrit ci-dessus
#
# Afin de travailler sur les bonnes pratiques, nous distinguerons un ensemble d'apprentissage et un ensemble de test.
# Les deux sont tirés selon la même distribution. L'ensemble de test comptera -arbitrairement- 1000 points.

# %%
def gen_data_lin(a, b, sig, N=500, Ntest=1000):
    X_train = np.sort(np.random.rand(N)) # sort optionnel, mais ça aide pour les plots
    X_test  = np.sort(np.random.rand(Ntest))
    sig1 = np.random.normal(0,sig,size=(N))
    sig2 = np.random.normal(0,sig,size=(Ntest))
    Y_train = a * X_train + b + sig1
    Y_test  = a * X_test + b + sig2
    return X_train, Y_train, X_test, Y_test

# %%
# génération de données jouets:
a = 6.
b = -1.
N = 100
sig = .4 # écart type

X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)

plt.figure()
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_train, Y_train, 'b')
plt.show()

# %% [markdown]
# Vous devez obtenir quelque chose de la forme:<br>
# ![données jouet](fig/gen_data.png)

# %% [markdown]
# ## Validation des formules analytiques
# Nous avons vu deux types de résolutions analytique: à partir des estimateurs des espérances et co-variances d'une part et des moindres carrés d'autre part. Testons les deux méthodes.
#
# ### Estimation de paramètres probabilistes
#  - $\hat a = \frac{\mbox{cov}(X,Y)}{\sigma_x^2}$
#  - $\hat b = E(Y)−\frac{\mbox{cov}(X,Y)}{\sigma_x^2} E(X)$
#
#  Estimer les paramètres, calculer l'erreur au sens des moindres carrés sur les données d'apprentissage et de test, puis tracer la droite de régression

# %%
def modele_lin_analytique(X_train, Y_train):
    cov_xy = np.cov(X_train, Y_train)[0][1]
    cov_std2 = cov_xy / (X_train.std()**2)
    ahat = cov_std2
    bhat = Y_train.mean() - cov_std2 * X_train.mean()
    return ahat, bhat

ahat, bhat = modele_lin_analytique(X_train, Y_train)
print(ahat,"\n",bhat)
# Out:
# 6.053066841658167
#  -1.0468371763093385

# %%
def erreur_mc(y, yhat):
    return ((y-yhat)**2).mean()

yhat_train = ahat*X_train+bhat
yhat_test  = ahat*X_test +bhat

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat_train, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):', erreur_mc(yhat_test, Y_test))
# Out:
# Erreur moyenne au sens des moindres carrés (train): 0.14567783966478193
# Erreur moyenne au sens des moindres carrés (test): 0.16338612228398597

# %%
plt.figure()
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_train, Y_train, 'b')
plt.plot(X_test, yhat_test, 'g', lw=3)

# %% [markdown]
# ## Formulation au sens des moindres carrés
#
# Nous partons directement sur une écriture matricielle. Du coup, il est nécessaire de construire la matrice enrichie $Xe$:
#     $$Xe = \left[\begin{array}{cc}
#                 X_0 & 1\\
#                 \vdots & \vdots\\
#                 X_N & 1
#                 \end{array}
#                 \right] $$
# Le code de la fonction d'enrichissement est donné ci-dessous.
#
# Il faut ensuite poser et résoudre un système d'équations linéaires de la forme:
# $$ A w = B $$
# **Rappel des formules vues en cours/TD:**
# $$ A=X^T X$$
# $$ B=X^T Y$$
# Fonction de résolution: `np.linalg.solve(A,B)`
# Vous devez obtenir la même solution que précédemment.

# %%
def make_mat_lin_biais(X): # fonctionne pour un vecteur unidimensionel X
    N = len(X)
    return np.hstack((X.reshape(N,1),np.ones((N,1))))

# %%
Xe = make_mat_lin_biais(X_train)
A = Xe.T @ Xe
B = Xe.T @ Y_train
w = np.linalg.solve(A,B)

print(w)
# Out:
# [ 5.99253617 -1.01941375]

# %% [markdown]
# Soit les données polynomiales générées avec la fonction ci-dessous
#  - proposer & une solution d'enrichissement (vue en cours et TD)
#  - résoudre analytiquement le problème des moindres carrés
#  - calculer l'erreur au sens des moindes carrés en apprentissage ET en test
#  - tracer les données et la solution

# %%
def gen_data_poly2(a, b, c, sig, N=500, Ntest=1000):
    '''
    Tire N points X aléatoirement entre 0 et 1 et génère y = ax^2 + bx + c + eps
    eps ~ N(0, sig^2)
    '''
    X_train = np.sort(np.random.rand(N))
    X_test  = np.sort(np.random.rand(Ntest))
    Y_train = a*X_train**2+b*X_train+c+np.random.randn(N)*sig
    Y_test  = a*X_test**2 +b*X_test +c+np.random.randn(Ntest)*sig
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = gen_data_poly2(10, -10, 5, 0.1, N=100, Ntest=100)
plt.figure()
plt.plot(X_train, Y_train)
plt.show()

# %%
def make_mat_poly_biais(X): # fonctionne pour un vecteur unidimensionel X
    N = len(X)
    tmp = np.hstack((X.reshape(N,1)**2,(X.reshape(N,1)))) # X**2, X
    return np.hstack((tmp, np.ones((N,1)))) # X**2, X, 1

Xe   = make_mat_poly_biais(X_train)
Xe_t = make_mat_poly_biais(X_test) 
A = Xe.T @ Xe
B = Xe.T @ Y_train
w = np.linalg.solve(A,B)

A_t = Xe_t.T @ Xe_t
B_t = Xe_t.T @ Y_test
w_t = np.linalg.solve(A_t,B_t)

print(w)

yhat   = X_train**2 * w[0]   + X_train * w[1]   + w[2]
yhat_t = X_test**2  * w_t[0] + X_test  * w_t[1] + w_t[2]
print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):', erreur_mc(yhat_t, Y_test))

plt.figure()
plt.plot(X_train, Y_train, 'b.')
plt.plot(X_train, yhat, 'r')
plt.show()
# Out:
# [ 10.21452311 -10.25687514   5.06990317]
# Erreur moyenne au sens des moindres carrés (train): 0.010736868769111627
# Erreur moyenne au sens des moindres carrés (test): 0.011799917171491297

# %% [markdown]
# # Fonction de coût & optimisation par descente de gradient
#
# Comme vu en TD et en cours, nous allons maintenant résoudre le problème de la régression par minimisation d'une fonction de coût:
# $$ C = \sum_{i=1}^N (y_i - f(x_i))$$
#
# Soit un problème avec des données $(x_i,y_i)_{i=1,\ldots,N}$, une fonction de décision/prédiction paramétrée par un vecteur $w$ et une fonction de cout à optimiser $C(w)$.
# Notre but est de trouver les paramètres $w^\star$ minimisant la fonction de coût:
# $$ w^\star = \arg\min_w C(w)$$
#
# l'algorithme de la descente de gradient est le suivant (rappel):
#
#  - $w_0 \leftarrow init$ par exemple : 0
#  - boucle
#      - $w_{t+1} \leftarrow w_{t} - \epsilon \nabla_w C(w_t)$
#
# Compléter le squelette d'implémentation fourni ci-dessous:

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)

# pour travailler en matrice: (re)construction de la matrice contenant les X et un biais
Xe = make_mat_lin_biais(X_train) # dataset linéaire, transformation lineaire des données
wstar = np.linalg.solve(Xe.T @ Xe, Xe.T @ Y_train)

def descente_grad_mc(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for i in range(nIterations):
        if i%(nIterations/10)==0:
            print(i*100/nIterations,"%")
        w = w - eps * 2 * X.T @ (X @ w - y)
        allw.append(w) # stockage de toutes les valeurs intermédiaires pour analyse
    allw = np.array(allw)
    return w, allw # la dernière valeur (meilleure) + tout l'historique pour le plot
    
w, allw = descente_grad_mc(Xe, Y_train, eps=1e-4, nIterations=10000)
print(wstar)
print(w)
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# [ 6.03219102 -1.03942442]
# [ 6.03213728 -1.03939466]

# %% [markdown]
# On s'intéresse ensuite à comprendre la descente de gradient dans l'espace des paramètres. Le code ci-dessous permet de tracer le cout pour un ensemble de paramètres (toutes les valeurs de paramètres prises par l'algorithmes au fil du temps).

# %%
# tracer de l'espace des couts
def plot_parametres( allw, X, y, opti = [], ngrid = 20, extract_bornes=False):
    '''
    Fonction de tracer d'un historique de coefficients
    ATTENTION: ca ne marche qu'en 2D (évidemment)
    Chaque w doit contenir 2 valeurs
    
    Il faut fournir les données (X,y) pour calculer le cout associé 
    à un jeu de paramètres w
    ATTENTION X = forme matricielle des données
    '''
    w_min = [-0.5, -2] # bornes par défaut, uniquement pour notre cas d'usage
    w_max = [8, 5]
    if extract_bornes: # bornes générales
        w_min = np.min(allw,0) # trouver les bornes
        w_max = np.max(allw,0)
    # faire une grille régulière avec tous les couples possibles entre le min et le max
    w1range = np.linspace(w_min[0], w_max[0], ngrid)
    w2range = np.linspace(w_min[1], w_max[1], ngrid)
    w1,w2 = np.meshgrid(w1range,w2range)
    # calcul de tous les couts associés à tous les couples de paramètres
    cost = np.array([[np.log(((X @ np.array([w1i,w2j])-y)**2).sum()) for w1i in w1range] for w2j in w2range])
    plt.figure()
    plt.contour(w1, w2, cost)
    if len(opti) > 0:
        plt.scatter(wstar[0], wstar[1],c='r')
    plt.plot(allw[:,0],allw[:,1],'b+-' ,lw=2 )
    return
    
plot_parametres(allw, Xe, Y_train, opti=wstar)
# plt.savefig('fig/grad_descente.png')

# %% [markdown]
# Vous devez obtenir un image de la forme :<br>
# ![Descente de gradient](fig/grad_descente.png)
#
# Tester différents jeux de paramètres pour mettre en évidence les phénomènes suivants:
#  - Divergence du gradient
#  - Convergence incomplète (trop lente ou pas assez d'itération)
#  - Convergence idéale: pas de gradient suffisamment grand et nombre d'itérations bien choisi

# %% [markdown]
# # Passage sur des données réelles
#
# Après avoir étudié trois manières de faire face au problème de la régression, nous proposons d'étudier un cas réel: la prédiction de la consommation des voitures en fonction de leurs caractéristiques.
#
# Dans le cas présent, nous allons baser la solution sur la résolution analytique du problème des moindres carrés (`np.linalg.solve(A,B)`), qui semble la mieux adaptée au problème qui nous intéresse.
#
# Le jeu de données est issu des datasets UCI, un répertoire parmi les plus connus en machine learning. Les données **sont déjà téléchargées et présentes dans le tme** mais vous voulez plus d'informations:
# https://archive.ics.uci.edu/ml/datasets/auto+mpg
#
# ![voiture](fig/Large9.jpg)
#
# Après avoir importé les données (fonction fournie), vous construirez une solution optimale et l'évaluerez au sens des moindres carrés en apprentissage et en test.

# %%
import pandas as pd
# Chargement des données
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) # comme np.loadtxt mais en plus robuste
# remplacement des données manquantes '?' => Nan pour travailler sur des nombres
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
# remplacement des valeurs manquantes par la moyenne
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())

print(data.head()) # visualiser ce qu'il y a dans les données

X = np.array(data.values[:,1:-2], dtype=np.float64)
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
# separation app/test
def separation_train_test(X, y, pc_train=0.75):
    napp = int(len(y)*pc_train) # nb de points pour le train
    X_train, Y_train = X[:napp], y[:napp]
    X_test, Y_test   = X[napp:], y[napp:]
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)

# %% [markdown]
# # Resolution analytique

# %%
def make_mat_lin_biais(X):
    N = X.shape[0]
    return np.hstack((X,np.ones((N,1)))) # ax + by + cz + ... + g ? ou ax² + by ... + g ?
    
def compute_yhat(X, w):
    res = w[0]
    N = X.shape[1]
    for i in range(1, N):
        res += X[:,i] * w[i]
    return res

def compute_w(X, y, linear):
    if(linear):
        Xe = make_mat_lin_biais(X)
    else:
        Xe = X
    A  = Xe.T @ Xe
    B  = Xe.T @ y
    w  = np.linalg.solve(A,B)
    return w
     
w   = compute_w(X_train, Y_train, linear=False)
w_t = compute_w(X_test , Y_test , linear=False)

print(w)

yhat   = compute_yhat(X_train, w)
yhat_t = compute_yhat(X_test , w_t)

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):',  erreur_mc(yhat_t, Y_test))
# Out:
# [-0.362168    0.00073902  0.00268987 -0.00563114 -0.01289395  0.54066773]
# Erreur moyenne au sens des moindres carrés (train): 10.661281449323736
# Erreur moyenne au sens des moindres carrés (test): 40.23068275181207

# %%
def plot_y(Y_train, Y_test, yhat, yhat_t):
    # tracé des prédictions:
    plt.figure()
    plt.subplot(211)
    plt.plot(Y_test, label="GT")
    plt.plot(yhat_t, label="pred")
    plt.title('En test')
    plt.legend()
    plt.subplot(212)
    plt.plot(Y_train, label="GT")
    plt.plot(yhat, label="pred")
    plt.title('En train')
    return

plot_y(Y_train, Y_test, yhat, yhat_t)

# %%
# interprétation des poids
plt.figure()
plt.bar(np.arange(len(w)), w)
plt.show()

# %% [markdown]
# # Résolution avec descente de gradient

# %%
def train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100, norm=False, grad="normal", encode=False, date_values_index=[], discrete_values_index=[]):
                
        if norm:
            Xn_train, Xn_test = normalisation(X_train, X_test)
        else:
            Xn_train, Xn_test = X_train, X_test
            
        if encode:
            Xn_train[:,date_values_index] = discretize_years(Xn_train[:,date_values_index], 10, date_values_index)
            Xn_test[:,date_values_index]  = discretize_years(Xn_test[:,date_values_index] , 10, date_values_index)
            Xn_train = encode_discrete_values(Xn_train, discrete_values_index)
            Xn_test  = encode_discrete_values(Xn_test , discrete_values_index)

        if norm:
            Xe_train = Xn_train
            Xe_test = Xn_test
        else:
            Xe_train = make_mat_lin_biais(Xn_train)
            Xe_test  = make_mat_lin_biais(Xn_test)
        
        if grad == "normal":
            w, _ = descente_grad_mc(Xe_train, Y_train, eps, nIterations)
        elif grad == "stoch":
            w, _ = descente_grad_mc_stoch(Xe_train, Y_train, eps, nIterations)
        elif grad == "momentum":
            w, _ = descente_grad_mc_stoch_mom(Xe_train, Y_train, eps, 0.9, nIterations)
        elif grad == "batch":
            w, _ = descente_grad_mc_stoch_batch(Xe_train, Y_train, eps, 20, nIterations)
        else:
            print("Pas de gradient ?")
                
        yhat   = Xe_train @ w
        yhat_t = Xe_test @ w

        print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
        print('Erreur moyenne au sens des moindres carrés (test):' , erreur_mc(yhat_t, Y_test))
        
        plot_y(Y_train, Y_test, yhat, yhat_t)
        
        plt.figure()
        plt.bar(np.arange(len(w)), w)
        plt.show()

# %%
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
train(X_train, X_test, Y_train, Y_test, eps=1e-6, nIterations=10, norm=False) # Gradient vanishing car pas de normalisation !
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 3.868530276071835e+78
# Erreur moyenne au sens des moindres carrés (test): 2.345811916660169e+78

# %% [markdown]
# ## Normalisation
#
# Sur le diagramme ci-dessus, on ne voit pas grand chose pour une raison évidente: on ne peut pas comparer ces poids qui comparent des variables dont les ordres de grandeur sont différents.
#
# Nous allons donc assimiler chaque colonne $X_j$ à une variable suivant une loi normale et nous allons revenir à une Normale centrée réduite selon la formule de base:
#
# $$X_j \sim \mathcal N(\mu_j, \sigma_j^2) $$
# $$\Rightarrow Z_j = \frac{X_j - \mu_j}{\sigma_j} \sim \mathcal N(0, 1) $$
#
# Tous les $Z_j$ sont comparables et nous seront en mesure de comprendre l'impact de chaque variables sur les résultats.
#
# **ATTENTION:** on ne se basera que sur les données d'apprentissage pour le calcul des $\{\mu_j, \sigma_j\}$.
#
# Une fois la normalisation effectuée, analyser l'impact des différentes variables descriptives sur la valeur à prédire.

# %%
def normalisation(X_train, X_test):
    '''
    Fonction de normalisation des données pour rendre les colonnes comparables
    Chaque variable sera assimilée à une loi normale qu'il faut centrer + réduire.
    ATTENTION: il faut calculer les moyennes et écarts-types sur les données d'apprentissage seulement
    '''
    stds     = X_train.std(axis=0)
    means    = X_train.mean(axis=0)
    stds_t   = X_test.std(axis=0)
    means_t  = X_test.mean(axis=0)
    Xn_train = (X_train - means)   / stds**2
    Xn_test  = (X_test  - means_t) / stds_t**2
    Xn_train = np.hstack((Xn_train, np.ones((Xn_train.shape[0], 1))))
    Xn_test  = np.hstack((Xn_test,  np.ones((Xn_test.shape [0], 1))))
    return Xn_train, Xn_test

Xn_train, Xn_test = normalisation(X_train, X_test)

w   = compute_w(Xn_train, Y_train, linear=False)
w_t = compute_w(Xn_test , Y_test , linear=False)

yhat   = compute_yhat(Xn_train, w  )
yhat_t = compute_yhat(Xn_test , w_t)

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):',  erreur_mc(yhat_t, Y_test))

plot_y(Y_train, Y_test, yhat, yhat_t)

plt.figure()
plt.bar(np.arange(len(w)), w)
plt.show()
# Out:
# Erreur moyenne au sens des moindres carrés (train): 9.197411943240763
# Erreur moyenne au sens des moindres carrés (test): 14.700511217891421

# %%
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=True) # Pourquoi un meilleur test que train ? Pourquoi besoin d'autant d'iterations ?
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 10.00581422002004
# Erreur moyenne au sens des moindres carrés (test): 206.60932167594763

# %%
X_train.shape
# Out:
# (298, 6)

# %% [markdown]
# # Questions d'ouverture
#
# ## Sélection de caractéristiques
#
# Quels sont les résultats obtenus en éliminant toutes les variables servent moins?
#
# ## Feature engineering
#
# En étudiant la signification des variables du problèmes, on trouve:
#
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
#
# D'après la question précédente, le poids, l'année du modèle et le biais sont des facteurs important pour le calcul de la consommation... Jusqu'ici, nous n'avons pas pris en compte l'origine qui était difficile à coder.
#
# ### Encodage de l'origine
#
# La variable origine est accessible de la manière suivante:
#
# ```
#   origine = data.values[:,-2]
# ```
# Il faut le faire au début du traitement pour bien conserver la séparation en l'apprentissage et le test.
#
# Au moins les deux derniers facteurs discrets pourraient être traités différemment en one-hot encoding:
# $$X_j = x \in \{1, \ldots, K\} \Rightarrow [0, 0, 1, 0] \in \{0, 1\}^K$$
#
# La valeur $x$ donne l'index de la colonne non nulle.
#
# ### Encodage de l'année
#
# Pour l'année, il est possible de procéder de la même manière, mais il préférable de découper les années en 10 catégories puis d'encoder pour limiter le nombre de dimensions.

# %%
# Rechargement des donnees
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) 
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())
print(data.head())

X = np.array(data.values[:,:-1], dtype=np.float64) # Cette fois on prend toutes les valeurs
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
# Index suivant le type de variable
discrete_values_index = np.array([1, 7])
date_values_index = np.array([6])
continuous_values_index = np.array([0, 2, 3, 4, 5])

# %%
# Traitement des variables discrete :
def one_hot_encoding(array):
    n = len(array)
    unique_values = np.unique(array)
    n_unique = len(unique_values)
    dic = {}
    for i in range(n_unique):
        dic[unique_values[i]] = i
    res = np.zeros((n, n_unique))
    for i in range(n):
        res[i][dic[array[i]]] = 1
    return res

def encode_discrete_values(X, index):
    for idx in index:
        encoding = one_hot_encoding(X[:,idx])
        X = np.delete(X, idx, 1)
        n = encoding.shape[1]
        for _ in range(n):
            X = np.hstack((X, np.zeros((X.shape[0], 1))))
        for i in range(X.shape[0]):
            for j in range(n):
                X[i][(X.shape[1]-n) + j] = encoding[i][j]
    return X                                  

# print(X[:,5:])
# X = encode_discrete_values(X, discrete_values_index)
# print(X[:,6:])

# %%
# Traitement de la variable date :
def discretize_years(array, n, index):
    array = np.sort(array)
    size = len(array)
    cpt = 0
    n_interval = size//n
    for i in range(1, size+1):
        array[i-1] = cpt
        if i%n_interval == 0:
            cpt += 1
    return array

# print(X[:,date_values_index])
# X = discretize_years(X[:,date_values_index], 10, date_values_index)
# print(X[:,date_values_index])

# %%
### Test avec toutes les features continues+discretes :
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
# 9. car name: string (unique for each instance)

X = np.array(data.values[:,:-1], dtype=np.float64)
# X = discretize_years(X[:,date_values_index], 10, date_values_index)
# X = encode_discrete_values(X, discrete_values_index)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True, encode=True, date_values_index=date_values_index, discrete_values_index=discrete_values_index)
# Out:
# (298, 8)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 6.203114515954615
# Erreur moyenne au sens des moindres carrés (test): 79.88341282758034

# %%
### Test avec toutes les features continues :
# 1. mpg: continuous
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous

index_to_delete = np.concatenate((discrete_values_index, date_values_index))
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True) # Resultat bien moins bon donc valeurs discrete one hot encoded importantes !
# Out:
# (298, 5)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 7.119738952721287
# Erreur moyenne au sens des moindres carrés (test): 127.16908733179729

# %%
### Test avec seulement les features :
# 1. mpg: continuous
# 6. acceleration: continuous

index_to_delete = [1,2,3,4,6,7]
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True) # Presque meme resultat qu'au dessus avec seulement 2 features
# Out:
# (298, 2)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 7.2185629585350775
# Erreur moyenne au sens des moindres carrés (test): 127.46374961047992

# %% [markdown]
# # Question d'ouverture sur le gradient
#
# ## La normalisation a-t-elle un impact sur le gradient?
#
# La normalisation des données peut au moins nous aider à régler plus facilement le pas (qui sera toujours du même ordre de grandeur... Mais cela a-t-il un impact sur la manière dont nous nous rapprochons de la solution optimale?
#
# ## Gradient stochastique
#
# Dans la plupart des algorithmes modernes d'optimisation liés aux réseaux de neurones, le gradient est calculé de manière stochastique, sur un exemple à la fois:
#
# - $w_0 \leftarrow init$ par exemple : 0
# - boucle
#      - tirage d'une donnée $i$: $(x_i,y_i)$
#      - $w_{t+1} \leftarrow w_{t} - \epsilon \nabla_w C_i(w)$
#
#
# Etudier le fonctionnement de cet algorithme sur les exemples jouets précédents.
#
# ## Amélioration du gradient
#
# Le blog de S. Ruder explique particulièrement bien les améliorations possibles sur les descentes de gradient.
#
# https://ruder.io/optimizing-gradient-descent/
#
# Comparer une descente de gradient stochastique avec et sans moment sur les données jouets des premières questions.

# %%
### Impact de la normalisation :
# La normalisation des données permet de ne pas avoir un gradient qui tend vers 0 ou vers de très grands nombres.
# Lors de la descente de gradient, si notre gradient prend des valeurs énormes, on pourrait rater un minimum local interessant.
# Dans le cas contraire, si le gradient prend des valeurs trop petite, on finit par avoir une perte d'information.

# %%
### Gradient stochastique :
def make_mat_lin_biais(X): # Redefinition de la fonction
    N = len(X)
    return np.hstack((X.reshape(N,1),np.ones((N,1))))

X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

# Gradient classique :
def descente_grad_mc(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for _ in range(nIterations):
        w = w - eps * 2 * X.T @ (X @ w - y)
        allw.append(w) # stockage de toutes les valeurs intermédiaires pour analyse
    allw = np.array(allw)
    return w, allw # la dernière valeur (meilleure) + tout l'historique pour le plot
    
w, allw = descente_grad_mc(Xe, Y_train, eps=1e-4, nIterations=100_000)
print(w)

plot_parametres(allw, Xe, Y_train, opti=wstar)

# Gradient stochastique :
def descente_grad_mc_stoch(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for _ in range(nIterations):
        rand = np.random.randint(X.shape[0])
        w = w - eps * 2 * X.T[:,rand] * (X[rand] @ w - y[rand])
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s, allw_s = descente_grad_mc_stoch(Xe, Y_train, eps=0.1, nIterations=1_000)
print(w_s)

plot_parametres(allw_s, Xe, Y_train, opti=wstar)

# Train avec gradient normal :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="normal")
# Train avec gradient stochastique :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Out:
# [ 6.05553556 -0.98835457]
# [ 6.10242611 -0.98633599]
# Erreur moyenne au sens des moindres carrés (train): 0.16934766498721174
# Erreur moyenne au sens des moindres carrés (test): 0.15861381136696984
# Erreur moyenne au sens des moindres carrés (train): 0.35466655867622093
# Erreur moyenne au sens des moindres carrés (test): 0.37163320223374685

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

### Amelioration du gradient :
# Gradient stochastique avec moment :
def descente_grad_mc_stoch_mom(X, y, eps=1e-4, gamma=0.9, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    value = w
    allw = [w]
    for i in range(nIterations):
        rand = np.random.randint(X.shape[0])
        gradient = eps * 2 * X.T[:,rand] * (X[rand] @ w - y[rand])
        new_value = (1-gamma) * gradient + gamma * value
        w = w - new_value
        value = new_value
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s_m, allw_s_m = descente_grad_mc_stoch_mom(Xe, Y_train, eps=0.1, nIterations=1_000)
print(w_s_m)

plot_parametres(allw_s_m, Xe, Y_train, opti=wstar)

# Train avec gradient sans moment :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Train avec gradient avec moment :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="momentum")
# Out:
# [ 5.88807072 -1.05761177]
# Erreur moyenne au sens des moindres carrés (train): 0.30933154585748585
# Erreur moyenne au sens des moindres carrés (test): 0.2630730402130814
# Erreur moyenne au sens des moindres carrés (train): 0.3108779059838941
# Erreur moyenne au sens des moindres carrés (test): 0.2644628172698202

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

### Amelioration du gradient :
# Gradient stochastique avec minibatch :
def descente_grad_mc_stoch_batch(X, y, eps=1e-4, n_batch=20, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    value = w
    allw = [w]
    for i in range(nIterations):
        rand = np.random.randint(X.shape[0]) - n_batch
        batch = X[rand:rand+n_batch]
        batch_t = batch.T
        batch_y = y[rand:rand+n_batch]
        gradient = eps * 2 * batch_t @ (batch @ w - batch_y)
        w = w - gradient
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s_b, allw_s_b = descente_grad_mc_stoch_batch(Xe, Y_train, eps=0.01, n_batch=20, nIterations=1_000)
print(w_s_b)

plot_parametres(allw_s_b, Xe, Y_train, opti=wstar)

# Train avec gradient stoch :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Train avec gradient avec batch :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="batch")
# Out:
# [ 5.7983486  -0.84701779]
# Erreur moyenne au sens des moindres carrés (train): 0.32553208859811766
# Erreur moyenne au sens des moindres carrés (test): 0.4545362838565728
# Erreur moyenne au sens des moindres carrés (train): 0.1464918306729407
# Erreur moyenne au sens des moindres carrés (test): 0.1732997149887393

# %% [markdown]
# # Exercice supplémentaire : regression avec multi layer perceptron

# %%
import tensorflow as tf

# %%
# Rechargement des donnees
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) 
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())
print(data.head())

X = np.array(data.values[:,:-1], dtype=np.float64)
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
index_to_delete = np.concatenate((discrete_values_index, date_values_index))
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)

# %%
TEST_SPLIT = 0.25
N_FEATURES = X.shape[1]
EPOCHS = 20
NB_NEURONS = 32
# DROPOUT_VALUE = 0.3

# %%
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=1-TEST_SPLIT)
print(X_train.shape)
# Out:
# (298, 5)

# %%
def norm(X):
    n,m = X.shape
    for i in range(n):
        for j in range(m):
            X[i][j] = (X[i][j] - X[:,j].min()) / (X[:,j].max() - X[:,j].min())
    return X

X_train_unnorm = X_train.copy()
X_test_unnorm = X_test.copy()

print(X_train.mean(axis=0))
X_train = norm(X_train)
X_test = norm(X_test)
print(X_train.mean(axis=0))
# Out:
# [  20.77013423  214.49832215  111.96979866 3130.23489933   15.22315436]
# [0.4993601  0.52790678 0.57298831 0.6737239  0.69030311]

# %% [markdown]
# # Descente de gradient stochastique

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="sgd", metrics=["mean_squared_error"]) # Fonction de loss moindre carres et optimisation par descente de gradient
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 69ms/step - loss: 355.6025 - mean_squared_error: 355.6025 - val_loss: 920.1942 - val_mean_squared_error: 920.1942
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 307.0629 - mean_squared_error: 307.0629 - val_loss: 126.5115 - val_mean_squared_error: 126.5115
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 64.6984 - mean_squared_error: 64.6984 - val_loss: 240.3063 - val_mean_squared_error: 240.3063
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 33.4456 - mean_squared_error: 33.4456 - val_loss: 11.3774 - val_mean_squared_error: 11.3774
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 71.2029 - mean_squared_error: 71.2029 - val_loss: 113.0214 - val_mean_squared_error: 113.0214
# Epoch 6/20
# 10/10 [==============================] - 0s 4ms/step - loss: 13.7317 - mean_squared_error: 13.7317 - val_loss: 56.3974 - val_mean_squared_error: 56.3974
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 16.1548 - mean_squared_error: 16.1548 - val_loss: 167.0174 - val_mean_squared_error: 167.0174
# Epoch 8/20
# 10/10 [==============================] - 0s 4ms/step - loss: 6.4905 - mean_squared_error: 6.4905 - val_loss: 54.0226 - val_mean_squared_error: 54.0226
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 11.3460 - mean_squared_error: 11.3460 - val_loss: 74.7873 - val_mean_squared_error: 74.7873
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 3.6556 - mean_squared_error: 3.6556 - val_loss: 56.7413 - val_mean_squared_error: 56.7413
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 8.9790 - mean_squared_error: 8.9790 - val_loss: 15.1967 - val_mean_squared_error: 15.1967
# Epoch 12/20
# 10/10 [==============================] - 0s 3ms/step - loss: 13.7082 - mean_squared_error: 13.7082 - val_loss: 46.9445 - val_mean_squared_error: 46.9445
# Epoch 13/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.8563 - mean_squared_error: 4.8563 - val_loss: 59.2926 - val_mean_squared_error: 59.2926
# Epoch 14/20
# 10/10 [==============================] - 0s 3ms/step - loss: 3.5592 - mean_squared_error: 3.5592 - val_loss: 37.6999 - val_mean_squared_error: 37.6999
# Epoch 15/20
# 10/10 [==============================] - 0s 4ms/step - loss: 7.7112 - mean_squared_error: 7.7112 - val_loss: 62.4206 - val_mean_squared_error: 62.4206
# Epoch 16/20
# 10/10 [==============================] - 0s 3ms/step - loss: 4.9086 - mean_squared_error: 4.9086 - val_loss: 94.4172 - val_mean_squared_error: 94.4172
# Epoch 17/20
# 10/10 [==============================] - 0s 3ms/step - loss: 4.4863 - mean_squared_error: 4.4863 - val_loss: 37.9619 - val_mean_squared_error: 37.9619
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 5.6077 - mean_squared_error: 5.6077 - val_loss: 42.0941 - val_mean_squared_error: 42.0941
# Epoch 19/20
# 10/10 [==============================] - 0s 3ms/step - loss: 6.8729 - mean_squared_error: 6.8729 - val_loss: 58.7344 - val_mean_squared_error: 58.7344
# Epoch 20/20
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8733 - mean_squared_error: 2.8733 - val_loss: 70.5374 - val_mean_squared_error: 70.5374

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
sample=10
predictions = model.predict([X_test])
print("Valeurs en entree normalisees:\n", X_test[:sample])
print("Valeurs en entree non-normalisees:\n", X_test_unnorm[:sample])
print("Valeurs reelle en sortie:\n", Y_test[:sample])
print("Valeurs predit en sortie:\n", predictions[:sample])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test[:sample], predictions[:sample])))
# Out:
# Valeurs en entree normalisees:
#  [[0.1862069  1.         0.91666667 1.         0.45185185]
#  [0.5820208  0.40114613 0.53464717 0.85633727 1.        ]
#  [0.51092125 0.74256209 0.68052419 0.91810198 0.9006135 ]
#  [0.73283804 0.29919679 0.52839285 0.59050989 0.52791411]
#  [0.73930163 0.29940109 0.52841529 0.57711417 0.59831288]
#  [0.68112927 0.24220935 0.49038426 0.54221095 0.77638037]
#  [0.79962853 0.25948755 0.52094758 0.57174974 0.59003067]
#  [0.60787519 0.43103483 0.68063172 0.71673729 0.64386503]
#  [0.61649331 0.4939355  0.87073189 0.69660013 0.44923313]
#  [0.57340267 0.4939355  0.87073189 0.72479216 0.51554333]]
# Valeurs en entree non-normalisees:
#  [[  23.   350.   125.  3900.    17.4]
#  [  27.2  141.    71.  3190.    24.8]
#  [  23.9  260.    90.  3420.    22.2]
#  [  34.2  105.    70.  2200.    13.2]
#  [  34.5  105.    70.  2150.    14.9]
#  [  31.8   85.    65.  2020.    19.2]
#  [  37.3   91.    69.  2130.    14.7]
#  [  28.4  151.    90.  2670.    16. ]
#  [  28.8  173.   115.  2595.    11.3]
#  [  26.8  173.   115.  2700.    12.9]]
# Valeurs reelle en sortie:
#  [23.  27.2 23.9 34.2 34.5 31.8 37.3 28.4 28.8 26.8]
# Valeurs predit en sortie:
#  [[12.318548]
#  [20.196548]
#  [16.835043]
#  [25.795963]
#  [26.383427]
#  [26.480429]
#  [28.005045]
#  [21.142286]
#  [20.630398]
#  [19.684307]]
# Valeur d'erreur moyenne:
#  10.18271742644723

# %% [markdown]
# # Adam

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="adam", metrics=["mean_squared_error"]) # Fonction de loss moindre carres et optimisation par descente de gradient
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 0s 14ms/step - loss: 481.8044 - mean_squared_error: 481.8044 - val_loss: 997.3862 - val_mean_squared_error: 997.3862
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 424.2564 - mean_squared_error: 424.2564 - val_loss: 967.5097 - val_mean_squared_error: 967.5097
# Epoch 3/20
# 10/10 [==============================] - 0s 3ms/step - loss: 411.3359 - mean_squared_error: 411.3359 - val_loss: 935.4570 - val_mean_squared_error: 935.4570
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 408.5385 - mean_squared_error: 408.5385 - val_loss: 901.3962 - val_mean_squared_error: 901.3962
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 398.7080 - mean_squared_error: 398.7080 - val_loss: 864.8740 - val_mean_squared_error: 864.8740
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 376.1503 - mean_squared_error: 376.1503 - val_loss: 825.4796 - val_mean_squared_error: 825.4796
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 356.6966 - mean_squared_error: 356.6966 - val_loss: 782.2836 - val_mean_squared_error: 782.2836
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 322.2127 - mean_squared_error: 322.2127 - val_loss: 735.8854 - val_mean_squared_error: 735.8854
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 306.4824 - mean_squared_error: 306.4824 - val_loss: 686.8876 - val_mean_squared_error: 686.8876
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 259.8453 - mean_squared_error: 259.8453 - val_loss: 635.8807 - val_mean_squared_error: 635.8807
# Epoch 11/20
# 10/10 [==============================] - 0s 3ms/step - loss: 229.3019 - mean_squared_error: 229.3019 - val_loss: 582.3965 - val_mean_squared_error: 582.3965
# Epoch 12/20
# 10/10 [==============================] - 0s 3ms/step - loss: 233.3714 - mean_squared_error: 233.3714 - val_loss: 525.9811 - val_mean_squared_error: 525.9811
# Epoch 13/20
# 10/10 [==============================] - 0s 3ms/step - loss: 193.9566 - mean_squared_error: 193.9566 - val_loss: 470.7855 - val_mean_squared_error: 470.7855
# Epoch 14/20
# 10/10 [==============================] - 0s 3ms/step - loss: 165.6191 - mean_squared_error: 165.6191 - val_loss: 416.6355 - val_mean_squared_error: 416.6355
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 137.3655 - mean_squared_error: 137.3655 - val_loss: 365.6229 - val_mean_squared_error: 365.6229
# Epoch 16/20
# 10/10 [==============================] - 0s 4ms/step - loss: 119.7051 - mean_squared_error: 119.7051 - val_loss: 317.4087 - val_mean_squared_error: 317.4087
# Epoch 17/20
# 10/10 [==============================] - 0s 3ms/step - loss: 89.8298 - mean_squared_error: 89.8298 - val_loss: 276.0702 - val_mean_squared_error: 276.0702
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 83.1283 - mean_squared_error: 83.1283 - val_loss: 240.8629 - val_mean_squared_error: 240.8629
# Epoch 19/20
# 10/10 [==============================] - 0s 3ms/step - loss: 76.0935 - mean_squared_error: 76.0935 - val_loss: 210.1612 - val_mean_squared_error: 210.1612
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 64.4134 - mean_squared_error: 64.4134 - val_loss: 189.3116 - val_mean_squared_error: 189.3116

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
sample=10
predictions = model.predict([X_test])
print("Valeurs en entree normalisees:\n", X_test[:sample])
print("Valeurs en entree non-normalisees:\n", X_test_unnorm[:sample])
print("Valeurs reelle en sortie:\n", Y_test[:sample])
print("Valeurs predit en sortie:\n", predictions[:sample])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test[:sample], predictions[:sample])))
# Out:
# Valeurs en entree normalisees:
#  [[0.1862069  1.         0.91666667 1.         0.45185185]
#  [0.5820208  0.40114613 0.53464717 0.85633727 1.        ]
#  [0.51092125 0.74256209 0.68052419 0.91810198 0.9006135 ]
#  [0.73283804 0.29919679 0.52839285 0.59050989 0.52791411]
#  [0.73930163 0.29940109 0.52841529 0.57711417 0.59831288]
#  [0.68112927 0.24220935 0.49038426 0.54221095 0.77638037]
#  [0.79962853 0.25948755 0.52094758 0.57174974 0.59003067]
#  [0.60787519 0.43103483 0.68063172 0.71673729 0.64386503]
#  [0.61649331 0.4939355  0.87073189 0.69660013 0.44923313]
#  [0.57340267 0.4939355  0.87073189 0.72479216 0.51554333]]
# Valeurs en entree non-normalisees:
#  [[  23.   350.   125.  3900.    17.4]
#  [  27.2  141.    71.  3190.    24.8]
#  [  23.9  260.    90.  3420.    22.2]
#  [  34.2  105.    70.  2200.    13.2]
#  [  34.5  105.    70.  2150.    14.9]
#  [  31.8   85.    65.  2020.    19.2]
#  [  37.3   91.    69.  2130.    14.7]
#  [  28.4  151.    90.  2670.    16. ]
#  [  28.8  173.   115.  2595.    11.3]
#  [  26.8  173.   115.  2700.    12.9]]
# Valeurs reelle en sortie:
#  [23.  27.2 23.9 34.2 34.5 31.8 37.3 28.4 28.8 26.8]
# Valeurs predit en sortie:
#  [[20.988564]
#  [19.889904]
#  [21.881437]
#  [17.160706]
#  [17.424967]
#  [17.116528]
#  [17.49126 ]
#  [18.88644 ]
#  [19.359095]
#  [19.48394 ]]
# Valeur d'erreur moyenne:
#  11.63761133597148

# %% [markdown]
# # Adam + optimisation learning rate + early stopping

# %%
EPOCHS = 400

# %%
def get_callbacks():   
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_mean_squared_error', factor=0.3, patience=10, verbose=1, mode="min", min_lr=1e-4)

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=30 , verbose=1, mode="min", restore_best_weights=True)
    
#     model_cp = ModelCheckpoint('model.h5', 
#                                  save_best_only = True, 
#                                  save_weights_only = True,
#                                  monitor = 'val_loss', 
#                                  mode = 'min', verbose = 1)

    return [early_stopping, reduce_lr]

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
#     model.add(tf.keras.layers.Dropout(DROPOUT_VALUE)) # Dropout pour eviter overfit
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="adam", metrics=["mean_squared_error"])
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test), callbacks=get_callbacks())
# Out:
# Epoch 1/400
# 10/10 [==============================] - 1s 14ms/step - loss: 481.4302 - mean_squared_error: 481.4302 - val_loss: 1055.7032 - val_mean_squared_error: 1055.7032
# Epoch 2/400
# 10/10 [==============================] - 0s 3ms/step - loss: 449.0671 - mean_squared_error: 449.0671 - val_loss: 1042.6908 - val_mean_squared_error: 1042.6908
# Epoch 3/400
# 10/10 [==============================] - 0s 4ms/step - loss: 478.8062 - mean_squared_error: 478.8062 - val_loss: 1030.2849 - val_mean_squared_error: 1030.2849
# Epoch 4/400
# 10/10 [==============================] - 0s 3ms/step - loss: 465.9368 - mean_squared_error: 465.9368 - val_loss: 1017.8668 - val_mean_squared_error: 1017.8668
# Epoch 5/400
# 10/10 [==============================] - 0s 3ms/step - loss: 455.7829 - mean_squared_error: 455.7829 - val_loss: 1004.5261 - val_mean_squared_error: 1004.5261
# Epoch 6/400
# 10/10 [==============================] - 0s 4ms/step - loss: 430.5385 - mean_squared_error: 430.5385 - val_loss: 989.8920 - val_mean_squared_error: 989.8920
# Epoch 7/400
# 10/10 [==============================] - 0s 3ms/step - loss: 435.3819 - mean_squared_error: 435.3819 - val_loss: 973.1481 - val_mean_squared_error: 973.1481
# Epoch 8/400
# 10/10 [==============================] - 0s 3ms/step - loss: 430.1156 - mean_squared_error: 430.1156 - val_loss: 953.7024 - val_mean_squared_error: 953.7024
# Epoch 9/400
# 10/10 [==============================] - 0s 3ms/step - loss: 398.3196 - mean_squared_error: 398.3196 - val_loss: 930.5673 - val_mean_squared_error: 930.5673
# Epoch 10/400
# 10/10 [==============================] - 0s 3ms/step - loss: 391.4353 - mean_squared_error: 391.4353 - val_loss: 903.0535 - val_mean_squared_error: 903.0535
# Epoch 11/400
# 10/10 [==============================] - 0s 3ms/step - loss: 380.5551 - mean_squared_error: 380.5551 - val_loss: 870.5594 - val_mean_squared_error: 870.5594
# Epoch 12/400
# 10/10 [==============================] - 0s 3ms/step - loss: 369.8839 - mean_squared_error: 369.8839 - val_loss: 831.7870 - val_mean_squared_error: 831.7870
# Epoch 13/400
# 10/10 [==============================] - 0s 3ms/step - loss: 339.5891 - mean_squared_error: 339.5891 - val_loss: 786.8875 - val_mean_squared_error: 786.8875
# Epoch 14/400
# 10/10 [==============================] - 0s 3ms/step - loss: 314.5372 - mean_squared_error: 314.5372 - val_loss: 736.4043 - val_mean_squared_error: 736.4043
# Epoch 15/400
# 10/10 [==============================] - 0s 3ms/step - loss: 263.7425 - mean_squared_error: 263.7425 - val_loss: 681.3102 - val_mean_squared_error: 681.3102
# Epoch 16/400
# 10/10 [==============================] - 0s 3ms/step - loss: 255.7669 - mean_squared_error: 255.7669 - val_loss: 621.1569 - val_mean_squared_error: 621.1569
# Epoch 17/400
# 10/10 [==============================] - 0s 3ms/step - loss: 212.0850 - mean_squared_error: 212.0850 - val_loss: 558.9780 - val_mean_squared_error: 558.9780
# Epoch 18/400
# 10/10 [==============================] - 0s 3ms/step - loss: 192.2369 - mean_squared_error: 192.2369 - val_loss: 495.1076 - val_mean_squared_error: 495.1076
# Epoch 19/400
# 10/10 [==============================] - 0s 4ms/step - loss: 156.6835 - mean_squared_error: 156.6835 - val_loss: 432.9376 - val_mean_squared_error: 432.9376
# Epoch 20/400
# 10/10 [==============================] - 0s 3ms/step - loss: 129.6711 - mean_squared_error: 129.6711 - val_loss: 373.9319 - val_mean_squared_error: 373.9319
# Epoch 21/400
# 10/10 [==============================] - 0s 4ms/step - loss: 109.2195 - mean_squared_error: 109.2195 - val_loss: 320.2950 - val_mean_squared_error: 320.2950
# Epoch 22/400
# 10/10 [==============================] - 0s 3ms/step - loss: 92.7596 - mean_squared_error: 92.7596 - val_loss: 273.7524 - val_mean_squared_error: 273.7524
# Epoch 23/400
# 10/10 [==============================] - 0s 4ms/step - loss: 69.3191 - mean_squared_error: 69.3191 - val_loss: 234.7703 - val_mean_squared_error: 234.7703
# Epoch 24/400
# 10/10 [==============================] - 0s 3ms/step - loss: 61.8269 - mean_squared_error: 61.8269 - val_loss: 203.1094 - val_mean_squared_error: 203.1094
# Epoch 25/400
# 10/10 [==============================] - 0s 3ms/step - loss: 52.9859 - mean_squared_error: 52.9859 - val_loss: 180.1881 - val_mean_squared_error: 180.1881
# Epoch 26/400
# 10/10 [==============================] - 0s 3ms/step - loss: 51.7571 - mean_squared_error: 51.7571 - val_loss: 163.4512 - val_mean_squared_error: 163.4512
# Epoch 27/400
# 10/10 [==============================] - 0s 3ms/step - loss: 50.7650 - mean_squared_error: 50.7650 - val_loss: 151.1407 - val_mean_squared_error: 151.1407
# Epoch 28/400
# 10/10 [==============================] - 0s 3ms/step - loss: 49.7559 - mean_squared_error: 49.7559 - val_loss: 143.5181 - val_mean_squared_error: 143.5181
# Epoch 29/400
# 10/10 [==============================] - 0s 3ms/step - loss: 49.4767 - mean_squared_error: 49.4767 - val_loss: 138.8848 - val_mean_squared_error: 138.8848
# Epoch 30/400
# 10/10 [==============================] - 0s 3ms/step - loss: 45.1196 - mean_squared_error: 45.1196 - val_loss: 136.4537 - val_mean_squared_error: 136.4537
# Epoch 31/400
# 10/10 [==============================] - 0s 3ms/step - loss: 45.9314 - mean_squared_error: 45.9314 - val_loss: 135.4165 - val_mean_squared_error: 135.4165
# Epoch 32/400
# 10/10 [==============================] - 0s 4ms/step - loss: 46.0434 - mean_squared_error: 46.0434 - val_loss: 134.2414 - val_mean_squared_error: 134.2414
# Epoch 33/400
# 10/10 [==============================] - 0s 4ms/step - loss: 43.5430 - mean_squared_error: 43.5430 - val_loss: 132.8394 - val_mean_squared_error: 132.8394
# Epoch 34/400
# 10/10 [==============================] - 0s 4ms/step - loss: 44.3254 - mean_squared_error: 44.3254 - val_loss: 131.4162 - val_mean_squared_error: 131.4162
# Epoch 35/400
# 10/10 [==============================] - 0s 4ms/step - loss: 41.9220 - mean_squared_error: 41.9220 - val_loss: 130.1262 - val_mean_squared_error: 130.1262
# Epoch 36/400
# 10/10 [==============================] - 0s 4ms/step - loss: 38.8925 - mean_squared_error: 38.8925 - val_loss: 128.3353 - val_mean_squared_error: 128.3353
# Epoch 37/400
# 10/10 [==============================] - 0s 3ms/step - loss: 37.7841 - mean_squared_error: 37.7841 - val_loss: 126.2732 - val_mean_squared_error: 126.2732
# Epoch 38/400
# 10/10 [==============================] - 0s 4ms/step - loss: 36.6270 - mean_squared_error: 36.6270 - val_loss: 125.2111 - val_mean_squared_error: 125.2111
# Epoch 39/400
# 10/10 [==============================] - 0s 4ms/step - loss: 36.8592 - mean_squared_error: 36.8592 - val_loss: 122.7279 - val_mean_squared_error: 122.7279
# Epoch 40/400
# 10/10 [==============================] - 0s 3ms/step - loss: 37.1639 - mean_squared_error: 37.1639 - val_loss: 121.7109 - val_mean_squared_error: 121.7109
# Epoch 41/400
# 10/10 [==============================] - 0s 4ms/step - loss: 34.8512 - mean_squared_error: 34.8512 - val_loss: 118.8624 - val_mean_squared_error: 118.8624
# Epoch 42/400
# 10/10 [==============================] - 0s 4ms/step - loss: 33.1791 - mean_squared_error: 33.1791 - val_loss: 118.6655 - val_mean_squared_error: 118.6655
# Epoch 43/400
# 10/10 [==============================] - 0s 3ms/step - loss: 34.0476 - mean_squared_error: 34.0476 - val_loss: 117.2443 - val_mean_squared_error: 117.2443
# Epoch 44/400
# 10/10 [==============================] - 0s 3ms/step - loss: 31.4319 - mean_squared_error: 31.4319 - val_loss: 117.2408 - val_mean_squared_error: 117.2408
# Epoch 45/400
# 10/10 [==============================] - 0s 4ms/step - loss: 30.9361 - mean_squared_error: 30.9361 - val_loss: 115.0597 - val_mean_squared_error: 115.0597
# Epoch 46/400
# 10/10 [==============================] - 0s 4ms/step - loss: 30.2677 - mean_squared_error: 30.2677 - val_loss: 114.0986 - val_mean_squared_error: 114.0986
# Epoch 47/400
# 10/10 [==============================] - 0s 3ms/step - loss: 28.3160 - mean_squared_error: 28.3160 - val_loss: 111.3284 - val_mean_squared_error: 111.3284
# Epoch 48/400
# 10/10 [==============================] - 0s 3ms/step - loss: 28.2116 - mean_squared_error: 28.2116 - val_loss: 108.9655 - val_mean_squared_error: 108.9655
# Epoch 49/400
# 10/10 [==============================] - 0s 4ms/step - loss: 26.5156 - mean_squared_error: 26.5156 - val_loss: 106.8931 - val_mean_squared_error: 106.8931
# Epoch 50/400
# 10/10 [==============================] - 0s 3ms/step - loss: 27.5675 - mean_squared_error: 27.5675 - val_loss: 105.8192 - val_mean_squared_error: 105.8192
# Epoch 51/400
# 10/10 [==============================] - 0s 4ms/step - loss: 26.0405 - mean_squared_error: 26.0405 - val_loss: 104.4193 - val_mean_squared_error: 104.4193
# Epoch 52/400
# 10/10 [==============================] - 0s 3ms/step - loss: 24.2013 - mean_squared_error: 24.2013 - val_loss: 102.2935 - val_mean_squared_error: 102.2935
# Epoch 53/400
# 10/10 [==============================] - 0s 3ms/step - loss: 23.8218 - mean_squared_error: 23.8218 - val_loss: 101.5579 - val_mean_squared_error: 101.5579
# Epoch 54/400
# 10/10 [==============================] - 0s 3ms/step - loss: 20.7567 - mean_squared_error: 20.7567 - val_loss: 101.3927 - val_mean_squared_error: 101.3927
# Epoch 55/400
# 10/10 [==============================] - 0s 3ms/step - loss: 21.0130 - mean_squared_error: 21.0130 - val_loss: 99.6180 - val_mean_squared_error: 99.6180
# Epoch 56/400
# 10/10 [==============================] - 0s 4ms/step - loss: 23.4088 - mean_squared_error: 23.4088 - val_loss: 97.6440 - val_mean_squared_error: 97.6440
# Epoch 57/400
# 10/10 [==============================] - 0s 3ms/step - loss: 20.8197 - mean_squared_error: 20.8197 - val_loss: 95.8057 - val_mean_squared_error: 95.8057
# Epoch 58/400
# 10/10 [==============================] - 0s 3ms/step - loss: 18.6569 - mean_squared_error: 18.6569 - val_loss: 94.2539 - val_mean_squared_error: 94.2539
# Epoch 59/400
# 10/10 [==============================] - 0s 3ms/step - loss: 20.2891 - mean_squared_error: 20.2891 - val_loss: 93.6916 - val_mean_squared_error: 93.6916
# Epoch 60/400
# 10/10 [==============================] - 0s 4ms/step - loss: 18.2104 - mean_squared_error: 18.2104 - val_loss: 92.7034 - val_mean_squared_error: 92.7034
# Epoch 61/400
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4469 - mean_squared_error: 18.4469 - val_loss: 93.4712 - val_mean_squared_error: 93.4712
# Epoch 62/400
# 10/10 [==============================] - 0s 3ms/step - loss: 16.8627 - mean_squared_error: 16.8627 - val_loss: 91.6530 - val_mean_squared_error: 91.6530
# Epoch 63/400
# 10/10 [==============================] - 0s 3ms/step - loss: 17.2184 - mean_squared_error: 17.2184 - val_loss: 91.1693 - val_mean_squared_error: 91.1693
# Epoch 64/400
# 10/10 [==============================] - 0s 3ms/step - loss: 16.5043 - mean_squared_error: 16.5043 - val_loss: 90.0557 - val_mean_squared_error: 90.0557
# Epoch 65/400
# 10/10 [==============================] - 0s 3ms/step - loss: 14.8614 - mean_squared_error: 14.8614 - val_loss: 86.7729 - val_mean_squared_error: 86.7729
# Epoch 66/400
# 10/10 [==============================] - 0s 3ms/step - loss: 13.6678 - mean_squared_error: 13.6678 - val_loss: 85.1085 - val_mean_squared_error: 85.1085
# Epoch 67/400
# 10/10 [==============================] - 0s 5ms/step - loss: 15.3619 - mean_squared_error: 15.3619 - val_loss: 84.8919 - val_mean_squared_error: 84.8919
# Epoch 68/400
# 10/10 [==============================] - 0s 3ms/step - loss: 14.0974 - mean_squared_error: 14.0974 - val_loss: 83.4315 - val_mean_squared_error: 83.4315
# Epoch 69/400
# 10/10 [==============================] - 0s 4ms/step - loss: 13.6056 - mean_squared_error: 13.6056 - val_loss: 81.9143 - val_mean_squared_error: 81.9143
# Epoch 70/400
# 10/10 [==============================] - 0s 3ms/step - loss: 12.0722 - mean_squared_error: 12.0722 - val_loss: 81.2940 - val_mean_squared_error: 81.2940
# Epoch 71/400
# 10/10 [==============================] - 0s 4ms/step - loss: 11.3318 - mean_squared_error: 11.3318 - val_loss: 79.8172 - val_mean_squared_error: 79.8172
# Epoch 72/400
# 10/10 [==============================] - 0s 3ms/step - loss: 11.6323 - mean_squared_error: 11.6323 - val_loss: 78.6181 - val_mean_squared_error: 78.6181
# Epoch 73/400
# 10/10 [==============================] - 0s 3ms/step - loss: 11.6396 - mean_squared_error: 11.6396 - val_loss: 78.4303 - val_mean_squared_error: 78.4303
# Epoch 74/400
# 10/10 [==============================] - 0s 3ms/step - loss: 10.4484 - mean_squared_error: 10.4484 - val_loss: 78.4743 - val_mean_squared_error: 78.4743
# Epoch 75/400
# 10/10 [==============================] - 0s 3ms/step - loss: 10.3227 - mean_squared_error: 10.3227 - val_loss: 77.3430 - val_mean_squared_error: 77.3430
# Epoch 76/400
# 10/10 [==============================] - 0s 3ms/step - loss: 10.1422 - mean_squared_error: 10.1422 - val_loss: 77.3024 - val_mean_squared_error: 77.3024
# Epoch 77/400
# 10/10 [==============================] - 0s 3ms/step - loss: 9.5212 - mean_squared_error: 9.5212 - val_loss: 75.1503 - val_mean_squared_error: 75.1503
# Epoch 78/400
# 10/10 [==============================] - 0s 3ms/step - loss: 8.9560 - mean_squared_error: 8.9560 - val_loss: 74.9270 - val_mean_squared_error: 74.9270
# Epoch 79/400
# 10/10 [==============================] - 0s 3ms/step - loss: 9.3885 - mean_squared_error: 9.3885 - val_loss: 72.9012 - val_mean_squared_error: 72.9012
# Epoch 80/400
# 10/10 [==============================] - 0s 4ms/step - loss: 9.0266 - mean_squared_error: 9.0266 - val_loss: 73.9282 - val_mean_squared_error: 73.9282
# Epoch 81/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.6478 - mean_squared_error: 7.6478 - val_loss: 72.0597 - val_mean_squared_error: 72.0597
# Epoch 82/400
# 10/10 [==============================] - 0s 3ms/step - loss: 7.7186 - mean_squared_error: 7.7186 - val_loss: 71.5282 - val_mean_squared_error: 71.5282
# Epoch 83/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.6163 - mean_squared_error: 6.6163 - val_loss: 70.7427 - val_mean_squared_error: 70.7427
# Epoch 84/400
# 10/10 [==============================] - 0s 3ms/step - loss: 7.4709 - mean_squared_error: 7.4709 - val_loss: 68.9907 - val_mean_squared_error: 68.9907
# Epoch 85/400
# 10/10 [==============================] - 0s 3ms/step - loss: 7.2619 - mean_squared_error: 7.2619 - val_loss: 68.2482 - val_mean_squared_error: 68.2482
# Epoch 86/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.4076 - mean_squared_error: 7.4076 - val_loss: 67.6164 - val_mean_squared_error: 67.6164
# Epoch 87/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.0272 - mean_squared_error: 6.0272 - val_loss: 66.7429 - val_mean_squared_error: 66.7429
# Epoch 88/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.7041 - mean_squared_error: 6.7041 - val_loss: 66.8331 - val_mean_squared_error: 66.8331
# Epoch 89/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.6209 - mean_squared_error: 6.6209 - val_loss: 66.3503 - val_mean_squared_error: 66.3503
# Epoch 90/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.4438 - mean_squared_error: 6.4438 - val_loss: 67.1369 - val_mean_squared_error: 67.1369
# Epoch 91/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.3112 - mean_squared_error: 6.3112 - val_loss: 65.7634 - val_mean_squared_error: 65.7634
# Epoch 92/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.2231 - mean_squared_error: 6.2231 - val_loss: 64.8132 - val_mean_squared_error: 64.8132
# Epoch 93/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.0827 - mean_squared_error: 6.0827 - val_loss: 63.9271 - val_mean_squared_error: 63.9271
# Epoch 94/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.1409 - mean_squared_error: 6.1409 - val_loss: 63.5839 - val_mean_squared_error: 63.5839
# Epoch 95/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.1050 - mean_squared_error: 6.1050 - val_loss: 64.2433 - val_mean_squared_error: 64.2433
# Epoch 96/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.2815 - mean_squared_error: 6.2815 - val_loss: 64.3639 - val_mean_squared_error: 64.3639
# Epoch 97/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.9185 - mean_squared_error: 5.9185 - val_loss: 63.4640 - val_mean_squared_error: 63.4640
# Epoch 98/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.6268 - mean_squared_error: 5.6268 - val_loss: 62.6169 - val_mean_squared_error: 62.6169
# Epoch 99/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.4229 - mean_squared_error: 6.4229 - val_loss: 62.3180 - val_mean_squared_error: 62.3180
# Epoch 100/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.9146 - mean_squared_error: 5.9146 - val_loss: 60.9915 - val_mean_squared_error: 60.9915
# Epoch 101/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.1750 - mean_squared_error: 6.1750 - val_loss: 61.5709 - val_mean_squared_error: 61.5709
# Epoch 102/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.9928 - mean_squared_error: 5.9928 - val_loss: 61.5069 - val_mean_squared_error: 61.5069
# Epoch 103/400
# 10/10 [==============================] - 0s 3ms/step - loss: 6.1983 - mean_squared_error: 6.1983 - val_loss: 59.9172 - val_mean_squared_error: 59.9172
# Epoch 104/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.9990 - mean_squared_error: 5.9990 - val_loss: 61.1764 - val_mean_squared_error: 61.1764
# Epoch 105/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.6792 - mean_squared_error: 5.6792 - val_loss: 60.9435 - val_mean_squared_error: 60.9435
# Epoch 106/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.1880 - mean_squared_error: 5.1880 - val_loss: 59.5863 - val_mean_squared_error: 59.5863
# Epoch 107/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.4436 - mean_squared_error: 5.4436 - val_loss: 59.5758 - val_mean_squared_error: 59.5758
# Epoch 108/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.4403 - mean_squared_error: 5.4403 - val_loss: 57.8965 - val_mean_squared_error: 57.8965
# Epoch 109/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.1568 - mean_squared_error: 5.1568 - val_loss: 57.1678 - val_mean_squared_error: 57.1678
# Epoch 110/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.1769 - mean_squared_error: 5.1769 - val_loss: 58.1202 - val_mean_squared_error: 58.1202
# Epoch 111/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.2564 - mean_squared_error: 5.2564 - val_loss: 59.3313 - val_mean_squared_error: 59.3313
# Epoch 112/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.8153 - mean_squared_error: 4.8153 - val_loss: 59.6959 - val_mean_squared_error: 59.6959
# Epoch 113/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.4753 - mean_squared_error: 5.4753 - val_loss: 58.4729 - val_mean_squared_error: 58.4729
# Epoch 114/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.3461 - mean_squared_error: 5.3461 - val_loss: 57.6486 - val_mean_squared_error: 57.6486
# Epoch 115/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.1969 - mean_squared_error: 5.1969 - val_loss: 57.2103 - val_mean_squared_error: 57.2103
# Epoch 116/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.6886 - mean_squared_error: 5.6886 - val_loss: 58.5035 - val_mean_squared_error: 58.5035
# Epoch 117/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.8473 - mean_squared_error: 4.8473 - val_loss: 58.5242 - val_mean_squared_error: 58.5242
# Epoch 118/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.9312 - mean_squared_error: 4.9312 - val_loss: 55.8195 - val_mean_squared_error: 55.8195
# Epoch 119/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.2839 - mean_squared_error: 5.2839 - val_loss: 56.0730 - val_mean_squared_error: 56.0730
# Epoch 120/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.0017 - mean_squared_error: 5.0017 - val_loss: 56.5714 - val_mean_squared_error: 56.5714
# Epoch 121/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.6594 - mean_squared_error: 4.6594 - val_loss: 56.4493 - val_mean_squared_error: 56.4493
# Epoch 122/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.4270 - mean_squared_error: 5.4270 - val_loss: 56.2766 - val_mean_squared_error: 56.2766
# Epoch 123/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.0228 - mean_squared_error: 5.0228 - val_loss: 56.5527 - val_mean_squared_error: 56.5527
# Epoch 124/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.7515 - mean_squared_error: 4.7515 - val_loss: 55.1477 - val_mean_squared_error: 55.1477
# Epoch 125/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.5508 - mean_squared_error: 4.5508 - val_loss: 53.7601 - val_mean_squared_error: 53.7601
# Epoch 126/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.0536 - mean_squared_error: 5.0536 - val_loss: 56.3703 - val_mean_squared_error: 56.3703
# Epoch 127/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.7948 - mean_squared_error: 4.7948 - val_loss: 56.3877 - val_mean_squared_error: 56.3877
# Epoch 128/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3671 - mean_squared_error: 4.3671 - val_loss: 56.2306 - val_mean_squared_error: 56.2306
# Epoch 129/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.6232 - mean_squared_error: 4.6232 - val_loss: 54.9049 - val_mean_squared_error: 54.9049
# Epoch 130/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.3626 - mean_squared_error: 4.3626 - val_loss: 54.4599 - val_mean_squared_error: 54.4599
# Epoch 131/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.6798 - mean_squared_error: 4.6798 - val_loss: 53.0960 - val_mean_squared_error: 53.0960
# Epoch 132/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.2294 - mean_squared_error: 5.2294 - val_loss: 52.8115 - val_mean_squared_error: 52.8115
# Epoch 133/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.6302 - mean_squared_error: 4.6302 - val_loss: 54.6399 - val_mean_squared_error: 54.6399
# Epoch 134/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.7509 - mean_squared_error: 4.7509 - val_loss: 54.5909 - val_mean_squared_error: 54.5909
# Epoch 135/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2837 - mean_squared_error: 4.2837 - val_loss: 53.1653 - val_mean_squared_error: 53.1653
# Epoch 136/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.8062 - mean_squared_error: 4.8062 - val_loss: 52.7946 - val_mean_squared_error: 52.7946
# Epoch 137/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.4411 - mean_squared_error: 4.4411 - val_loss: 54.2134 - val_mean_squared_error: 54.2134
# Epoch 138/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.3175 - mean_squared_error: 5.3175 - val_loss: 53.2325 - val_mean_squared_error: 53.2325
# Epoch 139/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.5441 - mean_squared_error: 4.5441 - val_loss: 52.5189 - val_mean_squared_error: 52.5189
# Epoch 140/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.0308 - mean_squared_error: 4.0308 - val_loss: 51.7245 - val_mean_squared_error: 51.7245
# Epoch 141/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.5078 - mean_squared_error: 4.5078 - val_loss: 53.3795 - val_mean_squared_error: 53.3795
# Epoch 142/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2914 - mean_squared_error: 4.2914 - val_loss: 53.1934 - val_mean_squared_error: 53.1934
# Epoch 143/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.5737 - mean_squared_error: 4.5737 - val_loss: 52.0506 - val_mean_squared_error: 52.0506
# Epoch 144/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.3371 - mean_squared_error: 4.3371 - val_loss: 51.0353 - val_mean_squared_error: 51.0353
# Epoch 145/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.3022 - mean_squared_error: 4.3022 - val_loss: 51.3491 - val_mean_squared_error: 51.3491
# Epoch 146/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.8120 - mean_squared_error: 4.8120 - val_loss: 52.0800 - val_mean_squared_error: 52.0800
# Epoch 147/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.9650 - mean_squared_error: 4.9650 - val_loss: 53.3937 - val_mean_squared_error: 53.3937
# Epoch 148/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.4402 - mean_squared_error: 4.4402 - val_loss: 51.9410 - val_mean_squared_error: 51.9410
# Epoch 149/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.5801 - mean_squared_error: 4.5801 - val_loss: 50.2036 - val_mean_squared_error: 50.2036
# Epoch 150/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.5938 - mean_squared_error: 4.5938 - val_loss: 49.8715 - val_mean_squared_error: 49.8715
# Epoch 151/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.0480 - mean_squared_error: 4.0480 - val_loss: 52.7910 - val_mean_squared_error: 52.7910
# Epoch 152/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.2082 - mean_squared_error: 4.2082 - val_loss: 51.0412 - val_mean_squared_error: 51.0412
# Epoch 153/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.9596 - mean_squared_error: 3.9596 - val_loss: 50.6641 - val_mean_squared_error: 50.6641
# Epoch 154/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.0348 - mean_squared_error: 4.0348 - val_loss: 49.7186 - val_mean_squared_error: 49.7186
# Epoch 155/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.2395 - mean_squared_error: 4.2395 - val_loss: 50.4407 - val_mean_squared_error: 50.4407
# Epoch 156/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.2057 - mean_squared_error: 4.2057 - val_loss: 48.7933 - val_mean_squared_error: 48.7933
# Epoch 157/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.4093 - mean_squared_error: 4.4093 - val_loss: 49.1096 - val_mean_squared_error: 49.1096
# Epoch 158/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.0992 - mean_squared_error: 4.0992 - val_loss: 48.2788 - val_mean_squared_error: 48.2788
# Epoch 159/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9536 - mean_squared_error: 3.9536 - val_loss: 49.6823 - val_mean_squared_error: 49.6823
# Epoch 160/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.0569 - mean_squared_error: 4.0569 - val_loss: 51.2875 - val_mean_squared_error: 51.2875
# Epoch 161/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.9571 - mean_squared_error: 3.9571 - val_loss: 48.8155 - val_mean_squared_error: 48.8155
# Epoch 162/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.9904 - mean_squared_error: 3.9904 - val_loss: 47.7058 - val_mean_squared_error: 47.7058
# Epoch 163/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.0101 - mean_squared_error: 4.0101 - val_loss: 48.9899 - val_mean_squared_error: 48.9899
# Epoch 164/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4381 - mean_squared_error: 3.4381 - val_loss: 48.8286 - val_mean_squared_error: 48.8286
# Epoch 165/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.0960 - mean_squared_error: 4.0960 - val_loss: 48.6479 - val_mean_squared_error: 48.6479
# Epoch 166/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.5705 - mean_squared_error: 3.5705 - val_loss: 48.4091 - val_mean_squared_error: 48.4091
# Epoch 167/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.1475 - mean_squared_error: 4.1475 - val_loss: 47.7575 - val_mean_squared_error: 47.7575
# Epoch 168/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.7912 - mean_squared_error: 3.7912 - val_loss: 48.2313 - val_mean_squared_error: 48.2313
# Epoch 169/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.8056 - mean_squared_error: 3.8056 - val_loss: 48.4165 - val_mean_squared_error: 48.4165
# Epoch 170/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.0282 - mean_squared_error: 4.0282 - val_loss: 47.3276 - val_mean_squared_error: 47.3276
# Epoch 171/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6110 - mean_squared_error: 3.6110 - val_loss: 47.5551 - val_mean_squared_error: 47.5551
# Epoch 172/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6214 - mean_squared_error: 3.6214 - val_loss: 47.3639 - val_mean_squared_error: 47.3639
# Epoch 173/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8854 - mean_squared_error: 3.8854 - val_loss: 46.9769 - val_mean_squared_error: 46.9769
# Epoch 174/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6742 - mean_squared_error: 3.6742 - val_loss: 48.2809 - val_mean_squared_error: 48.2809
# Epoch 175/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7420 - mean_squared_error: 3.7420 - val_loss: 47.8632 - val_mean_squared_error: 47.8632
# Epoch 176/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.4710 - mean_squared_error: 3.4710 - val_loss: 45.7923 - val_mean_squared_error: 45.7923
# Epoch 177/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.5148 - mean_squared_error: 3.5148 - val_loss: 45.9935 - val_mean_squared_error: 45.9935
# Epoch 178/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1421 - mean_squared_error: 3.1421 - val_loss: 47.3127 - val_mean_squared_error: 47.3127
# Epoch 179/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.5590 - mean_squared_error: 3.5590 - val_loss: 46.9821 - val_mean_squared_error: 46.9821
# Epoch 180/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0478 - mean_squared_error: 3.0478 - val_loss: 45.8808 - val_mean_squared_error: 45.8808
# Epoch 181/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.4324 - mean_squared_error: 3.4324 - val_loss: 46.6846 - val_mean_squared_error: 46.6846
# Epoch 182/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6965 - mean_squared_error: 3.6965 - val_loss: 47.6407 - val_mean_squared_error: 47.6407
# Epoch 183/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5790 - mean_squared_error: 3.5790 - val_loss: 46.4308 - val_mean_squared_error: 46.4308
# Epoch 184/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1728 - mean_squared_error: 3.1728 - val_loss: 44.9711 - val_mean_squared_error: 44.9711
# Epoch 185/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1375 - mean_squared_error: 3.1375 - val_loss: 44.9254 - val_mean_squared_error: 44.9254
# Epoch 186/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0569 - mean_squared_error: 3.0569 - val_loss: 45.8114 - val_mean_squared_error: 45.8114
# Epoch 187/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2250 - mean_squared_error: 3.2250 - val_loss: 45.4556 - val_mean_squared_error: 45.4556
# Epoch 188/400
# 10/10 [==============================] - 0s 6ms/step - loss: 2.8682 - mean_squared_error: 2.8682 - val_loss: 45.3829 - val_mean_squared_error: 45.3829
# Epoch 189/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9932 - mean_squared_error: 2.9932 - val_loss: 46.1051 - val_mean_squared_error: 46.1051
# Epoch 190/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2543 - mean_squared_error: 3.2543 - val_loss: 44.7721 - val_mean_squared_error: 44.7721
# Epoch 191/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9471 - mean_squared_error: 2.9471 - val_loss: 45.5972 - val_mean_squared_error: 45.5972
# Epoch 192/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9800 - mean_squared_error: 2.9800 - val_loss: 45.5663 - val_mean_squared_error: 45.5663
# Epoch 193/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1911 - mean_squared_error: 3.1911 - val_loss: 43.5820 - val_mean_squared_error: 43.5820
# Epoch 194/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.9471 - mean_squared_error: 2.9471 - val_loss: 45.1330 - val_mean_squared_error: 45.1330
# Epoch 195/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7149 - mean_squared_error: 2.7149 - val_loss: 44.2185 - val_mean_squared_error: 44.2185
# Epoch 196/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0453 - mean_squared_error: 3.0453 - val_loss: 43.0008 - val_mean_squared_error: 43.0008
# Epoch 197/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2620 - mean_squared_error: 3.2620 - val_loss: 44.3539 - val_mean_squared_error: 44.3539
# Epoch 198/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.7519 - mean_squared_error: 2.7519 - val_loss: 44.2710 - val_mean_squared_error: 44.2710
# Epoch 199/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.3202 - mean_squared_error: 3.3202 - val_loss: 43.3173 - val_mean_squared_error: 43.3173
# Epoch 200/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.7733 - mean_squared_error: 2.7733 - val_loss: 42.3900 - val_mean_squared_error: 42.3900
# Epoch 201/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8405 - mean_squared_error: 2.8405 - val_loss: 43.6028 - val_mean_squared_error: 43.6028
# Epoch 202/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.9911 - mean_squared_error: 2.9911 - val_loss: 45.1382 - val_mean_squared_error: 45.1382
# Epoch 203/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0907 - mean_squared_error: 3.0907 - val_loss: 43.3550 - val_mean_squared_error: 43.3550
# Epoch 204/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0671 - mean_squared_error: 3.0671 - val_loss: 43.3660 - val_mean_squared_error: 43.3660
# Epoch 205/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.7021 - mean_squared_error: 2.7021 - val_loss: 43.8127 - val_mean_squared_error: 43.8127
# Epoch 206/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8340 - mean_squared_error: 2.8340 - val_loss: 42.7265 - val_mean_squared_error: 42.7265
# Epoch 207/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.9640 - mean_squared_error: 2.9640 - val_loss: 42.8265 - val_mean_squared_error: 42.8265
# Epoch 208/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7903 - mean_squared_error: 2.7903 - val_loss: 42.7976 - val_mean_squared_error: 42.7976
# Epoch 209/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4852 - mean_squared_error: 2.4852 - val_loss: 43.8574 - val_mean_squared_error: 43.8574
# Epoch 210/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5547 - mean_squared_error: 2.5547 - val_loss: 41.6946 - val_mean_squared_error: 41.6946
# Epoch 211/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5229 - mean_squared_error: 2.5229 - val_loss: 42.1166 - val_mean_squared_error: 42.1166
# Epoch 212/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9171 - mean_squared_error: 2.9171 - val_loss: 41.7918 - val_mean_squared_error: 41.7918
# Epoch 213/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7850 - mean_squared_error: 2.7850 - val_loss: 42.4980 - val_mean_squared_error: 42.4980
# Epoch 214/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8115 - mean_squared_error: 2.8115 - val_loss: 41.2387 - val_mean_squared_error: 41.2387
# Epoch 215/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4938 - mean_squared_error: 2.4938 - val_loss: 41.6094 - val_mean_squared_error: 41.6094
# Epoch 216/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.3081 - mean_squared_error: 2.3081 - val_loss: 41.5777 - val_mean_squared_error: 41.5777
# Epoch 217/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.3970 - mean_squared_error: 2.3970 - val_loss: 41.5961 - val_mean_squared_error: 41.5961
# Epoch 218/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7771 - mean_squared_error: 2.7771 - val_loss: 41.5192 - val_mean_squared_error: 41.5192
# Epoch 219/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3475 - mean_squared_error: 2.3475 - val_loss: 41.8388 - val_mean_squared_error: 41.8388
# Epoch 220/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6681 - mean_squared_error: 2.6681 - val_loss: 39.9925 - val_mean_squared_error: 39.9925
# Epoch 221/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3172 - mean_squared_error: 2.3172 - val_loss: 40.4388 - val_mean_squared_error: 40.4388
# Epoch 222/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3443 - mean_squared_error: 2.3443 - val_loss: 42.0536 - val_mean_squared_error: 42.0536
# Epoch 223/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.6117 - mean_squared_error: 2.6117 - val_loss: 40.0395 - val_mean_squared_error: 40.0395
# Epoch 224/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5731 - mean_squared_error: 2.5731 - val_loss: 41.0370 - val_mean_squared_error: 41.0370
# Epoch 225/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4643 - mean_squared_error: 2.4643 - val_loss: 40.2028 - val_mean_squared_error: 40.2028
# Epoch 226/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.3132 - mean_squared_error: 2.3132 - val_loss: 39.8919 - val_mean_squared_error: 39.8919
# Epoch 227/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6738 - mean_squared_error: 2.6738 - val_loss: 40.5274 - val_mean_squared_error: 40.5274
# Epoch 228/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2396 - mean_squared_error: 2.2396 - val_loss: 38.8931 - val_mean_squared_error: 38.8931
# Epoch 229/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5763 - mean_squared_error: 2.5763 - val_loss: 39.4269 - val_mean_squared_error: 39.4269
# Epoch 230/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2316 - mean_squared_error: 2.2316 - val_loss: 39.5344 - val_mean_squared_error: 39.5344
# Epoch 231/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3193 - mean_squared_error: 2.3193 - val_loss: 39.4720 - val_mean_squared_error: 39.4720
# Epoch 232/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2868 - mean_squared_error: 2.2868 - val_loss: 39.3094 - val_mean_squared_error: 39.3094
# Epoch 233/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4294 - mean_squared_error: 2.4294 - val_loss: 38.9278 - val_mean_squared_error: 38.9278
# Epoch 234/400
# 10/10 [==============================] - ETA: 0s - loss: 2.6369 - mean_squared_error: 2.63 - 0s 3ms/step - loss: 2.2615 - mean_squared_error: 2.2615 - val_loss: 39.7692 - val_mean_squared_error: 39.7692
# Epoch 235/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2810 - mean_squared_error: 2.2810 - val_loss: 38.1967 - val_mean_squared_error: 38.1967
# Epoch 236/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4179 - mean_squared_error: 2.4179 - val_loss: 38.9260 - val_mean_squared_error: 38.9260
# Epoch 237/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2337 - mean_squared_error: 2.2337 - val_loss: 38.5689 - val_mean_squared_error: 38.5689
# Epoch 238/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2845 - mean_squared_error: 2.2845 - val_loss: 40.4120 - val_mean_squared_error: 40.4120
# Epoch 239/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5177 - mean_squared_error: 2.5177 - val_loss: 38.6170 - val_mean_squared_error: 38.6170
# Epoch 240/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0165 - mean_squared_error: 2.0165 - val_loss: 38.4353 - val_mean_squared_error: 38.4353
# Epoch 241/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2570 - mean_squared_error: 2.2570 - val_loss: 40.3036 - val_mean_squared_error: 40.3036
# Epoch 242/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0497 - mean_squared_error: 2.0497 - val_loss: 37.2511 - val_mean_squared_error: 37.2511
# Epoch 243/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4074 - mean_squared_error: 2.4074 - val_loss: 36.2050 - val_mean_squared_error: 36.2050
# Epoch 244/400
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9982 - mean_squared_error: 1.9982 - val_loss: 37.8149 - val_mean_squared_error: 37.8149
# Epoch 245/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1530 - mean_squared_error: 2.1530 - val_loss: 38.7136 - val_mean_squared_error: 38.7136
# Epoch 246/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4244 - mean_squared_error: 2.4244 - val_loss: 38.6444 - val_mean_squared_error: 38.6444
# Epoch 247/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0143 - mean_squared_error: 2.0143 - val_loss: 38.1995 - val_mean_squared_error: 38.1995
# Epoch 248/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2321 - mean_squared_error: 2.2321 - val_loss: 37.4248 - val_mean_squared_error: 37.4248
# Epoch 249/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1119 - mean_squared_error: 2.1119 - val_loss: 37.9348 - val_mean_squared_error: 37.9348
# Epoch 250/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0329 - mean_squared_error: 2.0329 - val_loss: 36.9711 - val_mean_squared_error: 36.9711
# Epoch 251/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1866 - mean_squared_error: 2.1866 - val_loss: 38.1368 - val_mean_squared_error: 38.1368
# Epoch 252/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0376 - mean_squared_error: 2.0376 - val_loss: 36.9871 - val_mean_squared_error: 36.9871
# Epoch 253/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0742 - mean_squared_error: 2.0742 - val_loss: 36.4514 - val_mean_squared_error: 36.4514
#
# Epoch 00253: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 254/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2746 - mean_squared_error: 2.2746 - val_loss: 36.5452 - val_mean_squared_error: 36.5452
# Epoch 255/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0453 - mean_squared_error: 2.0453 - val_loss: 36.6596 - val_mean_squared_error: 36.6596
# Epoch 256/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2334 - mean_squared_error: 2.2334 - val_loss: 36.8169 - val_mean_squared_error: 36.8169
# Epoch 257/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1164 - mean_squared_error: 2.1164 - val_loss: 37.4250 - val_mean_squared_error: 37.4250
# Epoch 258/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0597 - mean_squared_error: 2.0597 - val_loss: 37.1706 - val_mean_squared_error: 37.1706
# Epoch 259/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.3553 - mean_squared_error: 2.3553 - val_loss: 36.9043 - val_mean_squared_error: 36.9043
# Epoch 260/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2228 - mean_squared_error: 2.2228 - val_loss: 36.7611 - val_mean_squared_error: 36.7611
# Epoch 261/400
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9624 - mean_squared_error: 1.9624 - val_loss: 36.9710 - val_mean_squared_error: 36.9710
# Epoch 262/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2696 - mean_squared_error: 2.2696 - val_loss: 37.2737 - val_mean_squared_error: 37.2737
# Epoch 263/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0628 - mean_squared_error: 2.0628 - val_loss: 36.9449 - val_mean_squared_error: 36.9449
#
# Epoch 00263: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 264/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.3721 - mean_squared_error: 2.3721 - val_loss: 36.8701 - val_mean_squared_error: 36.8701
# Epoch 265/400
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9639 - mean_squared_error: 1.9639 - val_loss: 36.7731 - val_mean_squared_error: 36.7731
# Epoch 266/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1316 - mean_squared_error: 2.1316 - val_loss: 36.5879 - val_mean_squared_error: 36.5879
# Epoch 267/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0746 - mean_squared_error: 2.0746 - val_loss: 36.5025 - val_mean_squared_error: 36.5025
# Epoch 268/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8847 - mean_squared_error: 1.8847 - val_loss: 36.6405 - val_mean_squared_error: 36.6405
# Epoch 269/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1193 - mean_squared_error: 2.1193 - val_loss: 36.7700 - val_mean_squared_error: 36.7700
# Epoch 270/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2898 - mean_squared_error: 2.2898 - val_loss: 36.7160 - val_mean_squared_error: 36.7160
# Epoch 271/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9891 - mean_squared_error: 1.9891 - val_loss: 36.6663 - val_mean_squared_error: 36.6663
# Epoch 272/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9691 - mean_squared_error: 1.9691 - val_loss: 36.6830 - val_mean_squared_error: 36.6830
# Epoch 273/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2250 - mean_squared_error: 2.2250 - val_loss: 36.7210 - val_mean_squared_error: 36.7210
# Restoring model weights from the end of the best epoch.
# Epoch 00273: early stopping

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
predictions = model.predict([X_test])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test, predictions)))
# Out:
# Valeur d'erreur moyenne:
#  9.498251869460775
