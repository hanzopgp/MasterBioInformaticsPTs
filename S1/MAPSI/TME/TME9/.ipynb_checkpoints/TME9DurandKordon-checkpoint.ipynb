# %% [markdown]
# # Régression & optimisation par descente de gradient
#
# Ce tme a deux objectifs:
#  - acquérir les connaissances de base pour faire face au problème de la régression, c'est à dire de l'estimation d'un score réel correpondant à une situation,
#  - travailler sur les techniques d'optimisation par descente de gradient

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Génération de données jouet & construction d'une solution analytique
#
# Dans un premier temps, générons des données jouets paramétriques:
#  - $N$: nombre de points à générer
#  - $x \in [0, 1]$ tirage avec un simple rand() ou un linspace() -au choix-
#      - Si vous optez pour un tirage aléatoire des abscisses, triez les points pour simplifier les traitements ultérieurs
#  - $y=ax+b+\epsilon, \epsilon \sim \mathcal N(0,\sigma^2)$
#      - Rappel : en multipliant un tirage aléatoire selon une gaussienne centrée réduite par $\sigma$ on obtient le bruit décrit ci-dessus
#
# Afin de travailler sur les bonnes pratiques, nous distinguerons un ensemble d'apprentissage et un ensemble de test.
# Les deux sont tirés selon la même distribution. L'ensemble de test comptera -arbitrairement- 1000 points.

# %%
def gen_data_lin(a, b, sig, N=500, Ntest=1000):
    X_train = np.sort(np.random.rand(N)) # sort optionnel, mais ça aide pour les plots
    X_test  = np.sort(np.random.rand(Ntest))
    sig1 = np.random.normal(0,sig,size=(N))
    sig2 = np.random.normal(0,sig,size=(Ntest))
    Y_train = a * X_train + b + sig1
    Y_test  = a * X_test + b + sig2
    return X_train, Y_train, X_test, Y_test

# %%
# génération de données jouets:
a = 6.
b = -1.
N = 100
sig = .4 # écart type

X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)

plt.figure()
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_train, Y_train, 'b')
plt.show()

# %% [markdown]
# Vous devez obtenir quelque chose de la forme:<br>
# ![données jouet](fig/gen_data.png)

# %% [markdown]
# ## Validation des formules analytiques
# Nous avons vu deux types de résolutions analytique: à partir des estimateurs des espérances et co-variances d'une part et des moindres carrés d'autre part. Testons les deux méthodes.
#
# ### Estimation de paramètres probabilistes
#  - $\hat a = \frac{\mbox{cov}(X,Y)}{\sigma_x^2}$
#  - $\hat b = E(Y)−\frac{\mbox{cov}(X,Y)}{\sigma_x^2} E(X)$
#
#  Estimer les paramètres, calculer l'erreur au sens des moindres carrés sur les données d'apprentissage et de test, puis tracer la droite de régression

# %%
def modele_lin_analytique(X_train, Y_train):
    cov_xy = np.cov(X_train, Y_train)[0][1]
    cov_std2 = cov_xy / (X_train.std()**2)
    ahat = cov_std2
    bhat = Y_train.mean() - cov_std2 * X_train.mean()
    return ahat, bhat

ahat, bhat = modele_lin_analytique(X_train, Y_train)
print(ahat,"\n",bhat)
# Out:
# 6.100952657125159
#  -1.0373091468380693

# %%
def erreur_mc(y, yhat):
    return ((y-yhat)**2).mean()

yhat_train = ahat*X_train+bhat
yhat_test  = ahat*X_test +bhat

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat_train, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):', erreur_mc(yhat_test, Y_test))
# Out:
# Erreur moyenne au sens des moindres carrés (train): 0.146071387759373
# Erreur moyenne au sens des moindres carrés (test): 0.15339920943725882

# %%
plt.figure()
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_train, Y_train, 'b')
plt.plot(X_test, yhat_test, 'g', lw=3)

# %% [markdown]
# ## Formulation au sens des moindres carrés
#
# Nous partons directement sur une écriture matricielle. Du coup, il est nécessaire de construire la matrice enrichie $Xe$:
#     $$Xe = \left[\begin{array}{cc}
#                 X_0 & 1\\
#                 \vdots & \vdots\\
#                 X_N & 1
#                 \end{array}
#                 \right] $$
# Le code de la fonction d'enrichissement est donné ci-dessous.
#
# Il faut ensuite poser et résoudre un système d'équations linéaires de la forme:
# $$ A w = B $$
# **Rappel des formules vues en cours/TD:**
# $$ A=X^T X$$
# $$ B=X^T Y$$
# Fonction de résolution: `np.linalg.solve(A,B)`
# Vous devez obtenir la même solution que précédemment.

# %%
def make_mat_lin_biais(X): # fonctionne pour un vecteur unidimensionel X
    N = len(X)
    return np.hstack((X.reshape(N,1),np.ones((N,1))))

# %%
Xe = make_mat_lin_biais(X_train)
A = Xe.T @ Xe
B = Xe.T @ Y_train
w = np.linalg.solve(A,B)

print(w)
# Out:
# [ 6.03994313 -1.00412461]

# %% [markdown]
# Soit les données polynomiales générées avec la fonction ci-dessous
#  - proposer & une solution d'enrichissement (vue en cours et TD)
#  - résoudre analytiquement le problème des moindres carrés
#  - calculer l'erreur au sens des moindes carrés en apprentissage ET en test
#  - tracer les données et la solution

# %%
def gen_data_poly2(a, b, c, sig, N=500, Ntest=1000):
    '''
    Tire N points X aléatoirement entre 0 et 1 et génère y = ax^2 + bx + c + eps
    eps ~ N(0, sig^2)
    '''
    X_train = np.sort(np.random.rand(N))
    X_test  = np.sort(np.random.rand(Ntest))
    Y_train = a*X_train**2+b*X_train+c+np.random.randn(N)*sig
    Y_test  = a*X_test**2 +b*X_test +c+np.random.randn(Ntest)*sig
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = gen_data_poly2(10, -10, 5, 0.1, N=100, Ntest=100)
plt.figure()
plt.plot(X_train, Y_train)
plt.show()

# %%
def make_mat_poly_biais(X): # fonctionne pour un vecteur unidimensionel X
    N = len(X)
    tmp = np.hstack((X.reshape(N,1)**2,(X.reshape(N,1)))) # X**2, X
    return np.hstack((tmp, np.ones((N,1)))) # X**2, X, 1

Xe   = make_mat_poly_biais(X_train)
Xe_t = make_mat_poly_biais(X_test) 
A = Xe.T @ Xe
B = Xe.T @ Y_train
w = np.linalg.solve(A,B)

A_t = Xe_t.T @ Xe_t
B_t = Xe_t.T @ Y_test
w_t = np.linalg.solve(A_t,B_t)

print(w)

yhat   = X_train**2 * w[0]   + X_train * w[1]   + w[2]
yhat_t = X_test**2  * w_t[0] + X_test  * w_t[1] + w_t[2]
print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):', erreur_mc(yhat_t, Y_test))

plt.figure()
plt.plot(X_train, Y_train, 'b.')
plt.plot(X_train, yhat, 'r')
plt.show()
# Out:
# [ 9.9883531  -9.96945599  4.97318464]
# Erreur moyenne au sens des moindres carrés (train): 0.009315726049594871
# Erreur moyenne au sens des moindres carrés (test): 0.009687541435950707

# %% [markdown]
# # Fonction de coût & optimisation par descente de gradient
#
# Comme vu en TD et en cours, nous allons maintenant résoudre le problème de la régression par minimisation d'une fonction de coût:
# $$ C = \sum_{i=1}^N (y_i - f(x_i))$$
#
# Soit un problème avec des données $(x_i,y_i)_{i=1,\ldots,N}$, une fonction de décision/prédiction paramétrée par un vecteur $w$ et une fonction de cout à optimiser $C(w)$.
# Notre but est de trouver les paramètres $w^\star$ minimisant la fonction de coût:
# $$ w^\star = \arg\min_w C(w)$$
#
# l'algorithme de la descente de gradient est le suivant (rappel):
#
#  - $w_0 \leftarrow init$ par exemple : 0
#  - boucle
#      - $w_{t+1} \leftarrow w_{t} - \epsilon \nabla_w C(w_t)$
#
# Compléter le squelette d'implémentation fourni ci-dessous:

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)

# pour travailler en matrice: (re)construction de la matrice contenant les X et un biais
Xe = make_mat_lin_biais(X_train) # dataset linéaire, transformation lineaire des données
wstar = np.linalg.solve(Xe.T @ Xe, Xe.T @ Y_train)

def descente_grad_mc(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for i in range(nIterations):
        if i%(nIterations/10)==0:
            print(i*100/nIterations,"%")
        w = w - eps * 2 * X.T @ (X @ w - y)
        allw.append(w) # stockage de toutes les valeurs intermédiaires pour analyse
    allw = np.array(allw)
    return w, allw # la dernière valeur (meilleure) + tout l'historique pour le plot
    
w, allw = descente_grad_mc(Xe, Y_train, eps=1e-4, nIterations=10000)
print(wstar)
print(w)
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# [ 5.82792535 -0.96168419]
# [ 5.82792233 -0.96168259]

# %% [markdown]
# On s'intéresse ensuite à comprendre la descente de gradient dans l'espace des paramètres. Le code ci-dessous permet de tracer le cout pour un ensemble de paramètres (toutes les valeurs de paramètres prises par l'algorithmes au fil du temps).

# %%
# tracer de l'espace des couts
def plot_parametres( allw, X, y, opti = [], ngrid = 20, extract_bornes=False):
    '''
    Fonction de tracer d'un historique de coefficients
    ATTENTION: ca ne marche qu'en 2D (évidemment)
    Chaque w doit contenir 2 valeurs
    
    Il faut fournir les données (X,y) pour calculer le cout associé 
    à un jeu de paramètres w
    ATTENTION X = forme matricielle des données
    '''
    w_min = [-0.5, -2] # bornes par défaut, uniquement pour notre cas d'usage
    w_max = [8, 5]
    if extract_bornes: # bornes générales
        w_min = np.min(allw,0) # trouver les bornes
        w_max = np.max(allw,0)
    # faire une grille régulière avec tous les couples possibles entre le min et le max
    w1range = np.linspace(w_min[0], w_max[0], ngrid)
    w2range = np.linspace(w_min[1], w_max[1], ngrid)
    w1,w2 = np.meshgrid(w1range,w2range)
    # calcul de tous les couts associés à tous les couples de paramètres
    cost = np.array([[np.log(((X @ np.array([w1i,w2j])-y)**2).sum()) for w1i in w1range] for w2j in w2range])
    plt.figure()
    plt.contour(w1, w2, cost)
    if len(opti) > 0:
        plt.scatter(wstar[0], wstar[1],c='r')
    plt.plot(allw[:,0],allw[:,1],'b+-' ,lw=2 )
    return
    
plot_parametres(allw, Xe, Y_train, opti=wstar)
# plt.savefig('fig/grad_descente.png')

# %% [markdown]
# Vous devez obtenir un image de la forme :<br>
# ![Descente de gradient](fig/grad_descente.png)
#
# Tester différents jeux de paramètres pour mettre en évidence les phénomènes suivants:
#  - Divergence du gradient
#  - Convergence incomplète (trop lente ou pas assez d'itération)
#  - Convergence idéale: pas de gradient suffisamment grand et nombre d'itérations bien choisi

# %% [markdown]
# # Passage sur des données réelles
#
# Après avoir étudié trois manières de faire face au problème de la régression, nous proposons d'étudier un cas réel: la prédiction de la consommation des voitures en fonction de leurs caractéristiques.
#
# Dans le cas présent, nous allons baser la solution sur la résolution analytique du problème des moindres carrés (`np.linalg.solve(A,B)`), qui semble la mieux adaptée au problème qui nous intéresse.
#
# Le jeu de données est issu des datasets UCI, un répertoire parmi les plus connus en machine learning. Les données **sont déjà téléchargées et présentes dans le tme** mais vous voulez plus d'informations:
# https://archive.ics.uci.edu/ml/datasets/auto+mpg
#
# ![voiture](fig/Large9.jpg)
#
# Après avoir importé les données (fonction fournie), vous construirez une solution optimale et l'évaluerez au sens des moindres carrés en apprentissage et en test.

# %%
import pandas as pd
# Chargement des données
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) # comme np.loadtxt mais en plus robuste
# remplacement des données manquantes '?' => Nan pour travailler sur des nombres
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
# remplacement des valeurs manquantes par la moyenne
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())

print(data.head()) # visualiser ce qu'il y a dans les données

X = np.array(data.values[:,1:-2], dtype=np.float64)
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
# separation app/test
def separation_train_test(X, y, pc_train=0.75):
    napp = int(len(y)*pc_train) # nb de points pour le train
    X_train, Y_train = X[:napp], y[:napp]
    X_test, Y_test   = X[napp:], y[napp:]
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)

# %% [markdown]
# # Resolution analytique

# %%
def make_mat_lin_biais(X):
    N = X.shape[0]
    return np.hstack((X,np.ones((N,1)))) # ax + by + cz + ... + g ? ou ax² + by ... + g ?
    
def compute_yhat(X, w):
    res = w[0]
    N = X.shape[1]
    for i in range(1, N):
        res += X[:,i] * w[i]
    return res

def compute_w(X, y, linear):
    if(linear):
        Xe = make_mat_lin_biais(X)
    else:
        Xe = X
    A  = Xe.T @ Xe
    B  = Xe.T @ y
    w  = np.linalg.solve(A,B)
    return w
     
w   = compute_w(X_train, Y_train, linear=False)
w_t = compute_w(X_test , Y_test , linear=False)

print(w)

yhat   = compute_yhat(X_train, w)
yhat_t = compute_yhat(X_test , w_t)

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):',  erreur_mc(yhat_t, Y_test))
# Out:
# [-0.362168    0.00073902  0.00268987 -0.00563114 -0.01289395  0.54066773]
# Erreur moyenne au sens des moindres carrés (train): 10.661281449323736
# Erreur moyenne au sens des moindres carrés (test): 40.23068275181207

# %%
def plot_y(Y_train, Y_test, yhat, yhat_t):
    # tracé des prédictions:
    plt.figure()
    plt.subplot(211)
    plt.plot(Y_test, label="GT")
    plt.plot(yhat_t, label="pred")
    plt.title('En test')
    plt.legend()
    plt.subplot(212)
    plt.plot(Y_train, label="GT")
    plt.plot(yhat, label="pred")
    plt.title('En train')
    return

plot_y(Y_train, Y_test, yhat, yhat_t)

# %%
# interprétation des poids
plt.figure()
plt.bar(np.arange(len(w)), w)
plt.show()

# %% [markdown]
# # Résolution avec descente de gradient

# %%
def train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100, norm=False, grad="normal", encode=False, date_values_index=[], discrete_values_index=[]):
                
        if norm:
            Xn_train, Xn_test = normalisation(X_train, X_test)
        else:
            Xn_train, Xn_test = X_train, X_test
            
        if encode:
            Xn_train[:,date_values_index] = discretize_years(Xn_train[:,date_values_index], 10, date_values_index)
            Xn_test[:,date_values_index]  = discretize_years(Xn_test[:,date_values_index] , 10, date_values_index)
            Xn_train = encode_discrete_values(Xn_train, discrete_values_index)
            Xn_test  = encode_discrete_values(Xn_test , discrete_values_index)

        if norm:
            Xe_train = Xn_train
            Xe_test = Xn_test
        else:
            Xe_train = make_mat_lin_biais(Xn_train)
            Xe_test  = make_mat_lin_biais(Xn_test)
        
        if grad == "normal":
            w, _ = descente_grad_mc(Xe_train, Y_train, eps, nIterations)
        elif grad == "stoch":
            w, _ = descente_grad_mc_stoch(Xe_train, Y_train, eps, nIterations)
        elif grad == "momentum":
            w, _ = descente_grad_mc_stoch_mom(Xe_train, Y_train, eps, 0.9, nIterations)
        elif grad == "batch":
            w, _ = descente_grad_mc_stoch_batch(Xe_train, Y_train, eps, 20, nIterations)
        else:
            print("Pas de gradient ?")
                
        yhat   = Xe_train @ w
        yhat_t = Xe_test @ w

        print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
        print('Erreur moyenne au sens des moindres carrés (test):' , erreur_mc(yhat_t, Y_test))
        
        plot_y(Y_train, Y_test, yhat, yhat_t)
        
        plt.figure()
        plt.bar(np.arange(len(w)), w)
        plt.show()

# %%
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
train(X_train, X_test, Y_train, Y_test, eps=1e-6, nIterations=10, norm=False) # Gradient vanishing car pas de normalisation !
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 3.868530276071835e+78
# Erreur moyenne au sens des moindres carrés (test): 2.345811916660169e+78

# %% [markdown]
# ## Normalisation
#
# Sur le diagramme ci-dessus, on ne voit pas grand chose pour une raison évidente: on ne peut pas comparer ces poids qui comparent des variables dont les ordres de grandeur sont différents.
#
# Nous allons donc assimiler chaque colonne $X_j$ à une variable suivant une loi normale et nous allons revenir à une Normale centrée réduite selon la formule de base:
#
# $$X_j \sim \mathcal N(\mu_j, \sigma_j^2) $$
# $$\Rightarrow Z_j = \frac{X_j - \mu_j}{\sigma_j} \sim \mathcal N(0, 1) $$
#
# Tous les $Z_j$ sont comparables et nous seront en mesure de comprendre l'impact de chaque variables sur les résultats.
#
# **ATTENTION:** on ne se basera que sur les données d'apprentissage pour le calcul des $\{\mu_j, \sigma_j\}$.
#
# Une fois la normalisation effectuée, analyser l'impact des différentes variables descriptives sur la valeur à prédire.

# %%
def normalisation(X_train, X_test):
    '''
    Fonction de normalisation des données pour rendre les colonnes comparables
    Chaque variable sera assimilée à une loi normale qu'il faut centrer + réduire.
    ATTENTION: il faut calculer les moyennes et écarts-types sur les données d'apprentissage seulement
    '''
    stds     = X_train.std(axis=0)
    means    = X_train.mean(axis=0)
    stds_t   = X_test.std(axis=0)
    means_t  = X_test.mean(axis=0)
    Xn_train = (X_train - means)   / stds**2
    Xn_test  = (X_test  - means_t) / stds_t**2
    Xn_train = np.hstack((Xn_train, np.ones((Xn_train.shape[0], 1))))
    Xn_test  = np.hstack((Xn_test,  np.ones((Xn_test.shape [0], 1))))
    return Xn_train, Xn_test

Xn_train, Xn_test = normalisation(X_train, X_test)

w   = compute_w(Xn_train, Y_train, linear=False)
w_t = compute_w(Xn_test , Y_test , linear=False)

yhat   = compute_yhat(Xn_train, w  )
yhat_t = compute_yhat(Xn_test , w_t)

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):',  erreur_mc(yhat_t, Y_test))

plot_y(Y_train, Y_test, yhat, yhat_t)

plt.figure()
plt.bar(np.arange(len(w)), w)
plt.show()
# Out:
# Erreur moyenne au sens des moindres carrés (train): 9.197411943240763
# Erreur moyenne au sens des moindres carrés (test): 14.700511217891421

# %%
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=True) # Pourquoi un meilleur test que train ? Pourquoi besoin d'autant d'iterations ?
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 10.00581422002004
# Erreur moyenne au sens des moindres carrés (test): 206.60932167594763

# %%
X_train.shape
# Out:
# (298, 6)

# %% [markdown]
# # Questions d'ouverture
#
# ## Sélection de caractéristiques
#
# Quels sont les résultats obtenus en éliminant toutes les variables servent moins?
#
# ## Feature engineering
#
# En étudiant la signification des variables du problèmes, on trouve:
#
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
#
# D'après la question précédente, le poids, l'année du modèle et le biais sont des facteurs important pour le calcul de la consommation... Jusqu'ici, nous n'avons pas pris en compte l'origine qui était difficile à coder.
#
# ### Encodage de l'origine
#
# La variable origine est accessible de la manière suivante:
#
# ```
#   origine = data.values[:,-2]
# ```
# Il faut le faire au début du traitement pour bien conserver la séparation en l'apprentissage et le test.
#
# Au moins les deux derniers facteurs discrets pourraient être traités différemment en one-hot encoding:
# $$X_j = x \in \{1, \ldots, K\} \Rightarrow [0, 0, 1, 0] \in \{0, 1\}^K$$
#
# La valeur $x$ donne l'index de la colonne non nulle.
#
# ### Encodage de l'année
#
# Pour l'année, il est possible de procéder de la même manière, mais il préférable de découper les années en 10 catégories puis d'encoder pour limiter le nombre de dimensions.

# %%
# Rechargement des donnees
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) 
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())
print(data.head())

X = np.array(data.values[:,:-1], dtype=np.float64) # Cette fois on prend toutes les valeurs
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
# Index suivant le type de variable
discrete_values_index = np.array([1, 7])
date_values_index = np.array([6])
continuous_values_index = np.array([0, 2, 3, 4, 5])

# %%
# Traitement des variables discrete :
def one_hot_encoding(array):
    n = len(array)
    unique_values = np.unique(array)
    n_unique = len(unique_values)
    dic = {}
    for i in range(n_unique):
        dic[unique_values[i]] = i
    res = np.zeros((n, n_unique))
    for i in range(n):
        res[i][dic[array[i]]] = 1
    return res

def encode_discrete_values(X, index):
    for idx in index:
        encoding = one_hot_encoding(X[:,idx])
        X = np.delete(X, idx, 1)
        n = encoding.shape[1]
        for _ in range(n):
            X = np.hstack((X, np.zeros((X.shape[0], 1))))
        for i in range(X.shape[0]):
            for j in range(n):
                X[i][(X.shape[1]-n) + j] = encoding[i][j]
    return X                                  

# print(X[:,5:])
# X = encode_discrete_values(X, discrete_values_index)
# print(X[:,6:])

# %%
# Traitement de la variable date :
def discretize_years(array, n, index):
    array = np.sort(array)
    size = len(array)
    cpt = 0
    n_interval = size//n
    for i in range(1, size+1):
        array[i-1] = cpt
        if i%n_interval == 0:
            cpt += 1
    return array

# print(X[:,date_values_index])
# X = discretize_years(X[:,date_values_index], 10, date_values_index)
# print(X[:,date_values_index])

# %%
### Test avec toutes les features continues+discretes :
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
# 9. car name: string (unique for each instance)

X = np.array(data.values[:,:-1], dtype=np.float64)
# X = discretize_years(X[:,date_values_index], 10, date_values_index)
# X = encode_discrete_values(X, discrete_values_index)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True, encode=True, date_values_index=date_values_index, discrete_values_index=discrete_values_index)
# Out:
# (298, 8)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 6.203114515954615
# Erreur moyenne au sens des moindres carrés (test): 79.88341282758034

# %%
### Test avec toutes les features continues :
# 1. mpg: continuous
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous

index_to_delete = np.concatenate((discrete_values_index, date_values_index))
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True) # Resultat bien moins bon donc valeurs discrete one hot encoded importantes !
# Out:
# (298, 5)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 7.119738952721287
# Erreur moyenne au sens des moindres carrés (test): 127.16908733179729

# %%
### Test avec seulement les features :
# 1. mpg: continuous
# 6. acceleration: continuous

index_to_delete = [1,2,3,4,6,7]
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True) # Presque meme resultat qu'au dessus avec seulement 2 features
# Out:
# (298, 2)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 7.2185629585350775
# Erreur moyenne au sens des moindres carrés (test): 127.46374961047992

# %% [markdown]
# # Question d'ouverture sur le gradient
#
# ## La normalisation a-t-elle un impact sur le gradient?
#
# La normalisation des données peut au moins nous aider à régler plus facilement le pas (qui sera toujours du même ordre de grandeur... Mais cela a-t-il un impact sur la manière dont nous nous rapprochons de la solution optimale?
#
# ## Gradient stochastique
#
# Dans la plupart des algorithmes modernes d'optimisation liés aux réseaux de neurones, le gradient est calculé de manière stochastique, sur un exemple à la fois:
#
# - $w_0 \leftarrow init$ par exemple : 0
# - boucle
#      - tirage d'une donnée $i$: $(x_i,y_i)$
#      - $w_{t+1} \leftarrow w_{t} - \epsilon \nabla_w C_i(w)$
#
#
# Etudier le fonctionnement de cet algorithme sur les exemples jouets précédents.
#
# ## Amélioration du gradient
#
# Le blog de S. Ruder explique particulièrement bien les améliorations possibles sur les descentes de gradient.
#
# https://ruder.io/optimizing-gradient-descent/
#
# Comparer une descente de gradient stochastique avec et sans moment sur les données jouets des premières questions.

# %%
### Impact de la normalisation :
# La normalisation des données permet de ne pas avoir un gradient qui tend vers 0 ou vers de très grands nombres.
# Lors de la descente de gradient, si notre gradient prend des valeurs énormes, on pourrait rater un minimum local interessant.
# Dans le cas contraire, si le gradient prend des valeurs trop petite, on finit par avoir une perte d'information.

# %%
### Gradient stochastique :
def make_mat_lin_biais(X): # Redefinition de la fonction
    N = len(X)
    return np.hstack((X.reshape(N,1),np.ones((N,1))))

X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

# Gradient classique :
def descente_grad_mc(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for _ in range(nIterations):
        w = w - eps * 2 * X.T @ (X @ w - y)
        allw.append(w) # stockage de toutes les valeurs intermédiaires pour analyse
    allw = np.array(allw)
    return w, allw # la dernière valeur (meilleure) + tout l'historique pour le plot
    
w, allw = descente_grad_mc(Xe, Y_train, eps=1e-4, nIterations=100_000)
print(w)

plot_parametres(allw, Xe, Y_train, opti=wstar)

# Gradient stochastique :
def descente_grad_mc_stoch(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for _ in range(nIterations):
        rand = np.random.randint(X.shape[0])
        w = w - eps * 2 * X.T[:,rand] * (X[rand] @ w - y[rand])
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s, allw_s = descente_grad_mc_stoch(Xe, Y_train, eps=0.1, nIterations=1_000)
print(w_s)

plot_parametres(allw_s, Xe, Y_train, opti=wstar)

# Train avec gradient normal :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="normal")
# Train avec gradient stochastique :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Out:
# [ 6.10303081 -1.07352343]
# [ 6.13897236 -1.16783919]
# Erreur moyenne au sens des moindres carrés (train): 0.14862816172705995
# Erreur moyenne au sens des moindres carrés (test): 0.14542510751019952
# Erreur moyenne au sens des moindres carrés (train): 0.3353166112455625
# Erreur moyenne au sens des moindres carrés (test): 0.33274864426704287

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

### Amelioration du gradient :
# Gradient stochastique avec moment :
def descente_grad_mc_stoch_mom(X, y, eps=1e-4, gamma=0.9, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    value = w
    allw = [w]
    for i in range(nIterations):
        rand = np.random.randint(X.shape[0])
        gradient = eps * 2 * X.T[:,rand] * (X[rand] @ w - y[rand])
        new_value = (1-gamma) * gradient + gamma * value
        w = w - new_value
        value = new_value
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s_m, allw_s_m = descente_grad_mc_stoch_mom(Xe, Y_train, eps=0.1, nIterations=1_000)
print(w_s_m)

plot_parametres(allw_s_m, Xe, Y_train, opti=wstar)

# Train avec gradient sans moment :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Train avec gradient avec moment :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="momentum")
# Out:
# [ 6.08634754 -0.90465517]
# Erreur moyenne au sens des moindres carrés (train): 0.3259362294952676
# Erreur moyenne au sens des moindres carrés (test): 0.31437234452948953
# Erreur moyenne au sens des moindres carrés (train): 0.32559479119044804
# Erreur moyenne au sens des moindres carrés (test): 0.3141026570215343

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

### Amelioration du gradient :
# Gradient stochastique avec minibatch :
def descente_grad_mc_stoch_batch(X, y, eps=1e-4, n_batch=20, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    value = w
    allw = [w]
    for i in range(nIterations):
        rand = np.random.randint(X.shape[0]) - n_batch
        batch = X[rand:rand+n_batch]
        batch_t = batch.T
        batch_y = y[rand:rand+n_batch]
        gradient = eps * 2 * batch_t @ (batch @ w - batch_y)
        w = w - gradient
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s_b, allw_s_b = descente_grad_mc_stoch_batch(Xe, Y_train, eps=0.01, n_batch=20, nIterations=1_000)
print(w_s_b)

plot_parametres(allw_s_b, Xe, Y_train, opti=wstar)

# Train avec gradient stoch :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Train avec gradient avec batch :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="batch")
# Out:
# [ 5.95330953 -1.0128898 ]
# Erreur moyenne au sens des moindres carrés (train): 0.2848663519906632
# Erreur moyenne au sens des moindres carrés (test): 0.30923537416938884
# Erreur moyenne au sens des moindres carrés (train): 0.12108050187445416
# Erreur moyenne au sens des moindres carrés (test): 0.15508734020530118

# %% [markdown]
# # Exercice supplémentaire : regression avec multi layer perceptron

# %%
import tensorflow as tf

# %%
# Rechargement des donnees
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) 
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())
print(data.head())

X = np.array(data.values[:,:-1], dtype=np.float64)
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
index_to_delete = np.concatenate((discrete_values_index, date_values_index))
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)

# %%
TEST_SPLIT = 0.25
N_FEATURES = X.shape[1]
EPOCHS = 20
NB_NEURONS = 32
# DROPOUT_VALUE = 0.3

# %%
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=1-TEST_SPLIT)
print(X_train.shape)
# Out:
# (298, 5)

# %%
def norm(X):
    n,m = X.shape
    for i in range(n):
        for j in range(m):
            X[i][j] = (X[i][j] - X[:,j].min()) / (X[:,j].max() - X[:,j].min())
    return X

X_train_unnorm = X_train.copy()
X_test_unnorm = X_test.copy()

print(X_train.mean(axis=0))
X_train = norm(X_train)
X_test = norm(X_test)
print(X_train.mean(axis=0))
# Out:
# [  20.77013423  214.49832215  111.96979866 3130.23489933   15.22315436]
# [0.4993601  0.52790678 0.57298831 0.6737239  0.69030311]

# %% [markdown]
# # Descente de gradient stochastique

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="sgd", metrics=["mean_squared_error"]) # Fonction de loss moindre carres et optimisation par descente de gradient
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 78ms/step - loss: 362.0579 - mean_squared_error: 362.0579 - val_loss: 785.2466 - val_mean_squared_error: 785.2466
# Epoch 2/20
# 10/10 [==============================] - 0s 4ms/step - loss: 157.9094 - mean_squared_error: 157.9094 - val_loss: 136.7772 - val_mean_squared_error: 136.7772
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 53.1686 - mean_squared_error: 53.1686 - val_loss: 21.8715 - val_mean_squared_error: 21.8715
# Epoch 4/20
# 10/10 [==============================] - 0s 4ms/step - loss: 81.7140 - mean_squared_error: 81.7140 - val_loss: 144.7295 - val_mean_squared_error: 144.7295
# Epoch 5/20
# 10/10 [==============================] - 0s 4ms/step - loss: 24.1275 - mean_squared_error: 24.1275 - val_loss: 158.5733 - val_mean_squared_error: 158.5733
# Epoch 6/20
# 10/10 [==============================] - 0s 4ms/step - loss: 17.1773 - mean_squared_error: 17.1773 - val_loss: 132.4650 - val_mean_squared_error: 132.4650
# Epoch 7/20
# 10/10 [==============================] - 0s 4ms/step - loss: 8.0635 - mean_squared_error: 8.0635 - val_loss: 39.1364 - val_mean_squared_error: 39.1364
# Epoch 8/20
# 10/10 [==============================] - 0s 4ms/step - loss: 12.9603 - mean_squared_error: 12.9603 - val_loss: 65.8234 - val_mean_squared_error: 65.8234
# Epoch 9/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.0157 - mean_squared_error: 5.0157 - val_loss: 69.7707 - val_mean_squared_error: 69.7707
# Epoch 10/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2544 - mean_squared_error: 4.2544 - val_loss: 138.1871 - val_mean_squared_error: 138.1871
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 10.6909 - mean_squared_error: 10.6909 - val_loss: 109.7714 - val_mean_squared_error: 109.7714
# Epoch 12/20
# 10/10 [==============================] - 0s 4ms/step - loss: 8.7983 - mean_squared_error: 8.7983 - val_loss: 59.1141 - val_mean_squared_error: 59.1141
# Epoch 13/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.4271 - mean_squared_error: 4.4271 - val_loss: 60.6673 - val_mean_squared_error: 60.6673
# Epoch 14/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9117 - mean_squared_error: 2.9117 - val_loss: 134.1164 - val_mean_squared_error: 134.1164
# Epoch 15/20
# 10/10 [==============================] - 0s 4ms/step - loss: 10.3927 - mean_squared_error: 10.3927 - val_loss: 47.7944 - val_mean_squared_error: 47.7944
# Epoch 16/20
# 10/10 [==============================] - 0s 5ms/step - loss: 2.7540 - mean_squared_error: 2.7540 - val_loss: 74.3685 - val_mean_squared_error: 74.3685
# Epoch 17/20
# 10/10 [==============================] - 0s 5ms/step - loss: 9.6472 - mean_squared_error: 9.6472 - val_loss: 74.1600 - val_mean_squared_error: 74.1600
# Epoch 18/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2773 - mean_squared_error: 3.2773 - val_loss: 53.7966 - val_mean_squared_error: 53.7966
# Epoch 19/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9350 - mean_squared_error: 2.9350 - val_loss: 15.5509 - val_mean_squared_error: 15.5509
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 45.7706 - mean_squared_error: 45.7706 - val_loss: 38.2312 - val_mean_squared_error: 38.2312

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
sample=10
predictions = model.predict([X_test])
print("Valeurs en entree normalisees:\n", X_test[:sample])
print("Valeurs en entree non-normalisees:\n", X_test_unnorm[:sample])
print("Valeurs reelle en sortie:\n", Y_test[:sample])
print("Valeurs predit en sortie:\n", predictions[:sample])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test[:sample], predictions[:sample])))
# Out:
# Valeurs en entree normalisees:
#  [[0.1862069  1.         0.91666667 1.         0.45185185]
#  [0.5820208  0.40114613 0.53464717 0.85633727 1.        ]
#  [0.51092125 0.74256209 0.68052419 0.91810198 0.9006135 ]
#  [0.73283804 0.29919679 0.52839285 0.59050989 0.52791411]
#  [0.73930163 0.29940109 0.52841529 0.57711417 0.59831288]
#  [0.68112927 0.24220935 0.49038426 0.54221095 0.77638037]
#  [0.79962853 0.25948755 0.52094758 0.57174974 0.59003067]
#  [0.60787519 0.43103483 0.68063172 0.71673729 0.64386503]
#  [0.61649331 0.4939355  0.87073189 0.69660013 0.44923313]
#  [0.57340267 0.4939355  0.87073189 0.72479216 0.51554333]]
# Valeurs en entree non-normalisees:
#  [[  23.   350.   125.  3900.    17.4]
#  [  27.2  141.    71.  3190.    24.8]
#  [  23.9  260.    90.  3420.    22.2]
#  [  34.2  105.    70.  2200.    13.2]
#  [  34.5  105.    70.  2150.    14.9]
#  [  31.8   85.    65.  2020.    19.2]
#  [  37.3   91.    69.  2130.    14.7]
#  [  28.4  151.    90.  2670.    16. ]
#  [  28.8  173.   115.  2595.    11.3]
#  [  26.8  173.   115.  2700.    12.9]]
# Valeurs reelle en sortie:
#  [23.  27.2 23.9 34.2 34.5 31.8 37.3 28.4 28.8 26.8]
# Valeurs predit en sortie:
#  [[12.862997]
#  [23.120481]
#  [17.589245]
#  [29.292196]
#  [29.509758]
#  [29.10154 ]
#  [31.403084]
#  [23.762556]
#  [22.846878]
#  [21.732685]]
# Valeur d'erreur moyenne:
#  9.00822739372916

# %% [markdown]
# # Adam avec custom learning rate

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", 
                  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2), # Je specifie la lr de départ sinon trop long pour 20 epochs
                  metrics=["mean_squared_error"]) # Fonction de loss moindre carres et optimisation par descente de gradient
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 0s 15ms/step - loss: 445.0718 - mean_squared_error: 445.0718 - val_loss: 861.2872 - val_mean_squared_error: 861.2872
# Epoch 2/20
# 10/10 [==============================] - 0s 4ms/step - loss: 322.4913 - mean_squared_error: 322.4913 - val_loss: 504.8399 - val_mean_squared_error: 504.8399
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 140.5219 - mean_squared_error: 140.5219 - val_loss: 124.2063 - val_mean_squared_error: 124.2063
# Epoch 4/20
# 10/10 [==============================] - 0s 4ms/step - loss: 75.0509 - mean_squared_error: 75.0509 - val_loss: 95.0056 - val_mean_squared_error: 95.0056
# Epoch 5/20
# 10/10 [==============================] - 0s 4ms/step - loss: 62.5716 - mean_squared_error: 62.5716 - val_loss: 171.9001 - val_mean_squared_error: 171.9001
# Epoch 6/20
# 10/10 [==============================] - 0s 4ms/step - loss: 48.7257 - mean_squared_error: 48.7257 - val_loss: 148.2417 - val_mean_squared_error: 148.2417
# Epoch 7/20
# 10/10 [==============================] - 0s 4ms/step - loss: 47.0416 - mean_squared_error: 47.0416 - val_loss: 103.7990 - val_mean_squared_error: 103.7990
# Epoch 8/20
# 10/10 [==============================] - 0s 4ms/step - loss: 43.6076 - mean_squared_error: 43.6076 - val_loss: 110.9190 - val_mean_squared_error: 110.9190
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 36.5451 - mean_squared_error: 36.5451 - val_loss: 111.7479 - val_mean_squared_error: 111.7479
# Epoch 10/20
# 10/10 [==============================] - 0s 4ms/step - loss: 29.1905 - mean_squared_error: 29.1905 - val_loss: 93.2432 - val_mean_squared_error: 93.2432
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 25.2378 - mean_squared_error: 25.2378 - val_loss: 91.2373 - val_mean_squared_error: 91.2373
# Epoch 12/20
# 10/10 [==============================] - 0s 4ms/step - loss: 21.4276 - mean_squared_error: 21.4276 - val_loss: 79.2627 - val_mean_squared_error: 79.2627
# Epoch 13/20
# 10/10 [==============================] - 0s 4ms/step - loss: 18.4248 - mean_squared_error: 18.4248 - val_loss: 77.7278 - val_mean_squared_error: 77.7278
# Epoch 14/20
# 10/10 [==============================] - 0s 4ms/step - loss: 12.1969 - mean_squared_error: 12.1969 - val_loss: 62.5970 - val_mean_squared_error: 62.5970
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 9.9372 - mean_squared_error: 9.9372 - val_loss: 61.5265 - val_mean_squared_error: 61.5265
# Epoch 16/20
# 10/10 [==============================] - 0s 4ms/step - loss: 6.6587 - mean_squared_error: 6.6587 - val_loss: 55.3057 - val_mean_squared_error: 55.3057
# Epoch 17/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.3438 - mean_squared_error: 5.3438 - val_loss: 53.0901 - val_mean_squared_error: 53.0901
# Epoch 18/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.3292 - mean_squared_error: 5.3292 - val_loss: 48.3078 - val_mean_squared_error: 48.3078
# Epoch 19/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.9046 - mean_squared_error: 4.9046 - val_loss: 49.5446 - val_mean_squared_error: 49.5446
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2929 - mean_squared_error: 4.2929 - val_loss: 45.5654 - val_mean_squared_error: 45.5654

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
sample=10
predictions = model.predict([X_test])
print("Valeurs en entree normalisees:\n", X_test[:sample])
print("Valeurs en entree non-normalisees:\n", X_test_unnorm[:sample])
print("Valeurs reelle en sortie:\n", Y_test[:sample])
print("Valeurs predit en sortie:\n", predictions[:sample])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test[:sample], predictions[:sample])))
# Out:
# Valeurs en entree normalisees:
#  [[0.1862069  1.         0.91666667 1.         0.45185185]
#  [0.5820208  0.40114613 0.53464717 0.85633727 1.        ]
#  [0.51092125 0.74256209 0.68052419 0.91810198 0.9006135 ]
#  [0.73283804 0.29919679 0.52839285 0.59050989 0.52791411]
#  [0.73930163 0.29940109 0.52841529 0.57711417 0.59831288]
#  [0.68112927 0.24220935 0.49038426 0.54221095 0.77638037]
#  [0.79962853 0.25948755 0.52094758 0.57174974 0.59003067]
#  [0.60787519 0.43103483 0.68063172 0.71673729 0.64386503]
#  [0.61649331 0.4939355  0.87073189 0.69660013 0.44923313]
#  [0.57340267 0.4939355  0.87073189 0.72479216 0.51554333]]
# Valeurs en entree non-normalisees:
#  [[  23.   350.   125.  3900.    17.4]
#  [  27.2  141.    71.  3190.    24.8]
#  [  23.9  260.    90.  3420.    22.2]
#  [  34.2  105.    70.  2200.    13.2]
#  [  34.5  105.    70.  2150.    14.9]
#  [  31.8   85.    65.  2020.    19.2]
#  [  37.3   91.    69.  2130.    14.7]
#  [  28.4  151.    90.  2670.    16. ]
#  [  28.8  173.   115.  2595.    11.3]
#  [  26.8  173.   115.  2700.    12.9]]
# Valeurs reelle en sortie:
#  [23.  27.2 23.9 34.2 34.5 31.8 37.3 28.4 28.8 26.8]
# Valeurs predit en sortie:
#  [[ 7.934813]
#  [26.064894]
#  [21.18963 ]
#  [25.851744]
#  [26.725298]
#  [27.706797]
#  [28.211695]
#  [23.253866]
#  [21.225386]
#  [20.902987]]
# Valeur d'erreur moyenne:
#  9.829412652780228

# %% [markdown]
# # Adam + optimisation learning rate + early stopping

# %%
EPOCHS = 400

# %%
def get_callbacks():   
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_mean_squared_error', factor=0.3, patience=10, verbose=1, mode="min", min_lr=1e-4)

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=30 , verbose=1, mode="min", restore_best_weights=True)
    
#     model_cp = ModelCheckpoint('model.h5', 
#                                  save_best_only = True, 
#                                  save_weights_only = True,
#                                  monitor = 'val_loss', 
#                                  mode = 'min', verbose = 1)

    return [early_stopping, reduce_lr]

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
#     model.add(tf.keras.layers.Dropout(DROPOUT_VALUE)) # Dropout pour eviter overfit
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="adam", metrics=["mean_squared_error"])
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test), callbacks=get_callbacks())
# Out:
# Epoch 1/400
# 10/10 [==============================] - 1s 16ms/step - loss: 451.9990 - mean_squared_error: 451.9990 - val_loss: 1007.5851 - val_mean_squared_error: 1007.5851
# Epoch 2/400
# 10/10 [==============================] - 0s 5ms/step - loss: 440.0331 - mean_squared_error: 440.0331 - val_loss: 996.4562 - val_mean_squared_error: 996.4562
# Epoch 3/400
# 10/10 [==============================] - 0s 4ms/step - loss: 438.8642 - mean_squared_error: 438.8642 - val_loss: 983.9354 - val_mean_squared_error: 983.9354
# Epoch 4/400
# 10/10 [==============================] - 0s 6ms/step - loss: 442.3824 - mean_squared_error: 442.3824 - val_loss: 969.7760 - val_mean_squared_error: 969.7760
# Epoch 5/400
# 10/10 [==============================] - 0s 5ms/step - loss: 443.4374 - mean_squared_error: 443.4374 - val_loss: 953.6331 - val_mean_squared_error: 953.6331
# Epoch 6/400
# 10/10 [==============================] - 0s 5ms/step - loss: 411.6472 - mean_squared_error: 411.6472 - val_loss: 934.9558 - val_mean_squared_error: 934.9558
# Epoch 7/400
# 10/10 [==============================] - 0s 5ms/step - loss: 395.3808 - mean_squared_error: 395.3808 - val_loss: 912.9219 - val_mean_squared_error: 912.9219
# Epoch 8/400
# 10/10 [==============================] - 0s 4ms/step - loss: 397.6521 - mean_squared_error: 397.6521 - val_loss: 886.3385 - val_mean_squared_error: 886.3385
# Epoch 9/400
# 10/10 [==============================] - 0s 4ms/step - loss: 373.0825 - mean_squared_error: 373.0825 - val_loss: 855.2555 - val_mean_squared_error: 855.2555
# Epoch 10/400
# 10/10 [==============================] - 0s 4ms/step - loss: 357.1955 - mean_squared_error: 357.1955 - val_loss: 820.3970 - val_mean_squared_error: 820.3970
# Epoch 11/400
# 10/10 [==============================] - 0s 4ms/step - loss: 332.3327 - mean_squared_error: 332.3327 - val_loss: 781.4139 - val_mean_squared_error: 781.4139
# Epoch 12/400
# 10/10 [==============================] - 0s 4ms/step - loss: 315.4704 - mean_squared_error: 315.4704 - val_loss: 738.8323 - val_mean_squared_error: 738.8323
# Epoch 13/400
# 10/10 [==============================] - 0s 4ms/step - loss: 304.5079 - mean_squared_error: 304.5079 - val_loss: 692.3714 - val_mean_squared_error: 692.3714
# Epoch 14/400
# 10/10 [==============================] - 0s 4ms/step - loss: 265.5674 - mean_squared_error: 265.5674 - val_loss: 643.6217 - val_mean_squared_error: 643.6217
# Epoch 15/400
# 10/10 [==============================] - 0s 4ms/step - loss: 242.2645 - mean_squared_error: 242.2645 - val_loss: 592.9438 - val_mean_squared_error: 592.9438
# Epoch 16/400
# 10/10 [==============================] - 0s 4ms/step - loss: 215.2765 - mean_squared_error: 215.2765 - val_loss: 541.4874 - val_mean_squared_error: 541.4874
# Epoch 17/400
# 10/10 [==============================] - 0s 4ms/step - loss: 193.4628 - mean_squared_error: 193.4628 - val_loss: 489.4391 - val_mean_squared_error: 489.4391
# Epoch 18/400
# 10/10 [==============================] - 0s 4ms/step - loss: 191.7326 - mean_squared_error: 191.7326 - val_loss: 438.7113 - val_mean_squared_error: 438.7113
# Epoch 19/400
# 10/10 [==============================] - 0s 5ms/step - loss: 147.9556 - mean_squared_error: 147.9556 - val_loss: 391.1132 - val_mean_squared_error: 391.1132
# Epoch 20/400
# 10/10 [==============================] - 0s 5ms/step - loss: 125.8266 - mean_squared_error: 125.8266 - val_loss: 346.3482 - val_mean_squared_error: 346.3482
# Epoch 21/400
# 10/10 [==============================] - 0s 5ms/step - loss: 113.0677 - mean_squared_error: 113.0677 - val_loss: 306.8689 - val_mean_squared_error: 306.8689
# Epoch 22/400
# 10/10 [==============================] - 0s 4ms/step - loss: 92.9806 - mean_squared_error: 92.9806 - val_loss: 272.7074 - val_mean_squared_error: 272.7074
# Epoch 23/400
# 10/10 [==============================] - 0s 4ms/step - loss: 92.0084 - mean_squared_error: 92.0084 - val_loss: 244.1249 - val_mean_squared_error: 244.1249
# Epoch 24/400
# 10/10 [==============================] - 0s 4ms/step - loss: 76.6129 - mean_squared_error: 76.6129 - val_loss: 219.8937 - val_mean_squared_error: 219.8937
# Epoch 25/400
# 10/10 [==============================] - 0s 4ms/step - loss: 70.1178 - mean_squared_error: 70.1178 - val_loss: 201.7365 - val_mean_squared_error: 201.7365
# Epoch 26/400
# 10/10 [==============================] - 0s 4ms/step - loss: 66.2137 - mean_squared_error: 66.2137 - val_loss: 187.7675 - val_mean_squared_error: 187.7675
# Epoch 27/400
# 10/10 [==============================] - 0s 4ms/step - loss: 71.0260 - mean_squared_error: 71.0260 - val_loss: 176.1402 - val_mean_squared_error: 176.1402
# Epoch 28/400
# 10/10 [==============================] - 0s 4ms/step - loss: 63.7382 - mean_squared_error: 63.7382 - val_loss: 169.6144 - val_mean_squared_error: 169.6144
# Epoch 29/400
# 10/10 [==============================] - 0s 4ms/step - loss: 66.5572 - mean_squared_error: 66.5572 - val_loss: 164.6385 - val_mean_squared_error: 164.6385
# Epoch 30/400
# 10/10 [==============================] - 0s 5ms/step - loss: 69.5550 - mean_squared_error: 69.5550 - val_loss: 162.3304 - val_mean_squared_error: 162.3304
# Epoch 31/400
# 10/10 [==============================] - 0s 5ms/step - loss: 63.4061 - mean_squared_error: 63.4061 - val_loss: 161.9137 - val_mean_squared_error: 161.9137
# Epoch 32/400
# 10/10 [==============================] - 0s 4ms/step - loss: 62.9944 - mean_squared_error: 62.9944 - val_loss: 160.3622 - val_mean_squared_error: 160.3622
# Epoch 33/400
# 10/10 [==============================] - 0s 5ms/step - loss: 63.0398 - mean_squared_error: 63.0398 - val_loss: 156.6684 - val_mean_squared_error: 156.6684
# Epoch 34/400
# 10/10 [==============================] - 0s 4ms/step - loss: 61.2049 - mean_squared_error: 61.2049 - val_loss: 154.7426 - val_mean_squared_error: 154.7426
# Epoch 35/400
# 10/10 [==============================] - 0s 4ms/step - loss: 61.8476 - mean_squared_error: 61.8476 - val_loss: 151.2295 - val_mean_squared_error: 151.2295
# Epoch 36/400
# 10/10 [==============================] - 0s 4ms/step - loss: 59.0361 - mean_squared_error: 59.0361 - val_loss: 151.5340 - val_mean_squared_error: 151.5340
# Epoch 37/400
# 10/10 [==============================] - 0s 4ms/step - loss: 58.6514 - mean_squared_error: 58.6514 - val_loss: 148.4839 - val_mean_squared_error: 148.4839
# Epoch 38/400
# 10/10 [==============================] - 0s 5ms/step - loss: 70.0054 - mean_squared_error: 70.0054 - val_loss: 146.0774 - val_mean_squared_error: 146.0774
# Epoch 39/400
# 10/10 [==============================] - 0s 4ms/step - loss: 60.9411 - mean_squared_error: 60.9411 - val_loss: 147.0789 - val_mean_squared_error: 147.0789
# Epoch 40/400
# 10/10 [==============================] - 0s 4ms/step - loss: 56.6756 - mean_squared_error: 56.6756 - val_loss: 147.5651 - val_mean_squared_error: 147.5651
# Epoch 41/400
# 10/10 [==============================] - 0s 4ms/step - loss: 57.6820 - mean_squared_error: 57.6820 - val_loss: 146.7578 - val_mean_squared_error: 146.7578
# Epoch 42/400
# 10/10 [==============================] - 0s 4ms/step - loss: 59.7740 - mean_squared_error: 59.7740 - val_loss: 145.0370 - val_mean_squared_error: 145.0370
# Epoch 43/400
# 10/10 [==============================] - 0s 3ms/step - loss: 54.1889 - mean_squared_error: 54.1889 - val_loss: 142.9795 - val_mean_squared_error: 142.9795
# Epoch 44/400
# 10/10 [==============================] - 0s 5ms/step - loss: 53.4404 - mean_squared_error: 53.4404 - val_loss: 143.3629 - val_mean_squared_error: 143.3629
# Epoch 45/400
# 10/10 [==============================] - 0s 6ms/step - loss: 53.3097 - mean_squared_error: 53.3097 - val_loss: 141.1766 - val_mean_squared_error: 141.1766
# Epoch 46/400
# 10/10 [==============================] - 0s 6ms/step - loss: 55.4558 - mean_squared_error: 55.4558 - val_loss: 139.2503 - val_mean_squared_error: 139.2503
# Epoch 47/400
# 10/10 [==============================] - 0s 5ms/step - loss: 52.2051 - mean_squared_error: 52.2051 - val_loss: 137.7683 - val_mean_squared_error: 137.7683
# Epoch 48/400
# 10/10 [==============================] - 0s 6ms/step - loss: 50.3712 - mean_squared_error: 50.3712 - val_loss: 136.0913 - val_mean_squared_error: 136.0913
# Epoch 49/400
# 10/10 [==============================] - 0s 5ms/step - loss: 50.1841 - mean_squared_error: 50.1841 - val_loss: 135.8792 - val_mean_squared_error: 135.8792
# Epoch 50/400
# 10/10 [==============================] - 0s 4ms/step - loss: 51.2038 - mean_squared_error: 51.2038 - val_loss: 132.9331 - val_mean_squared_error: 132.9331
# Epoch 51/400
# 10/10 [==============================] - 0s 4ms/step - loss: 49.6706 - mean_squared_error: 49.6706 - val_loss: 132.9049 - val_mean_squared_error: 132.9049
# Epoch 52/400
# 10/10 [==============================] - 0s 4ms/step - loss: 47.8525 - mean_squared_error: 47.8525 - val_loss: 132.2861 - val_mean_squared_error: 132.2861
# Epoch 53/400
# 10/10 [==============================] - 0s 4ms/step - loss: 51.3334 - mean_squared_error: 51.3334 - val_loss: 130.8201 - val_mean_squared_error: 130.8201
# Epoch 54/400
# 10/10 [==============================] - 0s 4ms/step - loss: 49.2983 - mean_squared_error: 49.2983 - val_loss: 129.8149 - val_mean_squared_error: 129.8149
# Epoch 55/400
# 10/10 [==============================] - 0s 4ms/step - loss: 50.2267 - mean_squared_error: 50.2267 - val_loss: 129.8272 - val_mean_squared_error: 129.8272
# Epoch 56/400
# 10/10 [==============================] - 0s 4ms/step - loss: 43.2782 - mean_squared_error: 43.2782 - val_loss: 127.1142 - val_mean_squared_error: 127.1142
# Epoch 57/400
# 10/10 [==============================] - 0s 4ms/step - loss: 44.0582 - mean_squared_error: 44.0582 - val_loss: 126.3658 - val_mean_squared_error: 126.3658
# Epoch 58/400
# 10/10 [==============================] - 0s 4ms/step - loss: 45.2703 - mean_squared_error: 45.2703 - val_loss: 124.6084 - val_mean_squared_error: 124.6084
# Epoch 59/400
# 10/10 [==============================] - 0s 5ms/step - loss: 43.1993 - mean_squared_error: 43.1993 - val_loss: 121.0639 - val_mean_squared_error: 121.0639
# Epoch 60/400
# 10/10 [==============================] - 0s 4ms/step - loss: 41.8579 - mean_squared_error: 41.8579 - val_loss: 119.2299 - val_mean_squared_error: 119.2299
# Epoch 61/400
# 10/10 [==============================] - 0s 5ms/step - loss: 40.6544 - mean_squared_error: 40.6544 - val_loss: 119.9459 - val_mean_squared_error: 119.9459
# Epoch 62/400
# 10/10 [==============================] - 0s 4ms/step - loss: 44.7787 - mean_squared_error: 44.7787 - val_loss: 119.2486 - val_mean_squared_error: 119.2486
# Epoch 63/400
# 10/10 [==============================] - 0s 5ms/step - loss: 40.7580 - mean_squared_error: 40.7580 - val_loss: 117.9680 - val_mean_squared_error: 117.9680
# Epoch 64/400
# 10/10 [==============================] - 0s 4ms/step - loss: 42.8223 - mean_squared_error: 42.8223 - val_loss: 118.9595 - val_mean_squared_error: 118.9595
# Epoch 65/400
# 10/10 [==============================] - 0s 5ms/step - loss: 39.5984 - mean_squared_error: 39.5984 - val_loss: 116.0464 - val_mean_squared_error: 116.0464
# Epoch 66/400
# 10/10 [==============================] - 0s 4ms/step - loss: 38.5954 - mean_squared_error: 38.5954 - val_loss: 113.6349 - val_mean_squared_error: 113.6349
# Epoch 67/400
# 10/10 [==============================] - 0s 4ms/step - loss: 39.6077 - mean_squared_error: 39.6077 - val_loss: 111.1400 - val_mean_squared_error: 111.1400
# Epoch 68/400
# 10/10 [==============================] - 0s 4ms/step - loss: 35.1279 - mean_squared_error: 35.1279 - val_loss: 109.7164 - val_mean_squared_error: 109.7164
# Epoch 69/400
# 10/10 [==============================] - 0s 4ms/step - loss: 36.5284 - mean_squared_error: 36.5284 - val_loss: 109.3861 - val_mean_squared_error: 109.3861
# Epoch 70/400
# 10/10 [==============================] - 0s 4ms/step - loss: 36.3972 - mean_squared_error: 36.3972 - val_loss: 109.5923 - val_mean_squared_error: 109.5923
# Epoch 71/400
# 10/10 [==============================] - 0s 4ms/step - loss: 34.8707 - mean_squared_error: 34.8707 - val_loss: 108.1786 - val_mean_squared_error: 108.1786
# Epoch 72/400
# 10/10 [==============================] - 0s 3ms/step - loss: 35.5808 - mean_squared_error: 35.5808 - val_loss: 105.3157 - val_mean_squared_error: 105.3157
# Epoch 73/400
# 10/10 [==============================] - 0s 4ms/step - loss: 35.5778 - mean_squared_error: 35.5778 - val_loss: 105.4356 - val_mean_squared_error: 105.4356
# Epoch 74/400
# 10/10 [==============================] - 0s 4ms/step - loss: 36.0512 - mean_squared_error: 36.0512 - val_loss: 103.8390 - val_mean_squared_error: 103.8390
# Epoch 75/400
# 10/10 [==============================] - 0s 4ms/step - loss: 36.0759 - mean_squared_error: 36.0759 - val_loss: 103.2712 - val_mean_squared_error: 103.2712
# Epoch 76/400
# 10/10 [==============================] - 0s 4ms/step - loss: 33.4367 - mean_squared_error: 33.4367 - val_loss: 103.1579 - val_mean_squared_error: 103.1579
# Epoch 77/400
# 10/10 [==============================] - 0s 4ms/step - loss: 31.7592 - mean_squared_error: 31.7592 - val_loss: 102.3891 - val_mean_squared_error: 102.3891
# Epoch 78/400
# 10/10 [==============================] - ETA: 0s - loss: 36.6353 - mean_squared_error: 36.63 - 0s 4ms/step - loss: 30.8281 - mean_squared_error: 30.8281 - val_loss: 100.6878 - val_mean_squared_error: 100.6878
# Epoch 79/400
# 10/10 [==============================] - 0s 4ms/step - loss: 29.9228 - mean_squared_error: 29.9228 - val_loss: 99.3521 - val_mean_squared_error: 99.3521
# Epoch 80/400
# 10/10 [==============================] - 0s 4ms/step - loss: 29.8230 - mean_squared_error: 29.8230 - val_loss: 98.9705 - val_mean_squared_error: 98.9705
# Epoch 81/400
# 10/10 [==============================] - 0s 4ms/step - loss: 27.0806 - mean_squared_error: 27.0806 - val_loss: 96.2389 - val_mean_squared_error: 96.2389
# Epoch 82/400
# 10/10 [==============================] - 0s 4ms/step - loss: 30.3129 - mean_squared_error: 30.3129 - val_loss: 96.4640 - val_mean_squared_error: 96.4640
# Epoch 83/400
# 10/10 [==============================] - 0s 4ms/step - loss: 25.7007 - mean_squared_error: 25.7007 - val_loss: 95.5654 - val_mean_squared_error: 95.5654
# Epoch 84/400
# 10/10 [==============================] - 0s 3ms/step - loss: 25.7627 - mean_squared_error: 25.7627 - val_loss: 93.1770 - val_mean_squared_error: 93.1770
# Epoch 85/400
# 10/10 [==============================] - 0s 4ms/step - loss: 25.1306 - mean_squared_error: 25.1306 - val_loss: 91.6989 - val_mean_squared_error: 91.6989
# Epoch 86/400
# 10/10 [==============================] - 0s 3ms/step - loss: 25.7898 - mean_squared_error: 25.7898 - val_loss: 91.6588 - val_mean_squared_error: 91.6588
# Epoch 87/400
# 10/10 [==============================] - 0s 4ms/step - loss: 23.6988 - mean_squared_error: 23.6988 - val_loss: 89.3301 - val_mean_squared_error: 89.3301
# Epoch 88/400
# 10/10 [==============================] - 0s 4ms/step - loss: 26.2604 - mean_squared_error: 26.2604 - val_loss: 89.5362 - val_mean_squared_error: 89.5362
# Epoch 89/400
# 10/10 [==============================] - 0s 4ms/step - loss: 24.6542 - mean_squared_error: 24.6542 - val_loss: 88.3057 - val_mean_squared_error: 88.3057
# Epoch 90/400
# 10/10 [==============================] - 0s 4ms/step - loss: 21.4456 - mean_squared_error: 21.4456 - val_loss: 87.2118 - val_mean_squared_error: 87.2118
# Epoch 91/400
# 10/10 [==============================] - 0s 4ms/step - loss: 22.0305 - mean_squared_error: 22.0305 - val_loss: 86.3760 - val_mean_squared_error: 86.3760
# Epoch 92/400
# 10/10 [==============================] - 0s 4ms/step - loss: 21.1305 - mean_squared_error: 21.1305 - val_loss: 86.0130 - val_mean_squared_error: 86.0130
# Epoch 93/400
# 10/10 [==============================] - 0s 4ms/step - loss: 20.6061 - mean_squared_error: 20.6061 - val_loss: 85.5152 - val_mean_squared_error: 85.5152
# Epoch 94/400
# 10/10 [==============================] - 0s 4ms/step - loss: 18.8654 - mean_squared_error: 18.8654 - val_loss: 81.6250 - val_mean_squared_error: 81.6250
# Epoch 95/400
# 10/10 [==============================] - 0s 4ms/step - loss: 20.4684 - mean_squared_error: 20.4684 - val_loss: 80.8346 - val_mean_squared_error: 80.8346
# Epoch 96/400
# 10/10 [==============================] - 0s 4ms/step - loss: 17.5164 - mean_squared_error: 17.5164 - val_loss: 80.4489 - val_mean_squared_error: 80.4489
# Epoch 97/400
# 10/10 [==============================] - 0s 4ms/step - loss: 18.5442 - mean_squared_error: 18.5442 - val_loss: 78.0021 - val_mean_squared_error: 78.0021
# Epoch 98/400
# 10/10 [==============================] - 0s 4ms/step - loss: 17.2329 - mean_squared_error: 17.2329 - val_loss: 77.2498 - val_mean_squared_error: 77.2498
# Epoch 99/400
# 10/10 [==============================] - 0s 4ms/step - loss: 17.2248 - mean_squared_error: 17.2248 - val_loss: 77.2671 - val_mean_squared_error: 77.2671
# Epoch 100/400
# 10/10 [==============================] - 0s 4ms/step - loss: 15.6940 - mean_squared_error: 15.6940 - val_loss: 76.2799 - val_mean_squared_error: 76.2799
# Epoch 101/400
# 10/10 [==============================] - 0s 4ms/step - loss: 16.6112 - mean_squared_error: 16.6112 - val_loss: 75.5221 - val_mean_squared_error: 75.5221
# Epoch 102/400
# 10/10 [==============================] - 0s 4ms/step - loss: 14.0915 - mean_squared_error: 14.0915 - val_loss: 73.3964 - val_mean_squared_error: 73.3964
# Epoch 103/400
# 10/10 [==============================] - 0s 4ms/step - loss: 13.8337 - mean_squared_error: 13.8337 - val_loss: 71.7881 - val_mean_squared_error: 71.7881
# Epoch 104/400
# 10/10 [==============================] - 0s 4ms/step - loss: 15.0299 - mean_squared_error: 15.0299 - val_loss: 70.4346 - val_mean_squared_error: 70.4346
# Epoch 105/400
# 10/10 [==============================] - 0s 4ms/step - loss: 11.5292 - mean_squared_error: 11.5292 - val_loss: 70.8410 - val_mean_squared_error: 70.8410
# Epoch 106/400
# 10/10 [==============================] - 0s 4ms/step - loss: 13.9705 - mean_squared_error: 13.9705 - val_loss: 66.1756 - val_mean_squared_error: 66.1756
# Epoch 107/400
# 10/10 [==============================] - 0s 4ms/step - loss: 12.7273 - mean_squared_error: 12.7273 - val_loss: 66.4619 - val_mean_squared_error: 66.4619
# Epoch 108/400
# 10/10 [==============================] - 0s 4ms/step - loss: 12.0495 - mean_squared_error: 12.0495 - val_loss: 65.3393 - val_mean_squared_error: 65.3393
# Epoch 109/400
# 10/10 [==============================] - ETA: 0s - loss: 6.8004 - mean_squared_error: 6.80 - 0s 4ms/step - loss: 10.7561 - mean_squared_error: 10.7561 - val_loss: 65.4709 - val_mean_squared_error: 65.4709
# Epoch 110/400
# 10/10 [==============================] - 0s 4ms/step - loss: 11.3170 - mean_squared_error: 11.3170 - val_loss: 64.5861 - val_mean_squared_error: 64.5861
# Epoch 111/400
# 10/10 [==============================] - 0s 4ms/step - loss: 10.9593 - mean_squared_error: 10.9593 - val_loss: 64.6149 - val_mean_squared_error: 64.6149
# Epoch 112/400
# 10/10 [==============================] - 0s 4ms/step - loss: 8.9947 - mean_squared_error: 8.9947 - val_loss: 62.7412 - val_mean_squared_error: 62.7412
# Epoch 113/400
# 10/10 [==============================] - 0s 4ms/step - loss: 10.3148 - mean_squared_error: 10.3148 - val_loss: 60.8854 - val_mean_squared_error: 60.8854
# Epoch 114/400
# 10/10 [==============================] - 0s 4ms/step - loss: 9.8194 - mean_squared_error: 9.8194 - val_loss: 60.9160 - val_mean_squared_error: 60.9160
# Epoch 115/400
# 10/10 [==============================] - 0s 4ms/step - loss: 9.0649 - mean_squared_error: 9.0649 - val_loss: 59.8272 - val_mean_squared_error: 59.8272
# Epoch 116/400
# 10/10 [==============================] - 0s 4ms/step - loss: 8.9941 - mean_squared_error: 8.9941 - val_loss: 58.5585 - val_mean_squared_error: 58.5585
# Epoch 117/400
# 10/10 [==============================] - 0s 4ms/step - loss: 8.6183 - mean_squared_error: 8.6183 - val_loss: 59.0947 - val_mean_squared_error: 59.0947
# Epoch 118/400
# 10/10 [==============================] - 0s 4ms/step - loss: 8.3048 - mean_squared_error: 8.3048 - val_loss: 57.3529 - val_mean_squared_error: 57.3529
# Epoch 119/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.6982 - mean_squared_error: 7.6982 - val_loss: 55.6988 - val_mean_squared_error: 55.6988
# Epoch 120/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.2385 - mean_squared_error: 7.2385 - val_loss: 55.6700 - val_mean_squared_error: 55.6700
# Epoch 121/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.4656 - mean_squared_error: 7.4656 - val_loss: 54.5168 - val_mean_squared_error: 54.5168
# Epoch 122/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.3615 - mean_squared_error: 6.3615 - val_loss: 55.0672 - val_mean_squared_error: 55.0672
# Epoch 123/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.7189 - mean_squared_error: 6.7189 - val_loss: 54.3323 - val_mean_squared_error: 54.3323
# Epoch 124/400
# 10/10 [==============================] - 0s 5ms/step - loss: 6.0015 - mean_squared_error: 6.0015 - val_loss: 53.3013 - val_mean_squared_error: 53.3013
# Epoch 125/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.3821 - mean_squared_error: 5.3821 - val_loss: 53.0338 - val_mean_squared_error: 53.0338
# Epoch 126/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.6916 - mean_squared_error: 5.6916 - val_loss: 52.4821 - val_mean_squared_error: 52.4821
# Epoch 127/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.6733 - mean_squared_error: 5.6733 - val_loss: 50.8118 - val_mean_squared_error: 50.8118
# Epoch 128/400
# 10/10 [==============================] - 0s 6ms/step - loss: 5.4905 - mean_squared_error: 5.4905 - val_loss: 49.4821 - val_mean_squared_error: 49.4821
# Epoch 129/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.1165 - mean_squared_error: 5.1165 - val_loss: 50.6142 - val_mean_squared_error: 50.6142
# Epoch 130/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.2142 - mean_squared_error: 5.2142 - val_loss: 50.1726 - val_mean_squared_error: 50.1726
# Epoch 131/400
# 10/10 [==============================] - 0s 5ms/step - loss: 4.9961 - mean_squared_error: 4.9961 - val_loss: 49.3709 - val_mean_squared_error: 49.3709
# Epoch 132/400
# 10/10 [==============================] - 0s 5ms/step - loss: 4.8409 - mean_squared_error: 4.8409 - val_loss: 48.6789 - val_mean_squared_error: 48.6789
# Epoch 133/400
# 10/10 [==============================] - 0s 5ms/step - loss: 4.5230 - mean_squared_error: 4.5230 - val_loss: 48.2823 - val_mean_squared_error: 48.2823
# Epoch 134/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.4078 - mean_squared_error: 4.4078 - val_loss: 47.1624 - val_mean_squared_error: 47.1624
# Epoch 135/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.5913 - mean_squared_error: 4.5913 - val_loss: 47.3316 - val_mean_squared_error: 47.3316
# Epoch 136/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3221 - mean_squared_error: 4.3221 - val_loss: 47.2940 - val_mean_squared_error: 47.2940
# Epoch 137/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.8235 - mean_squared_error: 4.8235 - val_loss: 46.0281 - val_mean_squared_error: 46.0281
# Epoch 138/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.0004 - mean_squared_error: 4.0004 - val_loss: 46.2320 - val_mean_squared_error: 46.2320
# Epoch 139/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2686 - mean_squared_error: 4.2686 - val_loss: 44.9294 - val_mean_squared_error: 44.9294
# Epoch 140/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2045 - mean_squared_error: 4.2045 - val_loss: 44.9419 - val_mean_squared_error: 44.9419
# Epoch 141/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.7320 - mean_squared_error: 4.7320 - val_loss: 44.8714 - val_mean_squared_error: 44.8714
# Epoch 142/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8163 - mean_squared_error: 3.8163 - val_loss: 45.6637 - val_mean_squared_error: 45.6637
# Epoch 143/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2725 - mean_squared_error: 4.2725 - val_loss: 44.7932 - val_mean_squared_error: 44.7932
# Epoch 144/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3873 - mean_squared_error: 4.3873 - val_loss: 43.4561 - val_mean_squared_error: 43.4561
# Epoch 145/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3373 - mean_squared_error: 4.3373 - val_loss: 43.9545 - val_mean_squared_error: 43.9545
# Epoch 146/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.1525 - mean_squared_error: 4.1525 - val_loss: 43.6747 - val_mean_squared_error: 43.6747
# Epoch 147/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8260 - mean_squared_error: 3.8260 - val_loss: 43.0214 - val_mean_squared_error: 43.0214
# Epoch 148/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3495 - mean_squared_error: 3.3495 - val_loss: 42.3261 - val_mean_squared_error: 42.3261
# Epoch 149/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2094 - mean_squared_error: 4.2094 - val_loss: 42.3122 - val_mean_squared_error: 42.3122
# Epoch 150/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6340 - mean_squared_error: 3.6340 - val_loss: 43.0334 - val_mean_squared_error: 43.0334
# Epoch 151/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.0754 - mean_squared_error: 4.0754 - val_loss: 42.7789 - val_mean_squared_error: 42.7789
# Epoch 152/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7581 - mean_squared_error: 3.7581 - val_loss: 43.0712 - val_mean_squared_error: 43.0712
# Epoch 153/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.1315 - mean_squared_error: 4.1315 - val_loss: 42.2803 - val_mean_squared_error: 42.2803
# Epoch 154/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4117 - mean_squared_error: 3.4117 - val_loss: 40.7247 - val_mean_squared_error: 40.7247
# Epoch 155/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9572 - mean_squared_error: 3.9572 - val_loss: 41.0514 - val_mean_squared_error: 41.0514
# Epoch 156/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7647 - mean_squared_error: 3.7647 - val_loss: 41.8530 - val_mean_squared_error: 41.8530
# Epoch 157/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8346 - mean_squared_error: 3.8346 - val_loss: 41.1621 - val_mean_squared_error: 41.1621
# Epoch 158/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6369 - mean_squared_error: 3.6369 - val_loss: 40.6403 - val_mean_squared_error: 40.6403
# Epoch 159/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4446 - mean_squared_error: 3.4446 - val_loss: 40.2107 - val_mean_squared_error: 40.2107
# Epoch 160/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6273 - mean_squared_error: 3.6273 - val_loss: 41.2170 - val_mean_squared_error: 41.2170
# Epoch 161/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.1895 - mean_squared_error: 4.1895 - val_loss: 40.0562 - val_mean_squared_error: 40.0562
# Epoch 162/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5565 - mean_squared_error: 3.5565 - val_loss: 39.6199 - val_mean_squared_error: 39.6199
# Epoch 163/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.0923 - mean_squared_error: 4.0923 - val_loss: 40.5554 - val_mean_squared_error: 40.5554
# Epoch 164/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.6940 - mean_squared_error: 3.6940 - val_loss: 39.6885 - val_mean_squared_error: 39.6885
# Epoch 165/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8233 - mean_squared_error: 3.8233 - val_loss: 40.5661 - val_mean_squared_error: 40.5661
# Epoch 166/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.8001 - mean_squared_error: 3.8001 - val_loss: 39.6158 - val_mean_squared_error: 39.6158
# Epoch 167/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8469 - mean_squared_error: 3.8469 - val_loss: 39.1786 - val_mean_squared_error: 39.1786
# Epoch 168/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.0389 - mean_squared_error: 4.0389 - val_loss: 40.2401 - val_mean_squared_error: 40.2401
# Epoch 169/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9253 - mean_squared_error: 3.9253 - val_loss: 38.8383 - val_mean_squared_error: 38.8383
# Epoch 170/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5188 - mean_squared_error: 3.5188 - val_loss: 39.1198 - val_mean_squared_error: 39.1198
# Epoch 171/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5372 - mean_squared_error: 3.5372 - val_loss: 39.7431 - val_mean_squared_error: 39.7431
# Epoch 172/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.5162 - mean_squared_error: 3.5162 - val_loss: 39.2629 - val_mean_squared_error: 39.2629
# Epoch 173/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4962 - mean_squared_error: 3.4962 - val_loss: 39.2628 - val_mean_squared_error: 39.2628
# Epoch 174/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8804 - mean_squared_error: 3.8804 - val_loss: 38.5706 - val_mean_squared_error: 38.5706
# Epoch 175/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8699 - mean_squared_error: 3.8699 - val_loss: 39.6894 - val_mean_squared_error: 39.6894
# Epoch 176/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3208 - mean_squared_error: 3.3208 - val_loss: 38.3702 - val_mean_squared_error: 38.3702
# Epoch 177/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6151 - mean_squared_error: 3.6151 - val_loss: 38.7109 - val_mean_squared_error: 38.7109
# Epoch 178/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7471 - mean_squared_error: 3.7471 - val_loss: 37.4559 - val_mean_squared_error: 37.4559
# Epoch 179/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7007 - mean_squared_error: 3.7007 - val_loss: 38.0436 - val_mean_squared_error: 38.0436
# Epoch 180/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3914 - mean_squared_error: 3.3914 - val_loss: 37.2436 - val_mean_squared_error: 37.2436
# Epoch 181/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.1624 - mean_squared_error: 3.1624 - val_loss: 38.9675 - val_mean_squared_error: 38.9675
# Epoch 182/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2362 - mean_squared_error: 3.2362 - val_loss: 38.5786 - val_mean_squared_error: 38.5786
# Epoch 183/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2248 - mean_squared_error: 3.2248 - val_loss: 38.0376 - val_mean_squared_error: 38.0376
# Epoch 184/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.5982 - mean_squared_error: 3.5982 - val_loss: 36.9788 - val_mean_squared_error: 36.9788
# Epoch 185/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6518 - mean_squared_error: 3.6518 - val_loss: 36.5921 - val_mean_squared_error: 36.5921
# Epoch 186/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5973 - mean_squared_error: 3.5973 - val_loss: 38.0766 - val_mean_squared_error: 38.0766
# Epoch 187/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5130 - mean_squared_error: 3.5130 - val_loss: 37.4197 - val_mean_squared_error: 37.4197
# Epoch 188/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.6409 - mean_squared_error: 3.6409 - val_loss: 36.3402 - val_mean_squared_error: 36.3402
# Epoch 189/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0594 - mean_squared_error: 3.0594 - val_loss: 35.8291 - val_mean_squared_error: 35.8291
# Epoch 190/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.5092 - mean_squared_error: 3.5092 - val_loss: 36.8389 - val_mean_squared_error: 36.8389
# Epoch 191/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3294 - mean_squared_error: 3.3294 - val_loss: 37.4446 - val_mean_squared_error: 37.4446
# Epoch 192/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4803 - mean_squared_error: 3.4803 - val_loss: 36.1230 - val_mean_squared_error: 36.1230
# Epoch 193/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2700 - mean_squared_error: 3.2700 - val_loss: 36.6599 - val_mean_squared_error: 36.6599
# Epoch 194/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4611 - mean_squared_error: 3.4611 - val_loss: 36.3610 - val_mean_squared_error: 36.3610
# Epoch 195/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2182 - mean_squared_error: 3.2182 - val_loss: 36.6223 - val_mean_squared_error: 36.6223
# Epoch 196/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2218 - mean_squared_error: 3.2218 - val_loss: 34.6985 - val_mean_squared_error: 34.6985
# Epoch 197/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.1904 - mean_squared_error: 3.1904 - val_loss: 36.2195 - val_mean_squared_error: 36.2195
# Epoch 198/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2248 - mean_squared_error: 3.2248 - val_loss: 36.7173 - val_mean_squared_error: 36.7173
# Epoch 199/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3644 - mean_squared_error: 3.3644 - val_loss: 35.6592 - val_mean_squared_error: 35.6592
# Epoch 200/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2515 - mean_squared_error: 3.2515 - val_loss: 35.0278 - val_mean_squared_error: 35.0278
# Epoch 201/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.2846 - mean_squared_error: 3.2846 - val_loss: 36.1567 - val_mean_squared_error: 36.1567
# Epoch 202/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.4243 - mean_squared_error: 3.4243 - val_loss: 36.4463 - val_mean_squared_error: 36.4463
# Epoch 203/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2755 - mean_squared_error: 3.2755 - val_loss: 35.2812 - val_mean_squared_error: 35.2812
# Epoch 204/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.4982 - mean_squared_error: 3.4982 - val_loss: 34.6777 - val_mean_squared_error: 34.6777
# Epoch 205/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2169 - mean_squared_error: 3.2169 - val_loss: 35.0718 - val_mean_squared_error: 35.0718
# Epoch 206/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9640 - mean_squared_error: 2.9640 - val_loss: 35.9480 - val_mean_squared_error: 35.9480
# Epoch 207/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0894 - mean_squared_error: 3.0894 - val_loss: 35.2756 - val_mean_squared_error: 35.2756
# Epoch 208/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1752 - mean_squared_error: 3.1752 - val_loss: 34.4569 - val_mean_squared_error: 34.4569
# Epoch 209/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.2331 - mean_squared_error: 3.2331 - val_loss: 35.1554 - val_mean_squared_error: 35.1554
# Epoch 210/400
# 10/10 [==============================] - 0s 6ms/step - loss: 3.0203 - mean_squared_error: 3.0203 - val_loss: 34.1773 - val_mean_squared_error: 34.1773
# Epoch 211/400
# 10/10 [==============================] - 0s 5ms/step - loss: 3.3489 - mean_squared_error: 3.3489 - val_loss: 34.4247 - val_mean_squared_error: 34.4247
# Epoch 212/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1566 - mean_squared_error: 3.1566 - val_loss: 35.8425 - val_mean_squared_error: 35.8425
# Epoch 213/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1902 - mean_squared_error: 3.1902 - val_loss: 35.8447 - val_mean_squared_error: 35.8447
# Epoch 214/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.7801 - mean_squared_error: 2.7801 - val_loss: 33.5427 - val_mean_squared_error: 33.5427
# Epoch 215/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1943 - mean_squared_error: 3.1943 - val_loss: 33.9639 - val_mean_squared_error: 33.9639
# Epoch 216/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8745 - mean_squared_error: 2.8745 - val_loss: 34.4814 - val_mean_squared_error: 34.4814
# Epoch 217/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2586 - mean_squared_error: 3.2586 - val_loss: 33.9025 - val_mean_squared_error: 33.9025
# Epoch 218/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6795 - mean_squared_error: 2.6795 - val_loss: 34.1182 - val_mean_squared_error: 34.1182
# Epoch 219/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7213 - mean_squared_error: 2.7213 - val_loss: 34.1817 - val_mean_squared_error: 34.1817
# Epoch 220/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8698 - mean_squared_error: 2.8698 - val_loss: 33.3851 - val_mean_squared_error: 33.3851
# Epoch 221/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8647 - mean_squared_error: 2.8647 - val_loss: 34.1578 - val_mean_squared_error: 34.1578
# Epoch 222/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.9082 - mean_squared_error: 2.9082 - val_loss: 33.8966 - val_mean_squared_error: 33.8966
# Epoch 223/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5423 - mean_squared_error: 2.5423 - val_loss: 32.9083 - val_mean_squared_error: 32.9083
# Epoch 224/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7214 - mean_squared_error: 2.7214 - val_loss: 33.8802 - val_mean_squared_error: 33.8802
# Epoch 225/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2127 - mean_squared_error: 3.2127 - val_loss: 34.6142 - val_mean_squared_error: 34.6142
# Epoch 226/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.7829 - mean_squared_error: 2.7829 - val_loss: 33.3435 - val_mean_squared_error: 33.3435
# Epoch 227/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9786 - mean_squared_error: 2.9786 - val_loss: 32.7692 - val_mean_squared_error: 32.7692
# Epoch 228/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7787 - mean_squared_error: 2.7787 - val_loss: 33.4650 - val_mean_squared_error: 33.4650
# Epoch 229/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1553 - mean_squared_error: 3.1553 - val_loss: 33.2813 - val_mean_squared_error: 33.2813
# Epoch 230/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9323 - mean_squared_error: 2.9323 - val_loss: 33.4326 - val_mean_squared_error: 33.4326
# Epoch 231/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8373 - mean_squared_error: 2.8373 - val_loss: 33.3426 - val_mean_squared_error: 33.3426
# Epoch 232/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8812 - mean_squared_error: 2.8812 - val_loss: 32.4723 - val_mean_squared_error: 32.4723
# Epoch 233/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1399 - mean_squared_error: 3.1399 - val_loss: 32.0810 - val_mean_squared_error: 32.0810
# Epoch 234/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8096 - mean_squared_error: 2.8096 - val_loss: 33.5170 - val_mean_squared_error: 33.5170
# Epoch 235/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8650 - mean_squared_error: 2.8650 - val_loss: 33.3427 - val_mean_squared_error: 33.3427
# Epoch 236/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9741 - mean_squared_error: 2.9741 - val_loss: 32.4417 - val_mean_squared_error: 32.4417
# Epoch 237/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9975 - mean_squared_error: 2.9975 - val_loss: 32.4221 - val_mean_squared_error: 32.4221
# Epoch 238/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6512 - mean_squared_error: 2.6512 - val_loss: 33.2807 - val_mean_squared_error: 33.2807
# Epoch 239/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7953 - mean_squared_error: 2.7953 - val_loss: 31.2225 - val_mean_squared_error: 31.2225
# Epoch 240/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8711 - mean_squared_error: 2.8711 - val_loss: 33.1267 - val_mean_squared_error: 33.1267
# Epoch 241/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8230 - mean_squared_error: 2.8230 - val_loss: 31.2480 - val_mean_squared_error: 31.2480
# Epoch 242/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7227 - mean_squared_error: 2.7227 - val_loss: 32.5083 - val_mean_squared_error: 32.5083
# Epoch 243/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6484 - mean_squared_error: 2.6484 - val_loss: 31.3377 - val_mean_squared_error: 31.3377
# Epoch 244/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7135 - mean_squared_error: 2.7135 - val_loss: 32.6045 - val_mean_squared_error: 32.6045
# Epoch 245/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6074 - mean_squared_error: 2.6074 - val_loss: 31.7230 - val_mean_squared_error: 31.7230
# Epoch 246/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6126 - mean_squared_error: 2.6126 - val_loss: 31.8614 - val_mean_squared_error: 31.8614
# Epoch 247/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7696 - mean_squared_error: 2.7696 - val_loss: 31.5960 - val_mean_squared_error: 31.5960
# Epoch 248/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8423 - mean_squared_error: 2.8423 - val_loss: 31.0128 - val_mean_squared_error: 31.0128
# Epoch 249/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5738 - mean_squared_error: 2.5738 - val_loss: 31.2109 - val_mean_squared_error: 31.2109
# Epoch 250/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8164 - mean_squared_error: 2.8164 - val_loss: 30.8855 - val_mean_squared_error: 30.8855
# Epoch 251/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4565 - mean_squared_error: 2.4565 - val_loss: 32.0418 - val_mean_squared_error: 32.0418
# Epoch 252/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3075 - mean_squared_error: 2.3075 - val_loss: 30.6524 - val_mean_squared_error: 30.6524
# Epoch 253/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6679 - mean_squared_error: 2.6679 - val_loss: 30.9446 - val_mean_squared_error: 30.9446
# Epoch 254/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8755 - mean_squared_error: 2.8755 - val_loss: 32.1093 - val_mean_squared_error: 32.1093
# Epoch 255/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5051 - mean_squared_error: 2.5051 - val_loss: 30.3326 - val_mean_squared_error: 30.3326
# Epoch 256/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7446 - mean_squared_error: 2.7446 - val_loss: 31.8983 - val_mean_squared_error: 31.8983
# Epoch 257/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5553 - mean_squared_error: 2.5553 - val_loss: 30.3884 - val_mean_squared_error: 30.3884
# Epoch 258/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3628 - mean_squared_error: 2.3628 - val_loss: 31.6701 - val_mean_squared_error: 31.6701
# Epoch 259/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4164 - mean_squared_error: 2.4164 - val_loss: 30.2902 - val_mean_squared_error: 30.2902
# Epoch 260/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.7773 - mean_squared_error: 2.7773 - val_loss: 30.0003 - val_mean_squared_error: 30.0003
# Epoch 261/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5975 - mean_squared_error: 2.5975 - val_loss: 31.4670 - val_mean_squared_error: 31.4670
# Epoch 262/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5398 - mean_squared_error: 2.5398 - val_loss: 30.8144 - val_mean_squared_error: 30.8144
# Epoch 263/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5390 - mean_squared_error: 2.5390 - val_loss: 29.6495 - val_mean_squared_error: 29.6495
# Epoch 264/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4251 - mean_squared_error: 2.4251 - val_loss: 29.3842 - val_mean_squared_error: 29.3842
# Epoch 265/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4705 - mean_squared_error: 2.4705 - val_loss: 30.6672 - val_mean_squared_error: 30.6672
# Epoch 266/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.4785 - mean_squared_error: 2.4785 - val_loss: 30.3325 - val_mean_squared_error: 30.3325
# Epoch 267/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4769 - mean_squared_error: 2.4769 - val_loss: 30.5452 - val_mean_squared_error: 30.5452
# Epoch 268/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3402 - mean_squared_error: 2.3402 - val_loss: 30.3910 - val_mean_squared_error: 30.3910
# Epoch 269/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2500 - mean_squared_error: 2.2500 - val_loss: 29.7639 - val_mean_squared_error: 29.7639
# Epoch 270/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6873 - mean_squared_error: 2.6873 - val_loss: 29.3226 - val_mean_squared_error: 29.3226
# Epoch 271/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6628 - mean_squared_error: 2.6628 - val_loss: 30.3828 - val_mean_squared_error: 30.3828
# Epoch 272/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5642 - mean_squared_error: 2.5642 - val_loss: 29.8005 - val_mean_squared_error: 29.8005
# Epoch 273/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4617 - mean_squared_error: 2.4617 - val_loss: 30.3313 - val_mean_squared_error: 30.3313
# Epoch 274/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5021 - mean_squared_error: 2.5021 - val_loss: 29.1689 - val_mean_squared_error: 29.1689
# Epoch 275/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7301 - mean_squared_error: 2.7301 - val_loss: 30.3751 - val_mean_squared_error: 30.3751
# Epoch 276/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3226 - mean_squared_error: 2.3226 - val_loss: 29.8888 - val_mean_squared_error: 29.8888
# Epoch 277/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5529 - mean_squared_error: 2.5529 - val_loss: 29.1027 - val_mean_squared_error: 29.1027
# Epoch 278/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4901 - mean_squared_error: 2.4901 - val_loss: 29.1487 - val_mean_squared_error: 29.1487
# Epoch 279/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0425 - mean_squared_error: 2.0425 - val_loss: 29.2462 - val_mean_squared_error: 29.2462
# Epoch 280/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1290 - mean_squared_error: 2.1290 - val_loss: 29.5781 - val_mean_squared_error: 29.5781
# Epoch 281/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4395 - mean_squared_error: 2.4395 - val_loss: 29.3266 - val_mean_squared_error: 29.3266
# Epoch 282/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1232 - mean_squared_error: 2.1232 - val_loss: 29.3727 - val_mean_squared_error: 29.3727
# Epoch 283/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2317 - mean_squared_error: 2.2317 - val_loss: 27.7722 - val_mean_squared_error: 27.7722
# Epoch 284/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1425 - mean_squared_error: 2.1425 - val_loss: 29.6292 - val_mean_squared_error: 29.6292
# Epoch 285/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.6121 - mean_squared_error: 2.6121 - val_loss: 29.0486 - val_mean_squared_error: 29.0486
# Epoch 286/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5011 - mean_squared_error: 2.5011 - val_loss: 29.9912 - val_mean_squared_error: 29.9912
# Epoch 287/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0978 - mean_squared_error: 2.0978 - val_loss: 28.1699 - val_mean_squared_error: 28.1699
# Epoch 288/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4396 - mean_squared_error: 2.4396 - val_loss: 29.5085 - val_mean_squared_error: 29.5085
# Epoch 289/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6052 - mean_squared_error: 2.6052 - val_loss: 27.9834 - val_mean_squared_error: 27.9834
# Epoch 290/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3006 - mean_squared_error: 2.3006 - val_loss: 27.9061 - val_mean_squared_error: 27.9061
# Epoch 291/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0951 - mean_squared_error: 2.0951 - val_loss: 29.7323 - val_mean_squared_error: 29.7323
# Epoch 292/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7915 - mean_squared_error: 2.7915 - val_loss: 28.3569 - val_mean_squared_error: 28.3569
# Epoch 293/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3630 - mean_squared_error: 2.3630 - val_loss: 28.9725 - val_mean_squared_error: 28.9725
#
# Epoch 00293: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 294/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1326 - mean_squared_error: 2.1326 - val_loss: 28.6322 - val_mean_squared_error: 28.6322
# Epoch 295/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3923 - mean_squared_error: 2.3923 - val_loss: 28.6348 - val_mean_squared_error: 28.6348
# Epoch 296/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2613 - mean_squared_error: 2.2613 - val_loss: 28.6837 - val_mean_squared_error: 28.6837
# Epoch 297/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3497 - mean_squared_error: 2.3497 - val_loss: 28.5136 - val_mean_squared_error: 28.5136
# Epoch 298/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2497 - mean_squared_error: 2.2497 - val_loss: 28.2653 - val_mean_squared_error: 28.2653
# Epoch 299/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3367 - mean_squared_error: 2.3367 - val_loss: 27.6259 - val_mean_squared_error: 27.6259
# Epoch 300/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.2844 - mean_squared_error: 2.2844 - val_loss: 27.8720 - val_mean_squared_error: 27.8720
# Epoch 301/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1373 - mean_squared_error: 2.1373 - val_loss: 28.6307 - val_mean_squared_error: 28.6307
# Epoch 302/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.5526 - mean_squared_error: 2.5526 - val_loss: 29.1583 - val_mean_squared_error: 29.1583
# Epoch 303/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3614 - mean_squared_error: 2.3614 - val_loss: 28.9054 - val_mean_squared_error: 28.9054
# Epoch 304/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0701 - mean_squared_error: 2.0701 - val_loss: 28.6903 - val_mean_squared_error: 28.6903
# Epoch 305/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7406 - mean_squared_error: 2.7406 - val_loss: 28.6838 - val_mean_squared_error: 28.6838
# Epoch 306/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0703 - mean_squared_error: 2.0703 - val_loss: 28.2366 - val_mean_squared_error: 28.2366
# Epoch 307/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1760 - mean_squared_error: 2.1760 - val_loss: 28.1268 - val_mean_squared_error: 28.1268
# Epoch 308/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9776 - mean_squared_error: 2.9776 - val_loss: 27.9251 - val_mean_squared_error: 27.9251
# Epoch 309/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1733 - mean_squared_error: 2.1733 - val_loss: 27.7965 - val_mean_squared_error: 27.7965
#
# Epoch 00309: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 310/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1939 - mean_squared_error: 2.1939 - val_loss: 27.9645 - val_mean_squared_error: 27.9645
# Epoch 311/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1962 - mean_squared_error: 2.1962 - val_loss: 28.0719 - val_mean_squared_error: 28.0719
# Epoch 312/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8921 - mean_squared_error: 1.8921 - val_loss: 27.9261 - val_mean_squared_error: 27.9261
# Epoch 313/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.2096 - mean_squared_error: 2.2096 - val_loss: 28.2149 - val_mean_squared_error: 28.2149
# Epoch 314/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6306 - mean_squared_error: 2.6306 - val_loss: 28.3385 - val_mean_squared_error: 28.3385
# Epoch 315/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1232 - mean_squared_error: 2.1232 - val_loss: 28.3911 - val_mean_squared_error: 28.3911
# Epoch 316/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4955 - mean_squared_error: 2.4955 - val_loss: 28.5473 - val_mean_squared_error: 28.5473
# Epoch 317/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3714 - mean_squared_error: 2.3714 - val_loss: 28.4973 - val_mean_squared_error: 28.4973
# Epoch 318/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3713 - mean_squared_error: 2.3713 - val_loss: 28.5313 - val_mean_squared_error: 28.5313
# Epoch 319/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3562 - mean_squared_error: 2.3562 - val_loss: 28.3888 - val_mean_squared_error: 28.3888
# Epoch 320/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1767 - mean_squared_error: 2.1767 - val_loss: 28.2950 - val_mean_squared_error: 28.2950
# Epoch 321/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2054 - mean_squared_error: 2.2054 - val_loss: 28.2692 - val_mean_squared_error: 28.2692
# Epoch 322/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0057 - mean_squared_error: 2.0057 - val_loss: 28.2554 - val_mean_squared_error: 28.2554
# Epoch 323/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1069 - mean_squared_error: 2.1069 - val_loss: 28.2375 - val_mean_squared_error: 28.2375
# Epoch 324/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2539 - mean_squared_error: 2.2539 - val_loss: 28.1939 - val_mean_squared_error: 28.1939
# Epoch 325/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3960 - mean_squared_error: 2.3960 - val_loss: 28.3606 - val_mean_squared_error: 28.3606
# Epoch 326/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1587 - mean_squared_error: 2.1587 - val_loss: 28.1963 - val_mean_squared_error: 28.1963
# Epoch 327/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1520 - mean_squared_error: 2.1520 - val_loss: 28.0892 - val_mean_squared_error: 28.0892
# Epoch 328/400
# 10/10 [==============================] - 0s 5ms/step - loss: 1.9007 - mean_squared_error: 1.9007 - val_loss: 27.8779 - val_mean_squared_error: 27.8779
# Epoch 329/400
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1319 - mean_squared_error: 2.1319 - val_loss: 27.9958 - val_mean_squared_error: 27.9958
# Restoring model weights from the end of the best epoch.
# Epoch 00329: early stopping

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
predictions = model.predict([X_test])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test, predictions)))
# Out:
# Valeur d'erreur moyenne:
#  8.970287318091543
