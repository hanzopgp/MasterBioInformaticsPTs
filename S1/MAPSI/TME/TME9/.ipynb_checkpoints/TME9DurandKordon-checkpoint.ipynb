# %% [markdown]
# # Régression & optimisation par descente de gradient
#
# Ce tme a deux objectifs:
#  - acquérir les connaissances de base pour faire face au problème de la régression, c'est à dire de l'estimation d'un score réel correpondant à une situation,
#  - travailler sur les techniques d'optimisation par descente de gradient

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Génération de données jouet & construction d'une solution analytique
#
# Dans un premier temps, générons des données jouets paramétriques:
#  - $N$: nombre de points à générer
#  - $x \in [0, 1]$ tirage avec un simple rand() ou un linspace() -au choix-
#      - Si vous optez pour un tirage aléatoire des abscisses, triez les points pour simplifier les traitements ultérieurs
#  - $y=ax+b+\epsilon, \epsilon \sim \mathcal N(0,\sigma^2)$
#      - Rappel : en multipliant un tirage aléatoire selon une gaussienne centrée réduite par $\sigma$ on obtient le bruit décrit ci-dessus
#
# Afin de travailler sur les bonnes pratiques, nous distinguerons un ensemble d'apprentissage et un ensemble de test.
# Les deux sont tirés selon la même distribution. L'ensemble de test comptera -arbitrairement- 1000 points.

# %%
def gen_data_lin(a, b, sig, N=500, Ntest=1000):
    X_train = np.sort(np.random.rand(N)) # sort optionnel, mais ça aide pour les plots
    X_test  = np.sort(np.random.rand(Ntest))
    sig1 = np.random.normal(0,sig,size=(N))
    sig2 = np.random.normal(0,sig,size=(Ntest))
    Y_train = a * X_train + b + sig1
    Y_test  = a * X_test + b + sig2
    return X_train, Y_train, X_test, Y_test

# %%
# génération de données jouets:
a = 6.
b = -1.
N = 100
sig = .4 # écart type

X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)

plt.figure()
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_train, Y_train, 'b')
plt.show()

# %% [markdown]
# Vous devez obtenir quelque chose de la forme:<br>
# ![données jouet](fig/gen_data.png)

# %% [markdown]
# ## Validation des formules analytiques
# Nous avons vu deux types de résolutions analytique: à partir des estimateurs des espérances et co-variances d'une part et des moindres carrés d'autre part. Testons les deux méthodes.
#
# ### Estimation de paramètres probabilistes
#  - $\hat a = \frac{\mbox{cov}(X,Y)}{\sigma_x^2}$
#  - $\hat b = E(Y)−\frac{\mbox{cov}(X,Y)}{\sigma_x^2} E(X)$
#
#  Estimer les paramètres, calculer l'erreur au sens des moindres carrés sur les données d'apprentissage et de test, puis tracer la droite de régression

# %%
def modele_lin_analytique(X_train, Y_train):
    cov_xy = np.cov(X_train, Y_train)[0][1]
    cov_std2 = cov_xy / (X_train.std()**2)
    ahat = cov_std2
    bhat = Y_train.mean() - cov_std2 * X_train.mean()
    return ahat, bhat

ahat, bhat = modele_lin_analytique(X_train, Y_train)
print(ahat,"\n",bhat)
# Out:
# 6.071494882607818
#  -1.05948521382777

# %%
def erreur_mc(y, yhat):
    return ((y-yhat)**2).mean()

yhat_train = ahat*X_train+bhat
yhat_test  = ahat*X_test +bhat

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat_train, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):', erreur_mc(yhat_test, Y_test))
# Out:
# Erreur moyenne au sens des moindres carrés (train): 0.1292352501532062
# Erreur moyenne au sens des moindres carrés (test): 0.154074332433727

# %%
plt.figure()
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_train, Y_train, 'b')
plt.plot(X_test, yhat_test, 'g', lw=3)

# %% [markdown]
# ## Formulation au sens des moindres carrés
#
# Nous partons directement sur une écriture matricielle. Du coup, il est nécessaire de construire la matrice enrichie $Xe$:
#     $$Xe = \left[\begin{array}{cc}
#                 X_0 & 1\\
#                 \vdots & \vdots\\
#                 X_N & 1
#                 \end{array}
#                 \right] $$
# Le code de la fonction d'enrichissement est donné ci-dessous.
#
# Il faut ensuite poser et résoudre un système d'équations linéaires de la forme:
# $$ A w = B $$
# **Rappel des formules vues en cours/TD:**
# $$ A=X^T X$$
# $$ B=X^T Y$$
# Fonction de résolution: `np.linalg.solve(A,B)`
# Vous devez obtenir la même solution que précédemment.

# %%
def make_mat_lin_biais(X): # fonctionne pour un vecteur unidimensionel X
    N = len(X)
    return np.hstack((X.reshape(N,1),np.ones((N,1))))

# %%
Xe = make_mat_lin_biais(X_train)
A = Xe.T @ Xe
B = Xe.T @ Y_train
w = np.linalg.solve(A,B)

print(w)
# Out:
# [ 6.01077993 -1.03044663]

# %% [markdown]
# Soit les données polynomiales générées avec la fonction ci-dessous
#  - proposer & une solution d'enrichissement (vue en cours et TD)
#  - résoudre analytiquement le problème des moindres carrés
#  - calculer l'erreur au sens des moindes carrés en apprentissage ET en test
#  - tracer les données et la solution

# %%
def gen_data_poly2(a, b, c, sig, N=500, Ntest=1000):
    '''
    Tire N points X aléatoirement entre 0 et 1 et génère y = ax^2 + bx + c + eps
    eps ~ N(0, sig^2)
    '''
    X_train = np.sort(np.random.rand(N))
    X_test  = np.sort(np.random.rand(Ntest))
    Y_train = a*X_train**2+b*X_train+c+np.random.randn(N)*sig
    Y_test  = a*X_test**2 +b*X_test +c+np.random.randn(Ntest)*sig
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = gen_data_poly2(10, -10, 5, 0.1, N=100, Ntest=100)
plt.figure()
plt.plot(X_train, Y_train)
plt.show()

# %%
def make_mat_poly_biais(X): # fonctionne pour un vecteur unidimensionel X
    N = len(X)
    tmp = np.hstack((X.reshape(N,1)**2,(X.reshape(N,1)))) # X**2, X
    return np.hstack((tmp, np.ones((N,1)))) # X**2, X, 1

Xe   = make_mat_poly_biais(X_train)
Xe_t = make_mat_poly_biais(X_test) 
A = Xe.T @ Xe
B = Xe.T @ Y_train
w = np.linalg.solve(A,B)

A_t = Xe_t.T @ Xe_t
B_t = Xe_t.T @ Y_test
w_t = np.linalg.solve(A_t,B_t)

print(w)

yhat   = X_train**2 * w[0]   + X_train * w[1]   + w[2]
yhat_t = X_test**2  * w_t[0] + X_test  * w_t[1] + w_t[2]
print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):', erreur_mc(yhat_t, Y_test))

plt.figure()
plt.plot(X_train, Y_train, 'b.')
plt.plot(X_train, yhat, 'r')
plt.show()
# Out:
# [ 9.89962869 -9.90057268  4.98735908]
# Erreur moyenne au sens des moindres carrés (train): 0.00905356624013367
# Erreur moyenne au sens des moindres carrés (test): 0.009380495688432425

# %% [markdown]
# # Fonction de coût & optimisation par descente de gradient
#
# Comme vu en TD et en cours, nous allons maintenant résoudre le problème de la régression par minimisation d'une fonction de coût:
# $$ C = \sum_{i=1}^N (y_i - f(x_i))$$
#
# Soit un problème avec des données $(x_i,y_i)_{i=1,\ldots,N}$, une fonction de décision/prédiction paramétrée par un vecteur $w$ et une fonction de cout à optimiser $C(w)$.
# Notre but est de trouver les paramètres $w^\star$ minimisant la fonction de coût:
# $$ w^\star = \arg\min_w C(w)$$
#
# l'algorithme de la descente de gradient est le suivant (rappel):
#
#  - $w_0 \leftarrow init$ par exemple : 0
#  - boucle
#      - $w_{t+1} \leftarrow w_{t} - \epsilon \nabla_w C(w_t)$
#
# Compléter le squelette d'implémentation fourni ci-dessous:

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)

# pour travailler en matrice: (re)construction de la matrice contenant les X et un biais
Xe = make_mat_lin_biais(X_train) # dataset linéaire, transformation lineaire des données
wstar = np.linalg.solve(Xe.T @ Xe, Xe.T @ Y_train)

def descente_grad_mc(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for i in range(nIterations):
        if i%(nIterations/10)==0:
            print(i*100/nIterations,"%")
        w = w - eps * 2 * X.T @ (X @ w - y)
        allw.append(w) # stockage de toutes les valeurs intermédiaires pour analyse
    allw = np.array(allw)
    return w, allw # la dernière valeur (meilleure) + tout l'historique pour le plot
    
w, allw = descente_grad_mc(Xe, Y_train, eps=1e-4, nIterations=10000)
print(wstar)
print(w)
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# [ 5.94877492 -0.90915675]
# [ 5.94877022 -0.9091542 ]

# %% [markdown]
# On s'intéresse ensuite à comprendre la descente de gradient dans l'espace des paramètres. Le code ci-dessous permet de tracer le cout pour un ensemble de paramètres (toutes les valeurs de paramètres prises par l'algorithmes au fil du temps).

# %%
# tracer de l'espace des couts
def plot_parametres( allw, X, y, opti = [], ngrid = 20, extract_bornes=False):
    '''
    Fonction de tracer d'un historique de coefficients
    ATTENTION: ca ne marche qu'en 2D (évidemment)
    Chaque w doit contenir 2 valeurs
    
    Il faut fournir les données (X,y) pour calculer le cout associé 
    à un jeu de paramètres w
    ATTENTION X = forme matricielle des données
    '''
    w_min = [-0.5, -2] # bornes par défaut, uniquement pour notre cas d'usage
    w_max = [8, 5]
    if extract_bornes: # bornes générales
        w_min = np.min(allw,0) # trouver les bornes
        w_max = np.max(allw,0)
    # faire une grille régulière avec tous les couples possibles entre le min et le max
    w1range = np.linspace(w_min[0], w_max[0], ngrid)
    w2range = np.linspace(w_min[1], w_max[1], ngrid)
    w1,w2 = np.meshgrid(w1range,w2range)
    # calcul de tous les couts associés à tous les couples de paramètres
    cost = np.array([[np.log(((X @ np.array([w1i,w2j])-y)**2).sum()) for w1i in w1range] for w2j in w2range])
    plt.figure()
    plt.contour(w1, w2, cost)
    if len(opti) > 0:
        plt.scatter(wstar[0], wstar[1],c='r')
    plt.plot(allw[:,0],allw[:,1],'b+-' ,lw=2 )
    return
    
plot_parametres(allw, Xe, Y_train, opti=wstar)
# plt.savefig('fig/grad_descente.png')

# %% [markdown]
# Vous devez obtenir un image de la forme :<br>
# ![Descente de gradient](fig/grad_descente.png)
#
# Tester différents jeux de paramètres pour mettre en évidence les phénomènes suivants:
#  - Divergence du gradient
#  - Convergence incomplète (trop lente ou pas assez d'itération)
#  - Convergence idéale: pas de gradient suffisamment grand et nombre d'itérations bien choisi

# %% [markdown]
# # Passage sur des données réelles
#
# Après avoir étudié trois manières de faire face au problème de la régression, nous proposons d'étudier un cas réel: la prédiction de la consommation des voitures en fonction de leurs caractéristiques.
#
# Dans le cas présent, nous allons baser la solution sur la résolution analytique du problème des moindres carrés (`np.linalg.solve(A,B)`), qui semble la mieux adaptée au problème qui nous intéresse.
#
# Le jeu de données est issu des datasets UCI, un répertoire parmi les plus connus en machine learning. Les données **sont déjà téléchargées et présentes dans le tme** mais vous voulez plus d'informations:
# https://archive.ics.uci.edu/ml/datasets/auto+mpg
#
# ![voiture](fig/Large9.jpg)
#
# Après avoir importé les données (fonction fournie), vous construirez une solution optimale et l'évaluerez au sens des moindres carrés en apprentissage et en test.

# %%
import pandas as pd
# Chargement des données
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) # comme np.loadtxt mais en plus robuste
# remplacement des données manquantes '?' => Nan pour travailler sur des nombres
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
# remplacement des valeurs manquantes par la moyenne
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())

print(data.head()) # visualiser ce qu'il y a dans les données

X = np.array(data.values[:,1:-2], dtype=np.float64)
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
# separation app/test
def separation_train_test(X, y, pc_train=0.75):
    napp = int(len(y)*pc_train) # nb de points pour le train
    X_train, Y_train = X[:napp], y[:napp]
    X_test, Y_test   = X[napp:], y[napp:]
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)

# %% [markdown]
# # Resolution analytique

# %%
def make_mat_lin_biais(X):
    N = X.shape[0]
    return np.hstack((X,np.ones((N,1)))) # ax + by + cz + ... + g ? ou ax² + by ... + g ?
    
def compute_yhat(X, w):
    res = w[0]
    N = X.shape[1]
    for i in range(1, N):
        res += X[:,i] * w[i]
    return res

def compute_w(X, y, linear):
    if(linear):
        Xe = make_mat_lin_biais(X)
    else:
        Xe = X
    A  = Xe.T @ Xe
    B  = Xe.T @ y
    w  = np.linalg.solve(A,B)
    return w
     
w   = compute_w(X_train, Y_train, linear=False)
w_t = compute_w(X_test , Y_test , linear=False)

print(w)

yhat   = compute_yhat(X_train, w)
yhat_t = compute_yhat(X_test , w_t)

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):',  erreur_mc(yhat_t, Y_test))
# Out:
# [-0.362168    0.00073902  0.00268987 -0.00563114 -0.01289395  0.54066773]
# Erreur moyenne au sens des moindres carrés (train): 10.661281449323736
# Erreur moyenne au sens des moindres carrés (test): 40.23068275181207

# %%
def plot_y(Y_train, Y_test, yhat, yhat_t):
    # tracé des prédictions:
    plt.figure()
    plt.subplot(211)
    plt.plot(Y_test, label="GT")
    plt.plot(yhat_t, label="pred")
    plt.title('En test')
    plt.legend()
    plt.subplot(212)
    plt.plot(Y_train, label="GT")
    plt.plot(yhat, label="pred")
    plt.title('En train')
    return

plot_y(Y_train, Y_test, yhat, yhat_t)

# %%
# interprétation des poids
plt.figure()
plt.bar(np.arange(len(w)), w)
plt.show()

# %% [markdown]
# # Résolution avec descente de gradient

# %%
def train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100, norm=False, grad="normal", encode=False, date_values_index=[], discrete_values_index=[]):
                
        if norm:
            Xn_train, Xn_test = normalisation(X_train, X_test)
        else:
            Xn_train, Xn_test = X_train, X_test
            
        if encode:
            Xn_train[:,date_values_index] = discretize_years(Xn_train[:,date_values_index], 10, date_values_index)
            Xn_test[:,date_values_index]  = discretize_years(Xn_test[:,date_values_index] , 10, date_values_index)
            Xn_train = encode_discrete_values(Xn_train, discrete_values_index)
            Xn_test  = encode_discrete_values(Xn_test , discrete_values_index)

        if norm:
            Xe_train = Xn_train
            Xe_test = Xn_test
        else:
            Xe_train = make_mat_lin_biais(Xn_train)
            Xe_test  = make_mat_lin_biais(Xn_test)
        
        if grad == "normal":
            w, _ = descente_grad_mc(Xe_train, Y_train, eps, nIterations)
        elif grad == "stoch":
            w, _ = descente_grad_mc_stoch(Xe_train, Y_train, eps, nIterations)
        elif grad == "momentum":
            w, _ = descente_grad_mc_stoch_mom(Xe_train, Y_train, eps, 0.9, nIterations)
        elif grad == "batch":
            w, _ = descente_grad_mc_stoch_batch(Xe_train, Y_train, eps, 20, nIterations)
        else:
            print("Pas de gradient ?")
                
        yhat   = Xe_train @ w
        yhat_t = Xe_test @ w

        print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
        print('Erreur moyenne au sens des moindres carrés (test):' , erreur_mc(yhat_t, Y_test))
        
        plot_y(Y_train, Y_test, yhat, yhat_t)
        
        plt.figure()
        plt.bar(np.arange(len(w)), w)
        plt.show()

# %%
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
train(X_train, X_test, Y_train, Y_test, eps=1e-6, nIterations=10, norm=False) # Gradient vanishing car pas de normalisation !
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 3.868530276071835e+78
# Erreur moyenne au sens des moindres carrés (test): 2.345811916660169e+78

# %% [markdown]
# ## Normalisation
#
# Sur le diagramme ci-dessus, on ne voit pas grand chose pour une raison évidente: on ne peut pas comparer ces poids qui comparent des variables dont les ordres de grandeur sont différents.
#
# Nous allons donc assimiler chaque colonne $X_j$ à une variable suivant une loi normale et nous allons revenir à une Normale centrée réduite selon la formule de base:
#
# $$X_j \sim \mathcal N(\mu_j, \sigma_j^2) $$
# $$\Rightarrow Z_j = \frac{X_j - \mu_j}{\sigma_j} \sim \mathcal N(0, 1) $$
#
# Tous les $Z_j$ sont comparables et nous seront en mesure de comprendre l'impact de chaque variables sur les résultats.
#
# **ATTENTION:** on ne se basera que sur les données d'apprentissage pour le calcul des $\{\mu_j, \sigma_j\}$.
#
# Une fois la normalisation effectuée, analyser l'impact des différentes variables descriptives sur la valeur à prédire.

# %%
def normalisation(X_train, X_test):
    '''
    Fonction de normalisation des données pour rendre les colonnes comparables
    Chaque variable sera assimilée à une loi normale qu'il faut centrer + réduire.
    ATTENTION: il faut calculer les moyennes et écarts-types sur les données d'apprentissage seulement
    '''
    stds     = X_train.std(axis=0)
    means    = X_train.mean(axis=0)
    stds_t   = X_test.std(axis=0)
    means_t  = X_test.mean(axis=0)
    Xn_train = (X_train - means)   / stds**2
    Xn_test  = (X_test  - means_t) / stds_t**2
    Xn_train = np.hstack((Xn_train, np.ones((Xn_train.shape[0], 1))))
    Xn_test  = np.hstack((Xn_test,  np.ones((Xn_test.shape [0], 1))))
    return Xn_train, Xn_test

Xn_train, Xn_test = normalisation(X_train, X_test)

w   = compute_w(Xn_train, Y_train, linear=False)
w_t = compute_w(Xn_test , Y_test , linear=False)

yhat   = compute_yhat(Xn_train, w  )
yhat_t = compute_yhat(Xn_test , w_t)

print('Erreur moyenne au sens des moindres carrés (train):', erreur_mc(yhat, Y_train))
print('Erreur moyenne au sens des moindres carrés (test):',  erreur_mc(yhat_t, Y_test))

plot_y(Y_train, Y_test, yhat, yhat_t)

plt.figure()
plt.bar(np.arange(len(w)), w)
plt.show()
# Out:
# Erreur moyenne au sens des moindres carrés (train): 9.197411943240763
# Erreur moyenne au sens des moindres carrés (test): 14.700511217891421

# %%
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=True) # Pourquoi un meilleur test que train ? Pourquoi besoin d'autant d'iterations ?
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 10.00581422002004
# Erreur moyenne au sens des moindres carrés (test): 206.60932167594763

# %%
X_train.shape
# Out:
# (298, 6)

# %% [markdown]
# # Questions d'ouverture
#
# ## Sélection de caractéristiques
#
# Quels sont les résultats obtenus en éliminant toutes les variables servent moins?
#
# ## Feature engineering
#
# En étudiant la signification des variables du problèmes, on trouve:
#
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
#
# D'après la question précédente, le poids, l'année du modèle et le biais sont des facteurs important pour le calcul de la consommation... Jusqu'ici, nous n'avons pas pris en compte l'origine qui était difficile à coder.
#
# ### Encodage de l'origine
#
# La variable origine est accessible de la manière suivante:
#
# ```
#   origine = data.values[:,-2]
# ```
# Il faut le faire au début du traitement pour bien conserver la séparation en l'apprentissage et le test.
#
# Au moins les deux derniers facteurs discrets pourraient être traités différemment en one-hot encoding:
# $$X_j = x \in \{1, \ldots, K\} \Rightarrow [0, 0, 1, 0] \in \{0, 1\}^K$$
#
# La valeur $x$ donne l'index de la colonne non nulle.
#
# ### Encodage de l'année
#
# Pour l'année, il est possible de procéder de la même manière, mais il préférable de découper les années en 10 catégories puis d'encoder pour limiter le nombre de dimensions.

# %%
# Rechargement des donnees
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) 
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())
print(data.head())

X = np.array(data.values[:,:-1], dtype=np.float64) # Cette fois on prend toutes les valeurs
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
# Index suivant le type de variable
discrete_values_index = np.array([1, 7])
date_values_index = np.array([6])
continuous_values_index = np.array([0, 2, 3, 4, 5])

# %%
# Traitement des variables discrete :
def one_hot_encoding(array):
    n = len(array)
    unique_values = np.unique(array)
    n_unique = len(unique_values)
    dic = {}
    for i in range(n_unique):
        dic[unique_values[i]] = i
    res = np.zeros((n, n_unique))
    for i in range(n):
        res[i][dic[array[i]]] = 1
    return res

def encode_discrete_values(X, index):
    for idx in index:
        encoding = one_hot_encoding(X[:,idx])
        X = np.delete(X, idx, 1)
        n = encoding.shape[1]
        for _ in range(n):
            X = np.hstack((X, np.zeros((X.shape[0], 1))))
        for i in range(X.shape[0]):
            for j in range(n):
                X[i][(X.shape[1]-n) + j] = encoding[i][j]
    return X                                  

# print(X[:,5:])
# X = encode_discrete_values(X, discrete_values_index)
# print(X[:,6:])

# %%
# Traitement de la variable date :
def discretize_years(array, n, index):
    array = np.sort(array)
    size = len(array)
    cpt = 0
    n_interval = size//n
    for i in range(1, size+1):
        array[i-1] = cpt
        if i%n_interval == 0:
            cpt += 1
    return array

# print(X[:,date_values_index])
# X = discretize_years(X[:,date_values_index], 10, date_values_index)
# print(X[:,date_values_index])

# %%
### Test avec toutes les features continues+discretes :
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
# 9. car name: string (unique for each instance)

X = np.array(data.values[:,:-1], dtype=np.float64)
# X = discretize_years(X[:,date_values_index], 10, date_values_index)
# X = encode_discrete_values(X, discrete_values_index)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True, encode=True, date_values_index=date_values_index, discrete_values_index=discrete_values_index)
# Out:
# (298, 8)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 6.203114515954615
# Erreur moyenne au sens des moindres carrés (test): 79.88341282758034

# %%
### Test avec toutes les features continues :
# 1. mpg: continuous
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous

index_to_delete = np.concatenate((discrete_values_index, date_values_index))
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True) # Resultat bien moins bon donc valeurs discrete one hot encoded importantes !
# Out:
# (298, 5)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 7.119738952721287
# Erreur moyenne au sens des moindres carrés (test): 127.16908733179729

# %%
### Test avec seulement les features :
# 1. mpg: continuous
# 6. acceleration: continuous

index_to_delete = [1,2,3,4,6,7]
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=0.75)
print(X_train.shape)
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=600, norm=True) # Presque meme resultat qu'au dessus avec seulement 2 features
# Out:
# (298, 2)
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Erreur moyenne au sens des moindres carrés (train): 7.2185629585350775
# Erreur moyenne au sens des moindres carrés (test): 127.46374961047992

# %% [markdown]
# # Question d'ouverture sur le gradient
#
# ## La normalisation a-t-elle un impact sur le gradient?
#
# La normalisation des données peut au moins nous aider à régler plus facilement le pas (qui sera toujours du même ordre de grandeur... Mais cela a-t-il un impact sur la manière dont nous nous rapprochons de la solution optimale?
#
# ## Gradient stochastique
#
# Dans la plupart des algorithmes modernes d'optimisation liés aux réseaux de neurones, le gradient est calculé de manière stochastique, sur un exemple à la fois:
#
# - $w_0 \leftarrow init$ par exemple : 0
# - boucle
#      - tirage d'une donnée $i$: $(x_i,y_i)$
#      - $w_{t+1} \leftarrow w_{t} - \epsilon \nabla_w C_i(w)$
#
#
# Etudier le fonctionnement de cet algorithme sur les exemples jouets précédents.
#
# ## Amélioration du gradient
#
# Le blog de S. Ruder explique particulièrement bien les améliorations possibles sur les descentes de gradient.
#
# https://ruder.io/optimizing-gradient-descent/
#
# Comparer une descente de gradient stochastique avec et sans moment sur les données jouets des premières questions.

# %%
### Impact de la normalisation :
# La normalisation des données permet de ne pas avoir un gradient qui tend vers 0 ou vers de très grands nombres.
# Lors de la descente de gradient, si notre gradient prend des valeurs énormes, on pourrait rater un minimum local interessant.
# Dans le cas contraire, si le gradient prend des valeurs trop petite, on finit par avoir une perte d'information.

# %%
### Gradient stochastique :
def make_mat_lin_biais(X): # Redefinition de la fonction
    N = len(X)
    return np.hstack((X.reshape(N,1),np.ones((N,1))))

X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

# Gradient classique :
def descente_grad_mc(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for _ in range(nIterations):
        w = w - eps * 2 * X.T @ (X @ w - y)
        allw.append(w) # stockage de toutes les valeurs intermédiaires pour analyse
    allw = np.array(allw)
    return w, allw # la dernière valeur (meilleure) + tout l'historique pour le plot
    
w, allw = descente_grad_mc(Xe, Y_train, eps=1e-4, nIterations=100_000)
print(w)

plot_parametres(allw, Xe, Y_train, opti=wstar)

# Gradient stochastique :
def descente_grad_mc_stoch(X, y, eps=1e-4, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    allw = [w]
    for _ in range(nIterations):
        rand = np.random.randint(X.shape[0])
        w = w - eps * 2 * X.T[:,rand] * (X[rand] @ w - y[rand])
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s, allw_s = descente_grad_mc_stoch(Xe, Y_train, eps=0.1, nIterations=1_000)
print(w_s)

plot_parametres(allw_s, Xe, Y_train, opti=wstar)

# Train avec gradient normal :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="normal")
# Train avec gradient stochastique :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Out:
# [ 6.13709332 -1.06869162]
# [ 6.14470506 -1.20651782]
# Erreur moyenne au sens des moindres carrés (train): 0.15677508003552093
# Erreur moyenne au sens des moindres carrés (test): 0.16060706752420587
# Erreur moyenne au sens des moindres carrés (train): 0.32876803235786506
# Erreur moyenne au sens des moindres carrés (test): 0.30026164857252

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

### Amelioration du gradient :
# Gradient stochastique avec moment :
def descente_grad_mc_stoch_mom(X, y, eps=1e-4, gamma=0.9, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    value = w
    allw = [w]
    for i in range(nIterations):
        rand = np.random.randint(X.shape[0])
        gradient = eps * 2 * X.T[:,rand] * (X[rand] @ w - y[rand])
        new_value = (1-gamma) * gradient + gamma * value
        w = w - new_value
        value = new_value
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s_m, allw_s_m = descente_grad_mc_stoch_mom(Xe, Y_train, eps=0.1, nIterations=1_000)
print(w_s_m)

plot_parametres(allw_s_m, Xe, Y_train, opti=wstar)

# Train avec gradient sans moment :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Train avec gradient avec moment :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="momentum")
# Out:
# [ 5.69357448 -0.94163547]
# Erreur moyenne au sens des moindres carrés (train): 0.3065759254471726
# Erreur moyenne au sens des moindres carrés (test): 0.3980609907871271
# Erreur moyenne au sens des moindres carrés (train): 0.30570052393571795
# Erreur moyenne au sens des moindres carrés (test): 0.3967454359818257

# %%
X_train, Y_train, X_test, Y_test = gen_data_lin(a, b, sig, N)
Xe = make_mat_lin_biais(X_train)

### Amelioration du gradient :
# Gradient stochastique avec minibatch :
def descente_grad_mc_stoch_batch(X, y, eps=1e-4, n_batch=20, nIterations=100):
    w = np.zeros(X.shape[1]) # init à 0
    value = w
    allw = [w]
    for i in range(nIterations):
        rand = np.random.randint(X.shape[0]) - n_batch
        batch = X[rand:rand+n_batch]
        batch_t = batch.T
        batch_y = y[rand:rand+n_batch]
        gradient = eps * 2 * batch_t @ (batch @ w - batch_y)
        w = w - gradient
        allw.append(w.copy()) # stockage de toutes les valeurs intermédiaires pour analyse
    return w, np.array(allw)

w_s_b, allw_s_b = descente_grad_mc_stoch_batch(Xe, Y_train, eps=0.01, n_batch=20, nIterations=1_000)
print(w_s_b)

plot_parametres(allw_s_b, Xe, Y_train, opti=wstar)

# Train avec gradient stoch :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="stoch")
# Train avec gradient avec batch :
train(X_train, X_test, Y_train, Y_test, eps=1e-4, nIterations=100_000, norm=False, grad="batch")
# Out:
# [ 6.25368886 -1.19877723]
# Erreur moyenne au sens des moindres carrés (train): 0.3397311300636915
# Erreur moyenne au sens des moindres carrés (test): 0.28782092124550845
# Erreur moyenne au sens des moindres carrés (train): 0.16524534762821677
# Erreur moyenne au sens des moindres carrés (test): 0.1627938555398213

# %% [markdown]
# # Exercice supplémentaire : regression avec multi layer perceptron

# %%
import tensorflow as tf

# %%
# Rechargement des donnees
data = pd.read_csv('data/auto-mpg.data', delimiter='\s+', header=None) 
data.iloc[:,[3]] = data.iloc[:,[3]].replace('?', None)
data.iloc[:,[3]] = data.iloc[:,[3]].astype(float)
data.iloc[:,[3]] = data.iloc[:,[3]].fillna(data.iloc[:,[3]].mean())
print(data.head())

X = np.array(data.values[:,:-1], dtype=np.float64)
y = np.array(data.values[:,0], dtype=np.float64)
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
index_to_delete = np.concatenate((discrete_values_index, date_values_index))
X = np.array(data.values[:,:-1], dtype=np.float64)
X = np.delete(X, index_to_delete, 1)

# %%
TEST_SPLIT = 0.25
N_FEATURES = X.shape[1]
EPOCHS = 20
NB_NEURONS = 32
# DROPOUT_VALUE = 0.3

# %%
X_train, Y_train, X_test, Y_test = separation_train_test(X, y, pc_train=1-TEST_SPLIT)
print(X_train.shape)
# Out:
# (298, 5)

# %%
def norm(X):
    n,m = X.shape
    for i in range(n):
        for j in range(m):
            X[i][j] = (X[i][j] - X[:,j].min()) / (X[:,j].max() - X[:,j].min())
    return X

X_train_unnorm = X_train.copy()
X_test_unnorm = X_test.copy()

print(X_train.mean(axis=0))
X_train = norm(X_train)
X_test = norm(X_test)
print(X_train.mean(axis=0))
# Out:
# [  20.77013423  214.49832215  111.96979866 3130.23489933   15.22315436]
# [0.4993601  0.52790678 0.57298831 0.6737239  0.69030311]

# %% [markdown]
# # Descente de gradient stochastique

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="sgd", metrics=["mean_squared_error"]) # Fonction de loss moindre carres et optimisation par descente de gradient
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 72ms/step - loss: 306.0208 - mean_squared_error: 306.0208 - val_loss: 109.0782 - val_mean_squared_error: 109.0782
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 147.7462 - mean_squared_error: 147.7462 - val_loss: 257.4082 - val_mean_squared_error: 257.4082
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 34.6597 - mean_squared_error: 34.6597 - val_loss: 34.1523 - val_mean_squared_error: 34.1523
# Epoch 4/20
# 10/10 [==============================] - 0s 4ms/step - loss: 45.8898 - mean_squared_error: 45.8898 - val_loss: 24.4131 - val_mean_squared_error: 24.4131
# Epoch 5/20
# 10/10 [==============================] - 0s 4ms/step - loss: 21.3046 - mean_squared_error: 21.3046 - val_loss: 11.2585 - val_mean_squared_error: 11.2585
# Epoch 6/20
# 10/10 [==============================] - 0s 4ms/step - loss: 52.9289 - mean_squared_error: 52.9289 - val_loss: 138.6328 - val_mean_squared_error: 138.6328
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 8.1765 - mean_squared_error: 8.1765 - val_loss: 60.8642 - val_mean_squared_error: 60.8642
# Epoch 8/20
# 10/10 [==============================] - 0s 4ms/step - loss: 6.0503 - mean_squared_error: 6.0503 - val_loss: 34.3497 - val_mean_squared_error: 34.3497
# Epoch 9/20
# 10/10 [==============================] - 0s 4ms/step - loss: 12.6385 - mean_squared_error: 12.6385 - val_loss: 140.4461 - val_mean_squared_error: 140.4461
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 6.3039 - mean_squared_error: 6.3039 - val_loss: 83.7207 - val_mean_squared_error: 83.7207
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.2902 - mean_squared_error: 5.2902 - val_loss: 75.5770 - val_mean_squared_error: 75.5770
# Epoch 12/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6764 - mean_squared_error: 3.6764 - val_loss: 26.7022 - val_mean_squared_error: 26.7022
# Epoch 13/20
# 10/10 [==============================] - 0s 3ms/step - loss: 9.4189 - mean_squared_error: 9.4189 - val_loss: 34.5736 - val_mean_squared_error: 34.5736
# Epoch 14/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.2823 - mean_squared_error: 4.2823 - val_loss: 6.9110 - val_mean_squared_error: 6.9110
# Epoch 15/20
# 10/10 [==============================] - 0s 4ms/step - loss: 24.0947 - mean_squared_error: 24.0947 - val_loss: 64.2940 - val_mean_squared_error: 64.2940
# Epoch 16/20
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8485 - mean_squared_error: 2.8485 - val_loss: 55.8850 - val_mean_squared_error: 55.8850
# Epoch 17/20
# 10/10 [==============================] - 0s 3ms/step - loss: 3.1836 - mean_squared_error: 3.1836 - val_loss: 67.2142 - val_mean_squared_error: 67.2142
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0195 - mean_squared_error: 3.0195 - val_loss: 84.7870 - val_mean_squared_error: 84.7870
# Epoch 19/20
# 10/10 [==============================] - 0s 4ms/step - loss: 5.9075 - mean_squared_error: 5.9075 - val_loss: 58.2739 - val_mean_squared_error: 58.2739
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9911 - mean_squared_error: 3.9911 - val_loss: 55.5713 - val_mean_squared_error: 55.5713

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
sample=10
predictions = model.predict([X_test])
print("Valeurs en entree normalisees:\n", X_test[:sample])
print("Valeurs en entree non-normalisees:\n", X_test_unnorm[:sample])
print("Valeurs reelle en sortie:\n", Y_test[:sample])
print("Valeurs predit en sortie:\n", predictions[:sample])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test[:sample], predictions[:sample])))
# Out:
# Valeurs en entree normalisees:
#  [[0.1862069  1.         0.91666667 1.         0.45185185]
#  [0.5820208  0.40114613 0.53464717 0.85633727 1.        ]
#  [0.51092125 0.74256209 0.68052419 0.91810198 0.9006135 ]
#  [0.73283804 0.29919679 0.52839285 0.59050989 0.52791411]
#  [0.73930163 0.29940109 0.52841529 0.57711417 0.59831288]
#  [0.68112927 0.24220935 0.49038426 0.54221095 0.77638037]
#  [0.79962853 0.25948755 0.52094758 0.57174974 0.59003067]
#  [0.60787519 0.43103483 0.68063172 0.71673729 0.64386503]
#  [0.61649331 0.4939355  0.87073189 0.69660013 0.44923313]
#  [0.57340267 0.4939355  0.87073189 0.72479216 0.51554333]]
# Valeurs en entree non-normalisees:
#  [[  23.   350.   125.  3900.    17.4]
#  [  27.2  141.    71.  3190.    24.8]
#  [  23.9  260.    90.  3420.    22.2]
#  [  34.2  105.    70.  2200.    13.2]
#  [  34.5  105.    70.  2150.    14.9]
#  [  31.8   85.    65.  2020.    19.2]
#  [  37.3   91.    69.  2130.    14.7]
#  [  28.4  151.    90.  2670.    16. ]
#  [  28.8  173.   115.  2595.    11.3]
#  [  26.8  173.   115.  2700.    12.9]]
# Valeurs reelle en sortie:
#  [23.  27.2 23.9 34.2 34.5 31.8 37.3 28.4 28.8 26.8]
# Valeurs predit en sortie:
#  [[11.351603]
#  [21.220608]
#  [17.037603]
#  [27.367483]
#  [27.6523  ]
#  [27.187487]
#  [29.539705]
#  [21.914976]
#  [21.118269]
#  [20.05627 ]]
# Valeur d'erreur moyenne:
#  9.986564005194824

# %% [markdown]
# # Adam avec custom learning rate

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", 
                  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2), # Je specifie la lr de départ sinon trop long pour 20 epochs
                  metrics=["mean_squared_error"]) # Fonction de loss moindre carres et optimisation par descente de gradient
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 10/10 [==============================] - 0s 15ms/step - loss: 488.2443 - mean_squared_error: 488.2443 - val_loss: 885.2335 - val_mean_squared_error: 885.2335
# Epoch 2/20
# 10/10 [==============================] - 0s 4ms/step - loss: 351.4520 - mean_squared_error: 351.4520 - val_loss: 614.5931 - val_mean_squared_error: 614.5931
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 200.1480 - mean_squared_error: 200.1480 - val_loss: 246.4226 - val_mean_squared_error: 246.4226
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 79.3710 - mean_squared_error: 79.3710 - val_loss: 93.3052 - val_mean_squared_error: 93.3052
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 80.9022 - mean_squared_error: 80.9022 - val_loss: 147.1692 - val_mean_squared_error: 147.1692
# Epoch 6/20
# 10/10 [==============================] - 0s 4ms/step - loss: 63.1264 - mean_squared_error: 63.1264 - val_loss: 167.7269 - val_mean_squared_error: 167.7269
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 57.5901 - mean_squared_error: 57.5901 - val_loss: 132.0330 - val_mean_squared_error: 132.0330
# Epoch 8/20
# 10/10 [==============================] - 0s 4ms/step - loss: 55.0934 - mean_squared_error: 55.0934 - val_loss: 109.9434 - val_mean_squared_error: 109.9434
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 44.5644 - mean_squared_error: 44.5644 - val_loss: 116.8839 - val_mean_squared_error: 116.8839
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 38.8107 - mean_squared_error: 38.8107 - val_loss: 103.7160 - val_mean_squared_error: 103.7160
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 34.2908 - mean_squared_error: 34.2908 - val_loss: 83.2974 - val_mean_squared_error: 83.2974
# Epoch 12/20
# 10/10 [==============================] - 0s 3ms/step - loss: 29.1570 - mean_squared_error: 29.1570 - val_loss: 93.6885 - val_mean_squared_error: 93.6885
# Epoch 13/20
# 10/10 [==============================] - 0s 4ms/step - loss: 23.6501 - mean_squared_error: 23.6501 - val_loss: 70.9273 - val_mean_squared_error: 70.9273
# Epoch 14/20
# 10/10 [==============================] - 0s 4ms/step - loss: 14.2180 - mean_squared_error: 14.2180 - val_loss: 69.4558 - val_mean_squared_error: 69.4558
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 10.8291 - mean_squared_error: 10.8291 - val_loss: 49.5660 - val_mean_squared_error: 49.5660
# Epoch 16/20
# 10/10 [==============================] - 0s 3ms/step - loss: 7.1186 - mean_squared_error: 7.1186 - val_loss: 52.7938 - val_mean_squared_error: 52.7938
# Epoch 17/20
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3790 - mean_squared_error: 4.3790 - val_loss: 42.5816 - val_mean_squared_error: 42.5816
# Epoch 18/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7103 - mean_squared_error: 3.7103 - val_loss: 39.1401 - val_mean_squared_error: 39.1401
# Epoch 19/20
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6054 - mean_squared_error: 3.6054 - val_loss: 38.9172 - val_mean_squared_error: 38.9172
# Epoch 20/20
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0804 - mean_squared_error: 3.0804 - val_loss: 36.7628 - val_mean_squared_error: 36.7628

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
sample=10
predictions = model.predict([X_test])
print("Valeurs en entree normalisees:\n", X_test[:sample])
print("Valeurs en entree non-normalisees:\n", X_test_unnorm[:sample])
print("Valeurs reelle en sortie:\n", Y_test[:sample])
print("Valeurs predit en sortie:\n", predictions[:sample])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test[:sample], predictions[:sample])))
# Out:
# Valeurs en entree normalisees:
#  [[0.1862069  1.         0.91666667 1.         0.45185185]
#  [0.5820208  0.40114613 0.53464717 0.85633727 1.        ]
#  [0.51092125 0.74256209 0.68052419 0.91810198 0.9006135 ]
#  [0.73283804 0.29919679 0.52839285 0.59050989 0.52791411]
#  [0.73930163 0.29940109 0.52841529 0.57711417 0.59831288]
#  [0.68112927 0.24220935 0.49038426 0.54221095 0.77638037]
#  [0.79962853 0.25948755 0.52094758 0.57174974 0.59003067]
#  [0.60787519 0.43103483 0.68063172 0.71673729 0.64386503]
#  [0.61649331 0.4939355  0.87073189 0.69660013 0.44923313]
#  [0.57340267 0.4939355  0.87073189 0.72479216 0.51554333]]
# Valeurs en entree non-normalisees:
#  [[  23.   350.   125.  3900.    17.4]
#  [  27.2  141.    71.  3190.    24.8]
#  [  23.9  260.    90.  3420.    22.2]
#  [  34.2  105.    70.  2200.    13.2]
#  [  34.5  105.    70.  2150.    14.9]
#  [  31.8   85.    65.  2020.    19.2]
#  [  37.3   91.    69.  2130.    14.7]
#  [  28.4  151.    90.  2670.    16. ]
#  [  28.8  173.   115.  2595.    11.3]
#  [  26.8  173.   115.  2700.    12.9]]
# Valeurs reelle en sortie:
#  [23.  27.2 23.9 34.2 34.5 31.8 37.3 28.4 28.8 26.8]
# Valeurs predit en sortie:
#  [[ 7.7216682]
#  [25.367386 ]
#  [20.553923 ]
#  [27.121107 ]
#  [27.740278 ]
#  [27.89792  ]
#  [29.437727 ]
#  [23.633745 ]
#  [22.078077 ]
#  [21.404348 ]]
# Valeur d'erreur moyenne:
#  9.74704143066878

# %% [markdown]
# # Adam + optimisation learning rate + early stopping

# %%
EPOCHS = 400

# %%
def get_callbacks():   
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_mean_squared_error', factor=0.3, patience=10, verbose=1, mode="min", min_lr=1e-4)

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=30 , verbose=1, mode="min", restore_best_weights=True)
    
#     model_cp = ModelCheckpoint('model.h5', 
#                                  save_best_only = True, 
#                                  save_weights_only = True,
#                                  monitor = 'val_loss', 
#                                  mode = 'min', verbose = 1)

    return [early_stopping, reduce_lr]

# %%
def build_model():
    model = tf.keras.models.Sequential() # Model sequential feed forward classique
    model.add(tf.keras.layers.Dense(units=N_FEATURES, input_shape=(N_FEATURES,), activation="linear")) # Features en linéaire
    model.add(tf.keras.layers.Dense(units=NB_NEURONS, activation="relu")) # Activation ReLU classique
#     model.add(tf.keras.layers.Dropout(DROPOUT_VALUE)) # Dropout pour eviter overfit
    model.add(tf.keras.layers.Dense(units=1, activation="linear")) # Une seule sortie : le prix. Sortie linéaire car regression
    model.compile(loss="mse", optimizer="adam", metrics=["mean_squared_error"])
    model.summary()
    return model

# %%
model = build_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, Y_train, epochs=EPOCHS, validation_data=(X_test, Y_test), callbacks=get_callbacks())
# Out:
# Epoch 1/400
# 10/10 [==============================] - 1s 15ms/step - loss: 484.8810 - mean_squared_error: 484.8810 - val_loss: 1025.2852 - val_mean_squared_error: 1025.2852
# Epoch 2/400
# 10/10 [==============================] - 0s 3ms/step - loss: 460.5321 - mean_squared_error: 460.5321 - val_loss: 1013.6226 - val_mean_squared_error: 1013.6226
# Epoch 3/400
# 10/10 [==============================] - 0s 3ms/step - loss: 459.7333 - mean_squared_error: 459.7333 - val_loss: 999.7857 - val_mean_squared_error: 999.7857
# Epoch 4/400
# 10/10 [==============================] - 0s 3ms/step - loss: 448.5127 - mean_squared_error: 448.5127 - val_loss: 983.0751 - val_mean_squared_error: 983.0751
# Epoch 5/400
# 10/10 [==============================] - 0s 3ms/step - loss: 420.5842 - mean_squared_error: 420.5842 - val_loss: 963.2921 - val_mean_squared_error: 963.2921
# Epoch 6/400
# 10/10 [==============================] - 0s 4ms/step - loss: 429.3732 - mean_squared_error: 429.3732 - val_loss: 940.0245 - val_mean_squared_error: 940.0245
# Epoch 7/400
# 10/10 [==============================] - 0s 4ms/step - loss: 408.5190 - mean_squared_error: 408.5190 - val_loss: 913.3163 - val_mean_squared_error: 913.3163
# Epoch 8/400
# 10/10 [==============================] - 0s 4ms/step - loss: 395.4368 - mean_squared_error: 395.4368 - val_loss: 882.9013 - val_mean_squared_error: 882.9013
# Epoch 9/400
# 10/10 [==============================] - 0s 4ms/step - loss: 372.4924 - mean_squared_error: 372.4924 - val_loss: 848.3259 - val_mean_squared_error: 848.3259
# Epoch 10/400
# 10/10 [==============================] - 0s 3ms/step - loss: 361.2765 - mean_squared_error: 361.2765 - val_loss: 809.1761 - val_mean_squared_error: 809.1761
# Epoch 11/400
# 10/10 [==============================] - 0s 4ms/step - loss: 334.9746 - mean_squared_error: 334.9746 - val_loss: 766.3027 - val_mean_squared_error: 766.3027
# Epoch 12/400
# 10/10 [==============================] - 0s 3ms/step - loss: 309.1624 - mean_squared_error: 309.1624 - val_loss: 719.4405 - val_mean_squared_error: 719.4405
# Epoch 13/400
# 10/10 [==============================] - 0s 3ms/step - loss: 273.3866 - mean_squared_error: 273.3866 - val_loss: 669.6877 - val_mean_squared_error: 669.6877
# Epoch 14/400
# 10/10 [==============================] - 0s 4ms/step - loss: 244.5167 - mean_squared_error: 244.5167 - val_loss: 617.5965 - val_mean_squared_error: 617.5965
# Epoch 15/400
# 10/10 [==============================] - 0s 4ms/step - loss: 212.9941 - mean_squared_error: 212.9941 - val_loss: 564.0131 - val_mean_squared_error: 564.0131
# Epoch 16/400
# 10/10 [==============================] - 0s 3ms/step - loss: 192.2981 - mean_squared_error: 192.2981 - val_loss: 509.7221 - val_mean_squared_error: 509.7221
# Epoch 17/400
# 10/10 [==============================] - 0s 3ms/step - loss: 182.9017 - mean_squared_error: 182.9017 - val_loss: 455.4254 - val_mean_squared_error: 455.4254
# Epoch 18/400
# 10/10 [==============================] - 0s 4ms/step - loss: 143.9630 - mean_squared_error: 143.9630 - val_loss: 403.4090 - val_mean_squared_error: 403.4090
# Epoch 19/400
# 10/10 [==============================] - 0s 3ms/step - loss: 128.4283 - mean_squared_error: 128.4283 - val_loss: 353.4333 - val_mean_squared_error: 353.4333
# Epoch 20/400
# 10/10 [==============================] - 0s 3ms/step - loss: 99.4051 - mean_squared_error: 99.4051 - val_loss: 308.0731 - val_mean_squared_error: 308.0731
# Epoch 21/400
# 10/10 [==============================] - 0s 3ms/step - loss: 79.6728 - mean_squared_error: 79.6728 - val_loss: 268.3409 - val_mean_squared_error: 268.3409
# Epoch 22/400
# 10/10 [==============================] - 0s 4ms/step - loss: 79.8673 - mean_squared_error: 79.8673 - val_loss: 232.6023 - val_mean_squared_error: 232.6023
# Epoch 23/400
# 10/10 [==============================] - 0s 4ms/step - loss: 56.9540 - mean_squared_error: 56.9540 - val_loss: 204.6357 - val_mean_squared_error: 204.6357
# Epoch 24/400
# 10/10 [==============================] - 0s 3ms/step - loss: 54.1566 - mean_squared_error: 54.1566 - val_loss: 182.3225 - val_mean_squared_error: 182.3225
# Epoch 25/400
# 10/10 [==============================] - 0s 4ms/step - loss: 47.4676 - mean_squared_error: 47.4676 - val_loss: 165.4561 - val_mean_squared_error: 165.4561
# Epoch 26/400
# 10/10 [==============================] - 0s 4ms/step - loss: 45.4772 - mean_squared_error: 45.4772 - val_loss: 152.5994 - val_mean_squared_error: 152.5994
# Epoch 27/400
# 10/10 [==============================] - 0s 4ms/step - loss: 45.1138 - mean_squared_error: 45.1138 - val_loss: 144.0598 - val_mean_squared_error: 144.0598
# Epoch 28/400
# 10/10 [==============================] - 0s 4ms/step - loss: 44.0989 - mean_squared_error: 44.0989 - val_loss: 137.3290 - val_mean_squared_error: 137.3290
# Epoch 29/400
# 10/10 [==============================] - 0s 4ms/step - loss: 43.0895 - mean_squared_error: 43.0895 - val_loss: 132.6628 - val_mean_squared_error: 132.6628
# Epoch 30/400
# 10/10 [==============================] - 0s 4ms/step - loss: 40.5642 - mean_squared_error: 40.5642 - val_loss: 128.2197 - val_mean_squared_error: 128.2197
# Epoch 31/400
# 10/10 [==============================] - 0s 4ms/step - loss: 39.2971 - mean_squared_error: 39.2971 - val_loss: 125.9160 - val_mean_squared_error: 125.9160
# Epoch 32/400
# 10/10 [==============================] - 0s 4ms/step - loss: 40.2987 - mean_squared_error: 40.2987 - val_loss: 124.7887 - val_mean_squared_error: 124.7887
# Epoch 33/400
# 10/10 [==============================] - 0s 4ms/step - loss: 38.4294 - mean_squared_error: 38.4294 - val_loss: 124.1651 - val_mean_squared_error: 124.1651
# Epoch 34/400
# 10/10 [==============================] - 0s 3ms/step - loss: 40.9695 - mean_squared_error: 40.9695 - val_loss: 123.0568 - val_mean_squared_error: 123.0568
# Epoch 35/400
# 10/10 [==============================] - 0s 3ms/step - loss: 36.4398 - mean_squared_error: 36.4398 - val_loss: 122.7886 - val_mean_squared_error: 122.7886
# Epoch 36/400
# 10/10 [==============================] - 0s 3ms/step - loss: 36.7369 - mean_squared_error: 36.7369 - val_loss: 123.4361 - val_mean_squared_error: 123.4361
# Epoch 37/400
# 10/10 [==============================] - 0s 3ms/step - loss: 36.5274 - mean_squared_error: 36.5274 - val_loss: 121.6521 - val_mean_squared_error: 121.6521
# Epoch 38/400
# 10/10 [==============================] - 0s 4ms/step - loss: 36.5827 - mean_squared_error: 36.5827 - val_loss: 118.9096 - val_mean_squared_error: 118.9096
# Epoch 39/400
# 10/10 [==============================] - 0s 4ms/step - loss: 32.5961 - mean_squared_error: 32.5961 - val_loss: 116.5347 - val_mean_squared_error: 116.5347
# Epoch 40/400
# 10/10 [==============================] - 0s 3ms/step - loss: 33.1764 - mean_squared_error: 33.1764 - val_loss: 114.8908 - val_mean_squared_error: 114.8908
# Epoch 41/400
# 10/10 [==============================] - 0s 3ms/step - loss: 35.1757 - mean_squared_error: 35.1757 - val_loss: 113.8200 - val_mean_squared_error: 113.8200
# Epoch 42/400
# 10/10 [==============================] - 0s 3ms/step - loss: 35.4219 - mean_squared_error: 35.4219 - val_loss: 112.1892 - val_mean_squared_error: 112.1892
# Epoch 43/400
# 10/10 [==============================] - 0s 4ms/step - loss: 31.1780 - mean_squared_error: 31.1780 - val_loss: 110.7289 - val_mean_squared_error: 110.7289
# Epoch 44/400
# 10/10 [==============================] - 0s 4ms/step - loss: 33.9300 - mean_squared_error: 33.9300 - val_loss: 110.9453 - val_mean_squared_error: 110.9453
# Epoch 45/400
# 10/10 [==============================] - 0s 4ms/step - loss: 30.0930 - mean_squared_error: 30.0930 - val_loss: 110.0345 - val_mean_squared_error: 110.0345
# Epoch 46/400
# 10/10 [==============================] - 0s 3ms/step - loss: 30.2292 - mean_squared_error: 30.2292 - val_loss: 107.8719 - val_mean_squared_error: 107.8719
# Epoch 47/400
# 10/10 [==============================] - 0s 4ms/step - loss: 29.1081 - mean_squared_error: 29.1081 - val_loss: 108.2560 - val_mean_squared_error: 108.2560
# Epoch 48/400
# 10/10 [==============================] - 0s 4ms/step - loss: 27.6758 - mean_squared_error: 27.6758 - val_loss: 108.2334 - val_mean_squared_error: 108.2334
# Epoch 49/400
# 10/10 [==============================] - 0s 4ms/step - loss: 24.8571 - mean_squared_error: 24.8571 - val_loss: 106.5043 - val_mean_squared_error: 106.5043
# Epoch 50/400
# 10/10 [==============================] - 0s 4ms/step - loss: 26.5897 - mean_squared_error: 26.5897 - val_loss: 104.4519 - val_mean_squared_error: 104.4519
# Epoch 51/400
# 10/10 [==============================] - 0s 4ms/step - loss: 25.7420 - mean_squared_error: 25.7420 - val_loss: 103.8962 - val_mean_squared_error: 103.8962
# Epoch 52/400
# 10/10 [==============================] - 0s 4ms/step - loss: 26.4640 - mean_squared_error: 26.4640 - val_loss: 102.4159 - val_mean_squared_error: 102.4159
# Epoch 53/400
# 10/10 [==============================] - 0s 4ms/step - loss: 23.8885 - mean_squared_error: 23.8885 - val_loss: 100.6755 - val_mean_squared_error: 100.6755
# Epoch 54/400
# 10/10 [==============================] - 0s 4ms/step - loss: 26.5325 - mean_squared_error: 26.5325 - val_loss: 97.6681 - val_mean_squared_error: 97.6681
# Epoch 55/400
# 10/10 [==============================] - 0s 4ms/step - loss: 23.2423 - mean_squared_error: 23.2423 - val_loss: 96.6984 - val_mean_squared_error: 96.6984
# Epoch 56/400
# 10/10 [==============================] - 0s 4ms/step - loss: 23.7780 - mean_squared_error: 23.7780 - val_loss: 94.3815 - val_mean_squared_error: 94.3815
# Epoch 57/400
# 10/10 [==============================] - 0s 4ms/step - loss: 23.8408 - mean_squared_error: 23.8408 - val_loss: 93.5468 - val_mean_squared_error: 93.5468
# Epoch 58/400
# 10/10 [==============================] - 0s 4ms/step - loss: 20.7252 - mean_squared_error: 20.7252 - val_loss: 93.2859 - val_mean_squared_error: 93.2859
# Epoch 59/400
# 10/10 [==============================] - 0s 4ms/step - loss: 19.7385 - mean_squared_error: 19.7385 - val_loss: 92.0543 - val_mean_squared_error: 92.0543
# Epoch 60/400
# 10/10 [==============================] - 0s 4ms/step - loss: 21.4032 - mean_squared_error: 21.4032 - val_loss: 91.0375 - val_mean_squared_error: 91.0375
# Epoch 61/400
# 10/10 [==============================] - 0s 4ms/step - loss: 18.8335 - mean_squared_error: 18.8335 - val_loss: 90.5491 - val_mean_squared_error: 90.5491
# Epoch 62/400
# 10/10 [==============================] - 0s 4ms/step - loss: 20.2764 - mean_squared_error: 20.2764 - val_loss: 88.1090 - val_mean_squared_error: 88.1090
# Epoch 63/400
# 10/10 [==============================] - 0s 3ms/step - loss: 19.4701 - mean_squared_error: 19.4701 - val_loss: 87.1613 - val_mean_squared_error: 87.1613
# Epoch 64/400
# 10/10 [==============================] - 0s 4ms/step - loss: 19.0613 - mean_squared_error: 19.0613 - val_loss: 86.9035 - val_mean_squared_error: 86.9035
# Epoch 65/400
# 10/10 [==============================] - 0s 4ms/step - loss: 20.0693 - mean_squared_error: 20.0693 - val_loss: 86.3418 - val_mean_squared_error: 86.3418
# Epoch 66/400
# 10/10 [==============================] - 0s 4ms/step - loss: 17.4162 - mean_squared_error: 17.4162 - val_loss: 86.3849 - val_mean_squared_error: 86.3849
# Epoch 67/400
# 10/10 [==============================] - 0s 4ms/step - loss: 16.4174 - mean_squared_error: 16.4174 - val_loss: 85.9589 - val_mean_squared_error: 85.9589
# Epoch 68/400
# 10/10 [==============================] - 0s 4ms/step - loss: 15.3594 - mean_squared_error: 15.3594 - val_loss: 82.5346 - val_mean_squared_error: 82.5346
# Epoch 69/400
# 10/10 [==============================] - 0s 4ms/step - loss: 16.5597 - mean_squared_error: 16.5597 - val_loss: 81.2770 - val_mean_squared_error: 81.2770
# Epoch 70/400
# 10/10 [==============================] - 0s 3ms/step - loss: 14.9317 - mean_squared_error: 14.9317 - val_loss: 80.1743 - val_mean_squared_error: 80.1743
# Epoch 71/400
# 10/10 [==============================] - 0s 3ms/step - loss: 13.9124 - mean_squared_error: 13.9124 - val_loss: 78.0746 - val_mean_squared_error: 78.0746
# Epoch 72/400
# 10/10 [==============================] - 0s 4ms/step - loss: 15.2121 - mean_squared_error: 15.2121 - val_loss: 76.5470 - val_mean_squared_error: 76.5470
# Epoch 73/400
# 10/10 [==============================] - 0s 3ms/step - loss: 13.5983 - mean_squared_error: 13.5983 - val_loss: 76.4884 - val_mean_squared_error: 76.4884
# Epoch 74/400
# 10/10 [==============================] - 0s 3ms/step - loss: 12.9457 - mean_squared_error: 12.9457 - val_loss: 76.3096 - val_mean_squared_error: 76.3096
# Epoch 75/400
# 10/10 [==============================] - 0s 3ms/step - loss: 12.0577 - mean_squared_error: 12.0577 - val_loss: 75.3757 - val_mean_squared_error: 75.3757
# Epoch 76/400
# 10/10 [==============================] - 0s 4ms/step - loss: 12.0746 - mean_squared_error: 12.0746 - val_loss: 73.8587 - val_mean_squared_error: 73.8587
# Epoch 77/400
# 10/10 [==============================] - 0s 4ms/step - loss: 11.0185 - mean_squared_error: 11.0185 - val_loss: 73.6122 - val_mean_squared_error: 73.6122
# Epoch 78/400
# 10/10 [==============================] - 0s 4ms/step - loss: 11.0562 - mean_squared_error: 11.0562 - val_loss: 71.7564 - val_mean_squared_error: 71.7564
# Epoch 79/400
# 10/10 [==============================] - 0s 4ms/step - loss: 9.9933 - mean_squared_error: 9.9933 - val_loss: 70.0785 - val_mean_squared_error: 70.0785
# Epoch 80/400
# 10/10 [==============================] - 0s 4ms/step - loss: 9.4286 - mean_squared_error: 9.4286 - val_loss: 69.3879 - val_mean_squared_error: 69.3879
# Epoch 81/400
# 10/10 [==============================] - 0s 4ms/step - loss: 9.5312 - mean_squared_error: 9.5312 - val_loss: 68.3455 - val_mean_squared_error: 68.3455
# Epoch 82/400
# 10/10 [==============================] - 0s 4ms/step - loss: 8.7089 - mean_squared_error: 8.7089 - val_loss: 69.0270 - val_mean_squared_error: 69.0270
# Epoch 83/400
# 10/10 [==============================] - 0s 3ms/step - loss: 8.3102 - mean_squared_error: 8.3102 - val_loss: 67.3736 - val_mean_squared_error: 67.3736
# Epoch 84/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.9722 - mean_squared_error: 7.9722 - val_loss: 66.0356 - val_mean_squared_error: 66.0356
# Epoch 85/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.9513 - mean_squared_error: 7.9513 - val_loss: 63.9269 - val_mean_squared_error: 63.9269
# Epoch 86/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.8517 - mean_squared_error: 7.8517 - val_loss: 64.1264 - val_mean_squared_error: 64.1264
# Epoch 87/400
# 10/10 [==============================] - 0s 3ms/step - loss: 7.4457 - mean_squared_error: 7.4457 - val_loss: 64.2302 - val_mean_squared_error: 64.2302
# Epoch 88/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.5089 - mean_squared_error: 7.5089 - val_loss: 62.3339 - val_mean_squared_error: 62.3339
# Epoch 89/400
# 10/10 [==============================] - 0s 4ms/step - loss: 7.1837 - mean_squared_error: 7.1837 - val_loss: 61.7159 - val_mean_squared_error: 61.7159
# Epoch 90/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.4419 - mean_squared_error: 6.4419 - val_loss: 61.0195 - val_mean_squared_error: 61.0195
# Epoch 91/400
# 10/10 [==============================] - 0s 5ms/step - loss: 6.5460 - mean_squared_error: 6.5460 - val_loss: 60.1019 - val_mean_squared_error: 60.1019
# Epoch 92/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.4978 - mean_squared_error: 6.4978 - val_loss: 59.9130 - val_mean_squared_error: 59.9130
# Epoch 93/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.1219 - mean_squared_error: 6.1219 - val_loss: 59.0440 - val_mean_squared_error: 59.0440
# Epoch 94/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.5826 - mean_squared_error: 5.5826 - val_loss: 58.3882 - val_mean_squared_error: 58.3882
# Epoch 95/400
# 10/10 [==============================] - 0s 4ms/step - loss: 6.2749 - mean_squared_error: 6.2749 - val_loss: 56.5137 - val_mean_squared_error: 56.5137
# Epoch 96/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.6984 - mean_squared_error: 5.6984 - val_loss: 57.9247 - val_mean_squared_error: 57.9247
# Epoch 97/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.8166 - mean_squared_error: 5.8166 - val_loss: 57.3855 - val_mean_squared_error: 57.3855
# Epoch 98/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.8428 - mean_squared_error: 4.8428 - val_loss: 56.2559 - val_mean_squared_error: 56.2559
# Epoch 99/400
# 10/10 [==============================] - 0s 3ms/step - loss: 5.4222 - mean_squared_error: 5.4222 - val_loss: 54.4076 - val_mean_squared_error: 54.4076
# Epoch 100/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.9948 - mean_squared_error: 5.9948 - val_loss: 54.1081 - val_mean_squared_error: 54.1081
# Epoch 101/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.9516 - mean_squared_error: 4.9516 - val_loss: 54.0229 - val_mean_squared_error: 54.0229
# Epoch 102/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.4291 - mean_squared_error: 5.4291 - val_loss: 54.0932 - val_mean_squared_error: 54.0932
# Epoch 103/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.8940 - mean_squared_error: 4.8940 - val_loss: 54.5555 - val_mean_squared_error: 54.5555
# Epoch 104/400
# 10/10 [==============================] - 0s 4ms/step - loss: 5.2271 - mean_squared_error: 5.2271 - val_loss: 53.1473 - val_mean_squared_error: 53.1473
# Epoch 105/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.5956 - mean_squared_error: 4.5956 - val_loss: 53.5591 - val_mean_squared_error: 53.5591
# Epoch 106/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.4696 - mean_squared_error: 4.4696 - val_loss: 52.8249 - val_mean_squared_error: 52.8249
# Epoch 107/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.6073 - mean_squared_error: 4.6073 - val_loss: 51.5313 - val_mean_squared_error: 51.5313
# Epoch 108/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.8161 - mean_squared_error: 4.8161 - val_loss: 51.2888 - val_mean_squared_error: 51.2888
# Epoch 109/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3951 - mean_squared_error: 4.3951 - val_loss: 51.0180 - val_mean_squared_error: 51.0180
# Epoch 110/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.8334 - mean_squared_error: 4.8334 - val_loss: 50.5674 - val_mean_squared_error: 50.5674
# Epoch 111/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.4905 - mean_squared_error: 4.4905 - val_loss: 51.3594 - val_mean_squared_error: 51.3594
# Epoch 112/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.7707 - mean_squared_error: 4.7707 - val_loss: 51.4904 - val_mean_squared_error: 51.4904
# Epoch 113/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.6342 - mean_squared_error: 4.6342 - val_loss: 49.8540 - val_mean_squared_error: 49.8540
# Epoch 114/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.7798 - mean_squared_error: 4.7798 - val_loss: 49.4714 - val_mean_squared_error: 49.4714
# Epoch 115/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.5580 - mean_squared_error: 4.5580 - val_loss: 50.0076 - val_mean_squared_error: 50.0076
# Epoch 116/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.1056 - mean_squared_error: 4.1056 - val_loss: 49.9489 - val_mean_squared_error: 49.9489
# Epoch 117/400
# 10/10 [==============================] - 0s 3ms/step - loss: 4.3348 - mean_squared_error: 4.3348 - val_loss: 49.7244 - val_mean_squared_error: 49.7244
# Epoch 118/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.1025 - mean_squared_error: 4.1025 - val_loss: 49.6003 - val_mean_squared_error: 49.6003
# Epoch 119/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3453 - mean_squared_error: 4.3453 - val_loss: 47.7096 - val_mean_squared_error: 47.7096
# Epoch 120/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9458 - mean_squared_error: 3.9458 - val_loss: 46.8740 - val_mean_squared_error: 46.8740
# Epoch 121/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3051 - mean_squared_error: 4.3051 - val_loss: 48.3171 - val_mean_squared_error: 48.3171
# Epoch 122/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.0723 - mean_squared_error: 4.0723 - val_loss: 48.9157 - val_mean_squared_error: 48.9157
# Epoch 123/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7393 - mean_squared_error: 3.7393 - val_loss: 47.5476 - val_mean_squared_error: 47.5476
# Epoch 124/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.1028 - mean_squared_error: 4.1028 - val_loss: 47.2969 - val_mean_squared_error: 47.2969
# Epoch 125/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.3935 - mean_squared_error: 4.3935 - val_loss: 47.3039 - val_mean_squared_error: 47.3039
# Epoch 126/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.4380 - mean_squared_error: 4.4380 - val_loss: 46.9997 - val_mean_squared_error: 46.9997
# Epoch 127/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8727 - mean_squared_error: 3.8727 - val_loss: 46.7488 - val_mean_squared_error: 46.7488
# Epoch 128/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7244 - mean_squared_error: 3.7244 - val_loss: 47.0107 - val_mean_squared_error: 47.0107
# Epoch 129/400
# 10/10 [==============================] - 0s 4ms/step - loss: 4.0542 - mean_squared_error: 4.0542 - val_loss: 46.3727 - val_mean_squared_error: 46.3727
# Epoch 130/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7548 - mean_squared_error: 3.7548 - val_loss: 46.3203 - val_mean_squared_error: 46.3203
# Epoch 131/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8794 - mean_squared_error: 3.8794 - val_loss: 45.9788 - val_mean_squared_error: 45.9788
# Epoch 132/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7949 - mean_squared_error: 3.7949 - val_loss: 46.4755 - val_mean_squared_error: 46.4755
# Epoch 133/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8967 - mean_squared_error: 3.8967 - val_loss: 46.6824 - val_mean_squared_error: 46.6824
# Epoch 134/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.8573 - mean_squared_error: 3.8573 - val_loss: 45.3878 - val_mean_squared_error: 45.3878
# Epoch 135/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3376 - mean_squared_error: 3.3376 - val_loss: 44.7017 - val_mean_squared_error: 44.7017
# Epoch 136/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9328 - mean_squared_error: 3.9328 - val_loss: 45.7906 - val_mean_squared_error: 45.7906
# Epoch 137/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7897 - mean_squared_error: 3.7897 - val_loss: 44.1761 - val_mean_squared_error: 44.1761
# Epoch 138/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3134 - mean_squared_error: 3.3134 - val_loss: 45.0577 - val_mean_squared_error: 45.0577
# Epoch 139/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7464 - mean_squared_error: 3.7464 - val_loss: 45.3132 - val_mean_squared_error: 45.3132
# Epoch 140/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7364 - mean_squared_error: 3.7364 - val_loss: 45.1184 - val_mean_squared_error: 45.1184
# Epoch 141/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4981 - mean_squared_error: 3.4981 - val_loss: 43.8354 - val_mean_squared_error: 43.8354
# Epoch 142/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1872 - mean_squared_error: 3.1872 - val_loss: 43.9282 - val_mean_squared_error: 43.9282
# Epoch 143/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1489 - mean_squared_error: 3.1489 - val_loss: 43.2282 - val_mean_squared_error: 43.2282
# Epoch 144/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3963 - mean_squared_error: 3.3963 - val_loss: 43.6953 - val_mean_squared_error: 43.6953
# Epoch 145/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4356 - mean_squared_error: 3.4356 - val_loss: 43.3582 - val_mean_squared_error: 43.3582
# Epoch 146/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.4217 - mean_squared_error: 3.4217 - val_loss: 43.6117 - val_mean_squared_error: 43.6117
# Epoch 147/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3316 - mean_squared_error: 3.3316 - val_loss: 44.4516 - val_mean_squared_error: 44.4516
# Epoch 148/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4205 - mean_squared_error: 3.4205 - val_loss: 43.5054 - val_mean_squared_error: 43.5054
# Epoch 149/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9991 - mean_squared_error: 2.9991 - val_loss: 42.1821 - val_mean_squared_error: 42.1821
# Epoch 150/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1686 - mean_squared_error: 3.1686 - val_loss: 42.6385 - val_mean_squared_error: 42.6385
# Epoch 151/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2729 - mean_squared_error: 3.2729 - val_loss: 42.7733 - val_mean_squared_error: 42.7733
# Epoch 152/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5963 - mean_squared_error: 3.5963 - val_loss: 42.2645 - val_mean_squared_error: 42.2645
# Epoch 153/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1870 - mean_squared_error: 3.1870 - val_loss: 43.1324 - val_mean_squared_error: 43.1324
# Epoch 154/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2322 - mean_squared_error: 3.2322 - val_loss: 43.2096 - val_mean_squared_error: 43.2096
# Epoch 155/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3011 - mean_squared_error: 3.3011 - val_loss: 42.1344 - val_mean_squared_error: 42.1344
# Epoch 156/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5088 - mean_squared_error: 3.5088 - val_loss: 42.4000 - val_mean_squared_error: 42.4000
# Epoch 157/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1085 - mean_squared_error: 3.1085 - val_loss: 41.2242 - val_mean_squared_error: 41.2242
# Epoch 158/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3543 - mean_squared_error: 3.3543 - val_loss: 40.7367 - val_mean_squared_error: 40.7367
# Epoch 159/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4194 - mean_squared_error: 3.4194 - val_loss: 40.9251 - val_mean_squared_error: 40.9251
# Epoch 160/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8126 - mean_squared_error: 2.8126 - val_loss: 41.7262 - val_mean_squared_error: 41.7262
# Epoch 161/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1160 - mean_squared_error: 3.1160 - val_loss: 41.0113 - val_mean_squared_error: 41.0113
# Epoch 162/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8612 - mean_squared_error: 2.8612 - val_loss: 41.7223 - val_mean_squared_error: 41.7223
# Epoch 163/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9806 - mean_squared_error: 2.9806 - val_loss: 41.7198 - val_mean_squared_error: 41.7198
# Epoch 164/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6620 - mean_squared_error: 2.6620 - val_loss: 41.1743 - val_mean_squared_error: 41.1743
# Epoch 165/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0676 - mean_squared_error: 3.0676 - val_loss: 41.4286 - val_mean_squared_error: 41.4286
# Epoch 166/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8371 - mean_squared_error: 2.8371 - val_loss: 39.3268 - val_mean_squared_error: 39.3268
# Epoch 167/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3360 - mean_squared_error: 3.3360 - val_loss: 39.8866 - val_mean_squared_error: 39.8866
# Epoch 168/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.1602 - mean_squared_error: 3.1602 - val_loss: 40.4193 - val_mean_squared_error: 40.4193
# Epoch 169/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7837 - mean_squared_error: 2.7837 - val_loss: 40.1143 - val_mean_squared_error: 40.1143
# Epoch 170/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0205 - mean_squared_error: 3.0205 - val_loss: 39.5201 - val_mean_squared_error: 39.5201
# Epoch 171/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8551 - mean_squared_error: 2.8551 - val_loss: 39.4783 - val_mean_squared_error: 39.4783
# Epoch 172/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2346 - mean_squared_error: 3.2346 - val_loss: 39.1097 - val_mean_squared_error: 39.1097
# Epoch 173/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0190 - mean_squared_error: 3.0190 - val_loss: 39.3449 - val_mean_squared_error: 39.3449
# Epoch 174/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8602 - mean_squared_error: 2.8602 - val_loss: 38.9099 - val_mean_squared_error: 38.9099
# Epoch 175/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9026 - mean_squared_error: 2.9026 - val_loss: 39.4372 - val_mean_squared_error: 39.4372
# Epoch 176/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2637 - mean_squared_error: 3.2637 - val_loss: 39.6794 - val_mean_squared_error: 39.6794
# Epoch 177/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.6695 - mean_squared_error: 2.6695 - val_loss: 39.1674 - val_mean_squared_error: 39.1674
# Epoch 178/400
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0155 - mean_squared_error: 3.0155 - val_loss: 39.3140 - val_mean_squared_error: 39.3140
# Epoch 179/400
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0926 - mean_squared_error: 3.0926 - val_loss: 39.0078 - val_mean_squared_error: 39.0078
# Epoch 180/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6537 - mean_squared_error: 2.6537 - val_loss: 38.3296 - val_mean_squared_error: 38.3296
# Epoch 181/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5975 - mean_squared_error: 2.5975 - val_loss: 38.1170 - val_mean_squared_error: 38.1170
# Epoch 182/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7241 - mean_squared_error: 2.7241 - val_loss: 38.5449 - val_mean_squared_error: 38.5449
# Epoch 183/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8610 - mean_squared_error: 2.8610 - val_loss: 38.8963 - val_mean_squared_error: 38.8963
# Epoch 184/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3341 - mean_squared_error: 2.3341 - val_loss: 38.2424 - val_mean_squared_error: 38.2424
# Epoch 185/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6619 - mean_squared_error: 2.6619 - val_loss: 39.0654 - val_mean_squared_error: 39.0654
# Epoch 186/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8090 - mean_squared_error: 2.8090 - val_loss: 38.3169 - val_mean_squared_error: 38.3169
# Epoch 187/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.6040 - mean_squared_error: 2.6040 - val_loss: 36.3521 - val_mean_squared_error: 36.3521
# Epoch 188/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4630 - mean_squared_error: 2.4630 - val_loss: 37.7419 - val_mean_squared_error: 37.7419
# Epoch 189/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8786 - mean_squared_error: 2.8786 - val_loss: 37.3801 - val_mean_squared_error: 37.3801
# Epoch 190/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5763 - mean_squared_error: 2.5763 - val_loss: 37.9658 - val_mean_squared_error: 37.9658
# Epoch 191/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5013 - mean_squared_error: 2.5013 - val_loss: 37.4804 - val_mean_squared_error: 37.4804
# Epoch 192/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8276 - mean_squared_error: 2.8276 - val_loss: 37.0152 - val_mean_squared_error: 37.0152
# Epoch 193/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4857 - mean_squared_error: 2.4857 - val_loss: 36.4723 - val_mean_squared_error: 36.4723
# Epoch 194/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4761 - mean_squared_error: 2.4761 - val_loss: 35.9084 - val_mean_squared_error: 35.9084
# Epoch 195/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5774 - mean_squared_error: 2.5774 - val_loss: 37.1140 - val_mean_squared_error: 37.1140
# Epoch 196/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4654 - mean_squared_error: 2.4654 - val_loss: 36.9607 - val_mean_squared_error: 36.9607
# Epoch 197/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2146 - mean_squared_error: 2.2146 - val_loss: 36.2297 - val_mean_squared_error: 36.2297
# Epoch 198/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8293 - mean_squared_error: 2.8293 - val_loss: 38.0048 - val_mean_squared_error: 38.0048
# Epoch 199/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3091 - mean_squared_error: 2.3091 - val_loss: 35.3348 - val_mean_squared_error: 35.3348
# Epoch 200/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4302 - mean_squared_error: 2.4302 - val_loss: 35.1588 - val_mean_squared_error: 35.1588
# Epoch 201/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2448 - mean_squared_error: 2.2448 - val_loss: 36.1007 - val_mean_squared_error: 36.1007
# Epoch 202/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3708 - mean_squared_error: 2.3708 - val_loss: 36.5112 - val_mean_squared_error: 36.5112
# Epoch 203/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.6480 - mean_squared_error: 2.6480 - val_loss: 35.4057 - val_mean_squared_error: 35.4057
# Epoch 204/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3821 - mean_squared_error: 2.3821 - val_loss: 34.1533 - val_mean_squared_error: 34.1533
# Epoch 205/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3299 - mean_squared_error: 2.3299 - val_loss: 37.3185 - val_mean_squared_error: 37.3185
# Epoch 206/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6332 - mean_squared_error: 2.6332 - val_loss: 34.9450 - val_mean_squared_error: 34.9450
# Epoch 207/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3560 - mean_squared_error: 2.3560 - val_loss: 34.3872 - val_mean_squared_error: 34.3872
# Epoch 208/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3921 - mean_squared_error: 2.3921 - val_loss: 36.2828 - val_mean_squared_error: 36.2828
# Epoch 209/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3216 - mean_squared_error: 2.3216 - val_loss: 35.4695 - val_mean_squared_error: 35.4695
# Epoch 210/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3529 - mean_squared_error: 2.3529 - val_loss: 33.5165 - val_mean_squared_error: 33.5165
# Epoch 211/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3712 - mean_squared_error: 2.3712 - val_loss: 34.5637 - val_mean_squared_error: 34.5637
# Epoch 212/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.5037 - mean_squared_error: 2.5037 - val_loss: 34.8298 - val_mean_squared_error: 34.8298
# Epoch 213/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.3457 - mean_squared_error: 2.3457 - val_loss: 34.5040 - val_mean_squared_error: 34.5040
# Epoch 214/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4974 - mean_squared_error: 2.4974 - val_loss: 33.2632 - val_mean_squared_error: 33.2632
# Epoch 215/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2919 - mean_squared_error: 2.2919 - val_loss: 34.9957 - val_mean_squared_error: 34.9957
# Epoch 216/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1058 - mean_squared_error: 2.1058 - val_loss: 33.7897 - val_mean_squared_error: 33.7897
# Epoch 217/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2681 - mean_squared_error: 2.2681 - val_loss: 34.5604 - val_mean_squared_error: 34.5604
# Epoch 218/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2528 - mean_squared_error: 2.2528 - val_loss: 32.8259 - val_mean_squared_error: 32.8259
# Epoch 219/400
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4567 - mean_squared_error: 2.4567 - val_loss: 34.1975 - val_mean_squared_error: 34.1975
# Epoch 220/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2225 - mean_squared_error: 2.2225 - val_loss: 33.8906 - val_mean_squared_error: 33.8906
# Epoch 221/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3378 - mean_squared_error: 2.3378 - val_loss: 33.2830 - val_mean_squared_error: 33.2830
# Epoch 222/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4318 - mean_squared_error: 2.4318 - val_loss: 32.8626 - val_mean_squared_error: 32.8626
# Epoch 223/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9226 - mean_squared_error: 1.9226 - val_loss: 34.0074 - val_mean_squared_error: 34.0074
# Epoch 224/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2276 - mean_squared_error: 2.2276 - val_loss: 32.7169 - val_mean_squared_error: 32.7169
# Epoch 225/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1322 - mean_squared_error: 2.1322 - val_loss: 33.5277 - val_mean_squared_error: 33.5277
# Epoch 226/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2709 - mean_squared_error: 2.2709 - val_loss: 32.9734 - val_mean_squared_error: 32.9734
# Epoch 227/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0225 - mean_squared_error: 2.0225 - val_loss: 32.5261 - val_mean_squared_error: 32.5261
# Epoch 228/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0213 - mean_squared_error: 2.0213 - val_loss: 33.2718 - val_mean_squared_error: 33.2718
# Epoch 229/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1769 - mean_squared_error: 2.1769 - val_loss: 32.4901 - val_mean_squared_error: 32.4901
# Epoch 230/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9105 - mean_squared_error: 1.9105 - val_loss: 32.3705 - val_mean_squared_error: 32.3705
# Epoch 231/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1593 - mean_squared_error: 2.1593 - val_loss: 33.8054 - val_mean_squared_error: 33.8054
# Epoch 232/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9258 - mean_squared_error: 1.9258 - val_loss: 32.7019 - val_mean_squared_error: 32.7019
# Epoch 233/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7018 - mean_squared_error: 1.7018 - val_loss: 32.0047 - val_mean_squared_error: 32.0047
# Epoch 234/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1248 - mean_squared_error: 2.1248 - val_loss: 31.7809 - val_mean_squared_error: 31.7809
# Epoch 235/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0323 - mean_squared_error: 2.0323 - val_loss: 32.8317 - val_mean_squared_error: 32.8317
# Epoch 236/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0209 - mean_squared_error: 2.0209 - val_loss: 31.9308 - val_mean_squared_error: 31.9308
# Epoch 237/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8670 - mean_squared_error: 1.8670 - val_loss: 30.5381 - val_mean_squared_error: 30.5381
# Epoch 238/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0568 - mean_squared_error: 2.0568 - val_loss: 32.1084 - val_mean_squared_error: 32.1084
# Epoch 239/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9446 - mean_squared_error: 1.9446 - val_loss: 32.2606 - val_mean_squared_error: 32.2606
# Epoch 240/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2065 - mean_squared_error: 2.2065 - val_loss: 32.3960 - val_mean_squared_error: 32.3960
# Epoch 241/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8634 - mean_squared_error: 1.8634 - val_loss: 31.2762 - val_mean_squared_error: 31.2762
# Epoch 242/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9422 - mean_squared_error: 1.9422 - val_loss: 32.1103 - val_mean_squared_error: 32.1103
# Epoch 243/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8408 - mean_squared_error: 1.8408 - val_loss: 32.2202 - val_mean_squared_error: 32.2202
# Epoch 244/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8696 - mean_squared_error: 1.8696 - val_loss: 31.7580 - val_mean_squared_error: 31.7580
# Epoch 245/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0400 - mean_squared_error: 2.0400 - val_loss: 31.0159 - val_mean_squared_error: 31.0159
# Epoch 246/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1701 - mean_squared_error: 2.1701 - val_loss: 32.1982 - val_mean_squared_error: 32.1982
# Epoch 247/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2807 - mean_squared_error: 2.2807 - val_loss: 31.9737 - val_mean_squared_error: 31.9737
#
# Epoch 00247: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 248/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6974 - mean_squared_error: 1.6974 - val_loss: 31.5356 - val_mean_squared_error: 31.5356
# Epoch 249/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7476 - mean_squared_error: 1.7476 - val_loss: 31.6445 - val_mean_squared_error: 31.6445
# Epoch 250/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6364 - mean_squared_error: 1.6364 - val_loss: 31.4456 - val_mean_squared_error: 31.4456
# Epoch 251/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1560 - mean_squared_error: 2.1560 - val_loss: 31.6725 - val_mean_squared_error: 31.6725
# Epoch 252/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7745 - mean_squared_error: 1.7745 - val_loss: 31.1506 - val_mean_squared_error: 31.1506
# Epoch 253/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7241 - mean_squared_error: 1.7241 - val_loss: 31.2116 - val_mean_squared_error: 31.2116
# Epoch 254/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7449 - mean_squared_error: 1.7449 - val_loss: 31.4727 - val_mean_squared_error: 31.4727
# Epoch 255/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9693 - mean_squared_error: 1.9693 - val_loss: 32.0086 - val_mean_squared_error: 32.0086
# Epoch 256/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8084 - mean_squared_error: 1.8084 - val_loss: 31.1717 - val_mean_squared_error: 31.1717
# Epoch 257/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6671 - mean_squared_error: 1.6671 - val_loss: 31.3555 - val_mean_squared_error: 31.3555
#
# Epoch 00257: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 258/400
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9083 - mean_squared_error: 1.9083 - val_loss: 31.2317 - val_mean_squared_error: 31.2317
# Epoch 259/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9392 - mean_squared_error: 1.9392 - val_loss: 31.0535 - val_mean_squared_error: 31.0535
# Epoch 260/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8261 - mean_squared_error: 1.8261 - val_loss: 30.9143 - val_mean_squared_error: 30.9143
# Epoch 261/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8063 - mean_squared_error: 1.8063 - val_loss: 30.8953 - val_mean_squared_error: 30.8953
# Epoch 262/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7333 - mean_squared_error: 1.7333 - val_loss: 30.8671 - val_mean_squared_error: 30.8671
# Epoch 263/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6693 - mean_squared_error: 1.6693 - val_loss: 30.8717 - val_mean_squared_error: 30.8717
# Epoch 264/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7253 - mean_squared_error: 1.7253 - val_loss: 31.0413 - val_mean_squared_error: 31.0413
# Epoch 265/400
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0202 - mean_squared_error: 2.0202 - val_loss: 30.9694 - val_mean_squared_error: 30.9694
# Epoch 266/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9212 - mean_squared_error: 1.9212 - val_loss: 30.9817 - val_mean_squared_error: 30.9817
# Epoch 267/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7978 - mean_squared_error: 1.7978 - val_loss: 31.1016 - val_mean_squared_error: 31.1016
# Restoring model weights from the end of the best epoch.
# Epoch 00267: early stopping

# %%
# Check overfit
plt.xlabel("epoch")
plt.ylabel("mean_squared_error")
plt.plot(hist.history["mean_squared_error"], label="train")
plt.plot(hist.history["val_mean_squared_error"], label="test")
plt.legend()
plt.show()

# %%
# Check prediction
predictions = model.predict([X_test])
print("Valeur d'erreur moyenne:\n", np.sqrt(erreur_mc(Y_test, predictions)))
# Out:
# Valeur d'erreur moyenne:
#  9.318145415015781
